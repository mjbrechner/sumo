# %%
import pandas as pd
from sqlite3 import connect

# %%
sumos = pd.read_csv("data/cleaned.csv")
sumos
# Out:
#           basho     id       rikishi  rank  height  weight   bmi         heya  \
# 0       1983.01   4140   Chikubayama  J13w   175.5   115.0  37.3     Miyagino
# 1       1983.01   4306         Ofuji  Ms1e   193.5   145.0  38.7      Kokonoe
# 2       1983.01   1337  Tochitsukasa  J12w   178.5   130.0  40.8     Kasugano
# 3       1983.01   4323      Shiraiwa  J13e   182.4   103.0  31.0    Isegahama
# 4       1983.01   4097    Tamakiyama  J12e   182.0   134.0  40.5    Kataonami
# ...         ...    ...           ...   ...     ...     ...   ...          ...
# 227938  2023.07  11985      Daieisho   S1w   182.0   161.0  48.6     Oitekaze
# 227939  2023.07  12451      Hoshoryu   S1e   186.0   131.0  37.9    Tatsunami
# 227940  2023.07  12796       Hakuoho  M17w   179.0   156.0  48.7     Miyagino
# 227941  2023.07  12094           Abi   K1w   188.0   149.0  42.2  Shikoroyama
# 227942  2023.07  12231     Kirishima   O1w   187.0   138.0  39.5    Michinoku
#
#         shusshin  outcome    kimarite  opponent id      opponent
# 0        Fukuoka        0    yorikiri         4306         Ofuji
# 1          Tokyo        1    yorikiri         4140   Chikubayama
# 2          Aichi        1   oshidashi         4323      Shiraiwa
# 3          Akita        0   oshidashi         1337  Tochitsukasa
# 4        Fukuoka        0    yorikiri         4319    Harunafuji
# ...          ...      ...         ...          ...           ...
# 227938   Saitama        0  hikiotoshi        11855     Takanosho
# 227939  Mongolia        1   uwatenage        12796       Hakuoho
# 227940   Tottori        0   uwatenage        12451      Hoshoryu
# 227941   Saitama        1    yorikiri        12231     Kirishima
# 227942  Mongolia        0    yorikiri        12094           Abi
#
# [227943 rows x 13 columns]

# %% [markdown]
# In this next cell, I am trying to figure out a way to change 'rank' to be a string, but this is proving difficult so far.

# %%
rikishi_list = []
for i in sumos["rikishi"].unique():
    rikishi_list.append(i)

rikishi_list
# Out:
# ['Chikubayama',
#  'Ofuji',
#  'Tochitsukasa',
#  'Shiraiwa',
#  'Tamakiyama',
#  'Harunafuji',
#  'Kotogatake',
#  'Hakuryuyama',
#  'Zaonishiki',
#  'Hachiya',
#  'Takamisugi',
#  'Tengoyama',
#  'Daitetsu',
#  'Kakureizan',
#  'Tochiakagi',
#  'Shinko',
#  'Itai',
#  'Hakuryu',
#  'Sakahoko',
#  'Sanofuji',
#  'Hidanohana',
#  'Kotochitose',
#  'Onokuni',
#  'Koboyama',
#  'Wakajishi',
#  'Washuyama',
#  'Asahifuji',
#  'Banryuyama',
#  'Kurosegawa',
#  'Tochitsurugi',
#  'Jingaku',
#  'Shishiho',
#  'Wakasegawa',
#  'Amanoyama',
#  'Tamaryu',
#  'Tochihikari',
#  'Tagaryu',
#  'Wakanofuji',
#  'Takamiyama',
#  'Azumanada',
#  'Hoo',
#  'Saisu',
#  'Ozutsu',
#  'Fujizakura',
#  'Masudayama',
#  'Aobajo',
#  'Toryu',
#  'Kaiki',
#  'Kirinji',
#  'Sadanoumi',
#  'Kurama',
#  'Asashio',
#  'Oshio',
#  'Wakashimazu',
#  'Hokutenyu',
#  'Kotokaze',
#  'Onishiki',
#  'Takanosato',
#  'Wakanohana',
#  'Dewanohana',
#  'Daijuyama',
#  'Kitanoumi',
#  'Chiyonofuji',
#  'Oyutaka',
#  'Dewanoshima',
#  'Tejima',
#  'Ichinowatari',
#  'Suiryu',
#  'Kotowaka',
#  'Tochiizumi',
#  'Hananokuni',
#  'Hoshi',
#  'Kinoarashi',
#  'Rinho',
#  'Arai',
#  'Kirishima',
#  'Seionada',
#  'Taigiyama',
#  'Fukunosato',
#  'Oko',
#  'Tochiomi',
#  'Fujinosato',
#  'Kitao',
#  'Masurao',
#  'Kiyomidake',
#  'Onohana',
#  'Tochimatoi',
#  'Hanaarashi',
#  'Hattori',
#  'Hanaguruma',
#  'Koryu',
#  'Hananoumi',
#  'Hoshiiwato',
#  'Sekinohana',
#  'Futasekaze',
#  'Mitoizumi',
#  'Hiyama',
#  'Konishiki',
#  'Hoshikabuto',
#  'Kotonoryu',
#  'Maenoshin',
#  'Kotogaume',
#  'Shushi',
#  'Minenofuji',
#  'Asahizakura',
#  'Misugiiso',
#  'Kototsubaki',
#  'Wakatsukuba',
#  'Byakuhoyama',
#  'Terao',
#  'Takuetsuyama',
#  'Fujinoiwa',
#  'Takarakuni',
#  'Suiseizan',
#  'Misugisato',
#  'Hakusan',
#  'Kaio',
#  'Sasshunada',
#  'Genjiyama',
#  'Tenkoyama',
#  'Ichiki',
#  'Hanaryu',
#  'Fujihikari',
#  'Iyozakura',
#  'Tatsufuji',
#  'Shishuyama',
#  'Takanofuji',
#  'Tochinohana',
#  'Otaka',
#  'Genkaiho',
#  'Toshoho',
#  'Kirinishiki',
#  'Kaneshiro',
#  'Ishinriki',
#  'Kotoinazuma',
#  'Kotoosugi',
#  'Fujinokawa',
#  'Ojishi',
#  'Iwatefuji',
#  'Takanomine',
#  'Arashifuji',
#  'Hananofuji',
#  'Tachinofuji',
#  'Hanaogi',
#  'Enazakura',
#  'Kaseda',
#  'Kobayashiyama',
#  'Wakanoumi',
#  'Taue',
#  'Kotofuji',
#  'Kuga',
#  'Tamakirin',
#  'Saganobori',
#  'Takamichi',
#  'Tochinowaka',
#  'Hokutoumi',
#  'Futahaguro',
#  'Naruyama',
#  'Hananowaka',
#  'Kyokudozan',
#  'Yuho',
#  'Takanohama',
#  'Maenoarashi',
#  'Yamazaki',
#  'Kitakachidoki',
#  'Oishida',
#  'Nankairyu',
#  'Fujinoshin',
#  'Ryogoku',
#  'Daigaku',
#  'Tobimaru',
#  'Kotohakusan',
#  'Amamifuji',
#  'Akinoshima',
#  'Kotomatsuzawa',
#  'Kitafubuki',
#  'Morita',
#  'Fukuryudake',
#  'Kasugafuji',
#  'Kiraiho',
#  'Daizen',
#  'Dairyu',
#  'Maemiyama',
#  'Nishinoryu',
#  'Miyata',
#  'Kotonishiki',
#  'Kiyononada',
#  'Hidenohana',
#  'Dewanokuni',
#  'Kotobeppu',
#  'Koganefuji',
#  'Tachihikari',
#  'Owakamatsu',
#  'Zenshinyama',
#  'Oginohana',
#  'Kyokugozan',
#  'Komafudo',
#  'Kushima',
#  'Kyokueiko',
#  'Shidenryu',
#  'Asahisato',
#  'Morinosato',
#  'Yoshinobori',
#  'Kushimaumi',
#  'Takamishu',
#  'Goken',
#  'Kamakari',
#  'Yamanishiki',
#  'Takatoriki',
#  'Ryujuyama',
#  'Tamakairiki',
#  'Ryukozan',
#  'Takamio',
#  'Fuchita',
#  'Wakahanada',
#  'Takahanada',
#  'Suginohana',
#  'Tochitenko',
#  'Minatofuji',
#  'Akebono',
#  'Kumao',
#  'Osuzuki',
#  'Daishoyama',
#  'Tomoefuji',
#  'Kotonowaka',
#  'Ryugahama',
#  'Tokitsunada',
#  'Toyonoumi',
#  'Naminohana',
#  'Murata',
#  'Hayashi',
#  'Daikiko',
#  'Tatsuhikari',
#  'Nagao',
#  'Daishoho',
#  'Tsunenoyama',
#  'Namioka',
#  'Kenko',
#  'Seifu',
#  'Daishi',
#  'Takanonami',
#  'Seifuriki',
#  'Mainoumi',
#  'Hitachiryu',
#  'Musashimaru',
#  'Babaguchi',
#  'Wakashoyo',
#  'Nakajima',
#  'Tochisagami',
#  'Wakanoyama',
#  'Oginishiki',
#  'Akinomine',
#  'Kengaku',
#  'Kiyota',
#  'Murai',
#  'Ohidake',
#  'Koga',
#  'Teraki',
#  'Taishin',
#  'Ganyu',
#  'Kanechika',
#  'Asahiyutaka',
#  'Yutakafuji',
#  'Genkai',
#  'Kondo',
#  'Gassan',
#  'Aogiyama',
#  'Tochinofuji',
#  'Wakatosho',
#  'Hidenoumi',
#  'Mitsueyama',
#  'Higonoumi',
#  'Hoshitango',
#  'Akinokuni',
#  'Hoshiandesu',
#  'Rikio',
#  'Ota',
#  'Wakaadachi',
#  'Tomonohana',
#  'Yamanakayama',
#  'Asanonami',
#  'Hamasu',
#  'Daishoryu',
#  'Wakadozan',
#  'Kanesaku',
#  'Terunoumi',
#  'Hamanoshima',
#  'Asanowaka',
#  'Ozawa',
#  'Asasoyo',
#  'Takanohana',
#  'Yoshitane',
#  'Shigenoumi',
#  'Shikishima',
#  'Musoyama',
#  'Daitengo',
#  'Chokairyu',
#  'Kirinowaka',
#  'Umenosato',
#  'Kiyonofuji',
#  'Ikemori',
#  'Mineyama',
#  'Masakabuto',
#  'Mutsuhokkai',
#  'Shirasaki',
#  'Daiden',
#  'Ryudo',
#  'Oyamato',
#  'Ominato',
#  'Ohinode',
#  'Genkainami',
#  'Asanosho',
#  'Fukuzono',
#  'Kotoryu',
#  'Kurimoto',
#  'Mutetsuyama',
#  'Wakahayato',
#  'Sentoryu',
#  'Tosanoumi',
#  'Kotokanyu',
#  'Sunahama',
#  'Tsurunofuji',
#  'Goto',
#  'Daihisho',
#  'Tamakasuga',
#  'Yamato',
#  'Gokenzan',
#  'Kyokushuzan',
#  'Chiyotaikai',
#  'Gojoro',
#  'Ouchi',
#  'Aka',
#  'Takanonada',
#  'Wakanojo',
#  'Daiki',
#  'Sumiya',
#  'Saigo',
#  'Kotoarashi',
#  'Toyozakura',
#  'Otsukasa',
#  'Kotofujimoto',
#  'Shiga',
#  'Nanfu',
#  'Kyokutenho',
#  'Takamihana',
#  'Dewaarashi',
#  'Tochiazuma',
#  'Chiyonowaka',
#  'Kumagaya',
#  'Shoeito',
#  'Oikari',
#  'Dejima',
#  'Tochinonada',
#  'Akinoshu',
#  'Masunobori',
#  'Chiyotenzan',
#  'Tokitsuumi',
#  'Toki',
#  'Kogawa',
#  'Kaiho',
#  'Susanoumi',
#  'Kotoiwakuni',
#  'Arashi',
#  'Suzuki',
#  'Wakanosato',
#  'Hokutohikari',
#  'Kinkaiyama',
#  'Takaozaki',
#  'Kaigatake',
#  'Masutsuyoshi',
#  'Kaishinzan',
#  'Okamoto',
#  'Tochinoiwa',
#  'Dewataira',
#  'Kitazakura',
#  'Yotsukasa',
#  'Otakayama',
#  'Futatsukuba',
#  'Takeuchi',
#  'Tominagayama',
#  'Miyabiyama',
#  'Yachi',
#  'Saito',
#  'Kobo',
#  'Hayateumi',
#  'Wakatsutomu',
#  'Takanowaka',
#  'Tamanokuni',
#  'Dewanofuji',
#  'Tochisakae',
#  'Wakakosho',
#  'Towanoyama',
#  'Kasuganishiki',
#  'Juzan',
#  'Tamarikido',
#  'Tamanonada',
#  'Kato',
#  'Kototamiya',
#  'Aminishiki',
#  'Jumonji',
#  'Kotomitsuki',
#  'Buyuzan',
#  'Tomikaze',
#  'Takamisakari',
#  'Hokutomine',
#  'Midorifuji',
#  'Minami',
#  'Senshuyama',
#  'Nodera',
#  'Tanaka',
#  'Wakatoryu',
#  'Takahama',
#  'Hamanishiki',
#  'Asashoryu',
#  'Kuniazuma',
#  'Haruyama',
#  'Harunoyama',
#  'Sumanofuji',
#  'Komahikari',
#  'Furuichi',
#  'Sekiyama',
#  'Komidori',
#  'Hokutoriki',
#  'Yamada',
#  'Otoryu',
#  'Takanotsuru',
#  'Tamanoshima',
#  'Shimotori',
#  'Wakaazuma',
#  'Torafusuyama',
#  'Wakatoba',
#  'Nishikikaze',
#  'Raido',
#  'Ushiomaru',
#  'Wakatenro',
#  'Tochinoyama',
#  'Hokutoiwa',
#  'Daimanazuru',
#  'Iwakiyama',
#  'Kasugao',
#  'Daishodai',
#  'Toyonokuni',
#  'Kotonomine',
#  'Asasekiryu',
#  'Narita',
#  'Takekaze',
#  'Kokkai',
#  'Ryuho',
#  'Shishio',
#  'Hidenokuni',
#  'Asamiyoshi',
#  'Asofuji',
#  'Kakizoe',
#  'Uchida',
#  'Fujinohana',
#  'Kaito',
#  'Nakao',
#  'Futeno',
#  'Asahibenten',
#  'Tochifudo',
#  'Kaido',
#  'Bushuyama',
#  'Tokitenku',
#  'Hokutojo',
#  'Ama',
#  'Wakainami',
#  'Raiko',
#  'Hakuho',
#  'Roho',
#  'Nadatsukasa',
#  'Ichinotani',
#  'Hagiwara',
#  'Kotooshu',
#  'Toyonoshima',
#  'Kotokasuga',
#  'Maikaze',
#  'Ishide',
#  'Kotoshogiku',
#  'Katayama',
#  'Yoshiazuma',
#  'Suzukawa',
#  'Takamifuji',
#  'Hakurozan',
#  'Wakakirin',
#  'Hochiyama',
#  'Tamaasuka',
#  'Chiyohakuho',
#  'Kisenosato',
#  'Kaishozan',
#  'Kyokunankai',
#  'Kotokuni',
#  'Fukkoyama',
#  'Asahimaru',
#  'Dewanosato',
#  'Kanbayashi',
#  'Masatsukasa',
#  'Onishi',
#  'Shiraishi',
#  'Yoshikaze',
#  'Tamamitsukuni',
#  'Dairaido',
#  'Baruto',
#  'Daishoma',
#  'Kakuryu',
#  'Shunketsu',
#  'Mokonami',
#  'Homasho',
#  'Satoyama',
#  'Sawai',
#  'Ryuo',
#  'Oga',
#  'Dewaotori',
#  'Hakuba',
#  'Kimurayama',
#  'Shimoda',
#  'Kageyama',
#  'Tochiozan',
#  'Yakigaya',
#  'Kadomoto',
#  'Goeido',
#  'Wakanoho',
#  'Toyohibiki',
#  'Shirononami',
#  'Sakaizawa',
#  'Musashiryu',
#  'Ichihara',
#  'Hoshihikari',
#  'Kitataiki',
#  'Shimootori',
#  'Isobe',
#  'Sokokurai',
#  'Hokutokuni',
#  'Sagatsukasa',
#  'Tochinoshin',
#  'Tamawashi',
#  'Wakakoyu',
#  'Tosayutaka',
#  'Shotenro',
#  'Daiyubu',
#  'Yamamotoyama',
#  'Mori',
#  'Aran',
#  'Hoshikaze',
#  'Tokusegawa',
#  'Daishoumi',
#  'Yotsuguruma',
#  'Kotoyutaka',
#  'Kiyoseumi',
#  'Harumafuji',
#  'Fukuoka',
#  'Sensho',
#  'Kasugakuni',
#  'Okinoumi',
#  'Gagamaru',
#  'Shoketsu',
#  'Sotairyu',
#  'Tokushinho',
#  'Sadanofuji',
#  'Nakanokuni',
#  'Miyamoto',
#  'Surugatsukasa',
#  'Myogiryu',
#  'Kurosawa',
#  'Nakanishi',
#  'Daido',
#  'Matsutani',
#  'Masuraumi',
#  'Kaisei',
#  'Takarafuji',
#  'Tsurugidake',
#  'Takanoyama',
#  'Fukao',
#  'Maeta',
#  'Shironoryu',
#  'Fujiazuma',
#  'Akiseyama',
#  'Masunoyama',
#  'Takayasu',
#  'Aoki',
#  'Ikioi',
#  'Nionoumi',
#  'Aoiyama',
#  'Kitaharima',
#  'Mochimaru',
#  'Kaonishiki',
#  'Arawashi',
#  'Tochitsubasa',
#  'Hitenryu',
#  'Chiyonokuni',
#  'Tenkaiho',
#  'Oniarashi',
#  'Kyokushuho',
#  'Chiyozakura',
#  'Chiyoarashi',
#  'Kotoyuki',
#  'Naoe',
#  'Tokushoryu',
#  'Hishofuji',
#  'Kimikaze',
#  'Oiwato',
#  'Tochihiryu',
#  'Kitazono',
#  'Azumaryu',
#  'Asahisho',
#  'Shohozan',
#  'Meigetsuin',
#  'Homarefuji',
#  'Chiyotairyu',
#  'Amuru',
#  'Chokozan',
#  'Chiyootori',
#  'Wakanoshima',
#  'Hakiai',
#  'Sakumayama',
#  'Higonojo',
#  'Takanoiwa',
#  'Jokoryu',
#  'Masakaze',
#  'Kei',
#  'Terashita',
#  'Kairyu',
#  'Tanzo',
#  'Keitenkai',
#  'Daikiho',
#  'Tochiyashiki',
#  'Ryuden',
#  'Seiro',
#  'Chiyoo',
#  'Kagamio',
#  'Nishikigi',
#  'Kawanari',
#  'Chiyomaru',
#  'Kizenryu',
#  'Kotomisen',
#  'Endo',
#  'Osunaarashi',
#  'Sakigake',
#  'Wakamisho',
#  'Terunofuji',
#  'Shoho',
#  'Kihonoumi',
#  'Kansei',
#  'Yamatofuji',
#  'Higoarashi',
#  'Ichinojo',
#  'Daieisho',
#  'Kyokutaisei',
#  'Ishiura',
#  'Horyuyama',
#  'Dewahayate',
#  'Iwasaki',
#  'Kotoeko',
#  'Tatsu',
#  'Kagayaki',
#  'Abiko',
#  'Onosho',
#  'Horikiri',
#  'Amakaze',
#  'Abi',
#  'Kawabata',
#  'Shodai',
#  'Daishomaru',
#  'Mitakeumi',
#  'Hokaho',
#  'Takaryu',
#  'Asabenkei',
#  'Kisenoyama',
#  'Chiyoshoma',
#  'Tsurugisho',
#  'Ura',
#  'Akua',
#  'Terutsuyoshi',
#  'Hakuyozan',
#  'Sato',
#  'Shimanoumi',
#  'Oyanagi',
#  'Yamaguchi',
#  'Meisei',
#  'Hokutofuji',
#  'Sakamoto',
#  'Daiamami',
#  'Rikishin',
#  'Takakeisho',
#  'Tochimaru',
#  'Shiba',
#  'Takagenji',
#  'Asanoyama',
#  'Yutakayama',
#  'Tobizaru',
#  'Daiseido',
#  'Yago',
#  'Chiyonoo',
#  'Masunosho',
#  'Kizaki',
#  'Takanosho',
#  'Mitoryu',
#  'Tamaki',
#  'Enho',
#  'Takayoshitoshi',
#  'Wakatakakage',
#  'Chiyonoumi',
#  'Churanoumi',
#  'Gokushindo',
#  'Ichiyamamoto',
#  'Kiribayama',
#  'Tomokaze',
#  'Irodori',
#  'Kotodaigo',
#  'Ryuko',
#  'Wakamotoharu',
#  'Kotokuzan',
#  'Kotokamatani',
#  'Kizakiumi',
#  'Hoshoryu',
#  'Kaisho',
#  'Asagyokusei',
#  'Nishikifuji',
#  'Kototebakari',
#  'Kotoshoho',
#  'Oho',
#  'Bushozan',
#  'Tohakuryu',
#  'Hiradoumi',
#  'Atamifuji',
#  'Hokuseiho',
#  'Oshoma',
#  'Kinbozan',
#  'Shonannoumi',
#  'Gonoyama',
#  'Hakuoho',
#  'Roga',
#  'Shimazuumi',
#  'Tamashoho']

# %%
# There are two lines for each match, one for the winner and one for the loser.
# So as not to show duplicates of every match, we'll just show the winners with sumo_only_wins
sumo_only_wins = sumos[
    sumos.outcome == int("1")
]  # could also use sumo.loc[sumo.rikishi1_win == 1]

sumo_only_wins[["rikishi", "kimarite"]]
# sumo_only_wins
# Out:
#              rikishi    kimarite
# 1              Ofuji    yorikiri
# 2       Tochitsukasa   oshidashi
# 5         Harunafuji    yorikiri
# 7        Hakuryuyama  tsukidashi
# 9            Hachiya  hatakikomi
# ...              ...         ...
# 227934    Kotonowaka    yorikiri
# 227936     Asanoyama    yorikiri
# 227937     Takanosho  hikiotoshi
# 227939      Hoshoryu   uwatenage
# 227941           Abi    yorikiri
#
# [113960 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(sumos["height"], sumos["weight"])
