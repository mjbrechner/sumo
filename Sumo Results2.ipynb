# %%
import pandas as pd

sumo = pd.read_csv("data/results.csv", dtype={'basho': 'string', 'day': 'string', 'rikishi1_id': 'int64', 'rikishi1_rank': 'string', 'rikishi1_shikona': 'string', 'rikishi1_result': 'string', 'rikishi1_win': 'int64', 'kimarite': 'string', 'rikishi2_id': 'int64', 'rikishi2_rank': 'string', 'rikishi2_shikona': 'string', 'rikishi2_result': 'string', 'rikishi2_win': 'string'})

# %%
#print(results.loc[5, 'rikishi1_shikona'])
sumo
# Out:
#           basho day  rikishi1_id rikishi1_rank rikishi1_shikona  \
# 0       1983.01   1         4140          J13w      Chikubayama
# 1       1983.01   1         4306          Ms1e            Ofuji
# 2       1983.01   1         1337          J12w     Tochitsukasa
# 3       1983.01   1         4323          J13e         Shiraiwa
# 4       1983.01   1         4097          J12e       Tamakiyama
# ...         ...  ..          ...           ...              ...
# 227767  2023.07  15        11985           S1w         Daieisho
# 227768  2023.07  15        12451           S1e         Hoshoryu
# 227769  2023.07  15        12796          M17w          Hakuoho
# 227770  2023.07  15        12094           K1w              Abi
# 227771  2023.07  15        12231           O1w        Kirishima
#
#        rikishi1_result  rikishi1_win    kimarite  rikishi2_id rikishi2_rank  \
# 0            0-1 (7-8)             0    yorikiri         4306          Ms1e
# 1            1-0 (6-1)             1    yorikiri         4140          J13w
# 2            1-0 (9-6)             1   oshidashi         4323          J13e
# 3           0-1 (3-12)             0   oshidashi         1337          J12w
# 4            0-1 (8-7)             0    yorikiri         4319          J11w
# ...                ...           ...         ...          ...           ...
# 227767             9-6             0  hikiotoshi        11855           M9e
# 227768            12-3             1   uwatenage        12796          M17w
# 227769            11-4             0   uwatenage        12451           S1e
# 227770             6-9             1    yorikiri        12231           O1w
# 227771           6-7-2             0    yorikiri        12094           K1w
#
#        rikishi2_shikona rikishi2_result rikishi2_win
# 0                 Ofuji       1-0 (6-1)            1
# 1           Chikubayama       0-1 (7-8)            0
# 2              Shiraiwa      0-1 (3-12)            0
# 3          Tochitsukasa       1-0 (9-6)            1
# 4            Harunafuji      1-0 (5-10)            1
# ...                 ...             ...          ...
# 227767        Takanosho             8-7            1
# 227768          Hakuoho            11-4            0
# 227769         Hoshoryu            12-3            1
# 227770        Kirishima           6-7-2            0
# 227771              Abi             6-9            1
#
# [227772 rows x 13 columns]

# %%
sumo.sort_values(by='rikishi1_id')
# Out:
#           basho day  rikishi1_id rikishi1_rank rikishi1_shikona  \
# 101238  2000.09   7            1           Y1e          Akebono
# 98016   2000.01  15            1           Y2w          Akebono
# 57810   1993.03   5            1           Y1e          Akebono
# 69412   1995.03   3            1           Y1w          Akebono
# 78780   1996.09  12            1           Y1w          Akebono
# ...         ...  ..          ...           ...              ...
# 227545  2023.07  10        12796          M17w          Hakuoho
# 227703  2023.07  14        12796          M17w          Hakuoho
# 227501  2023.07   9        12796          M17w          Hakuoho
# 227385  2023.07   6        12796          M17w          Hakuoho
# 227685  2023.07  13        12796          M17w          Hakuoho
#
#        rikishi1_result  rikishi1_win     kimarite  rikishi2_id rikishi2_rank  \
# 101238      6-1 (13-2)             1     yorikiri           29           M1w
# 98016             11-4             0   yoritaoshi            2           Y1w
# 57810       5-0 (10-5)             1     yorikiri           44           M2w
# 69412       3-0 (14-1)             1   tsukidashi           62           M5e
# 78780       9-3 (10-5)             0   yoritaoshi            4           O2e
# ...                ...           ...          ...          ...           ...
# 227545      7-3 (11-4)             1    oshidashi         7153          M11e
# 227703     11-3 (11-4)             1  tsukiotoshi        12239           M9w
# 227501      6-3 (11-4)             0    oshidashi        12040          M14e
# 227385      4-2 (11-4)             1   hatakikomi        12688          M13e
# 227685     10-3 (11-4)             1     uchigake         6596           M1e
#
#        rikishi2_shikona rikishi2_result rikishi2_win
# 101238          Kotoryu      1-6 (1-14)            0
# 98016        Takanohana            12-3            1
# 57810        Kushimaumi     2-3 (7-7-1)            0
# 69412            Daishi      0-3 (3-12)            0
# 78780       Musashimaru     10-2 (11-4)            1
# ...                 ...             ...          ...
# 227545          Kotoeko       4-6 (8-7)            0
# 227703       Hokutofuji     11-3 (12-3)            0
# 227501         Daishoho       4-5 (6-9)            1
# 227385         Gonoyama      5-1 (10-5)            0
# 227685        Nishikigi     10-3 (10-5)            0
#
# [227772 rows x 13 columns]

# %%
rikishi_list = []
for i in sumo['rikishi1_shikona'].unique():
    rikishi_list.append(i)

rikishi_list
# Out:
# ['Chikubayama',
#  'Ofuji',
#  'Tochitsukasa',
#  'Shiraiwa',
#  'Tamakiyama',
#  'Harunafuji',
#  'Kotogatake',
#  'Hakuryuyama',
#  'Zaonishiki',
#  'Hachiya',
#  'Takamisugi',
#  'Tengoyama',
#  'Daitetsu',
#  'Kakureizan',
#  'Tochiakagi',
#  'Shinko',
#  'Itai',
#  'Hakuryu',
#  'Sakahoko',
#  'Sanofuji',
#  'Hidanohana',
#  'Kotochitose',
#  'Onokuni',
#  'Koboyama',
#  'Wakajishi',
#  'Washuyama',
#  'Asahifuji',
#  'Banryuyama',
#  'Kurosegawa',
#  'Tochitsurugi',
#  'Jingaku',
#  'Shishiho',
#  'Wakasegawa',
#  'Amanoyama',
#  'Tamaryu',
#  'Tochihikari',
#  'Tagaryu',
#  'Wakanofuji',
#  'Takamiyama',
#  'Azumanada',
#  'Hoo',
#  'Saisu',
#  'Ozutsu',
#  'Fujizakura',
#  'Masudayama',
#  'Aobajo',
#  'Toryu',
#  'Kaiki',
#  'Kirinji',
#  'Sadanoumi',
#  'Kurama',
#  'Asashio',
#  'Oshio',
#  'Wakashimazu',
#  'Hokutenyu',
#  'Kotokaze',
#  'Onishiki',
#  'Takanosato',
#  'Wakanohana',
#  'Dewanohana',
#  'Daijuyama',
#  'Kitanoumi',
#  'Chiyonofuji',
#  'Oyutaka',
#  'Dewanoshima',
#  'Tejima',
#  'Ichinowatari',
#  'Suiryu',
#  'Kotowaka',
#  'Tochiizumi',
#  'Hananokuni',
#  'Hoshi',
#  'Kinoarashi',
#  'Rinho',
#  'Arai',
#  'Kirishima',
#  'Seionada',
#  'Taigiyama',
#  'Fukunosato',
#  'Oko',
#  'Tochiomi',
#  'Fujinosato',
#  'Kitao',
#  'Masurao',
#  'Kiyomidake',
#  'Onohana',
#  'Tochimatoi',
#  'Hanaarashi',
#  'Hattori',
#  'Hanaguruma',
#  'Koryu',
#  'Hananoumi',
#  'Hoshiiwato',
#  'Sekinohana',
#  'Futasekaze',
#  'Mitoizumi',
#  'Hiyama',
#  'Konishiki',
#  'Hoshikabuto',
#  'Kotonoryu',
#  'Maenoshin',
#  'Kotogaume',
#  'Shushi',
#  'Minenofuji',
#  'Asahizakura',
#  'Misugiiso',
#  'Kototsubaki',
#  'Wakatsukuba',
#  'Byakuhoyama',
#  'Terao',
#  'Takuetsuyama',
#  'Fujinoiwa',
#  'Takarakuni',
#  'Suiseizan',
#  'Misugisato',
#  'Hakusan',
#  'Kaio',
#  'Sasshunada',
#  'Genjiyama',
#  'Tenkoyama',
#  'Ichiki',
#  'Hanaryu',
#  'Fujihikari',
#  'Iyozakura',
#  'Tatsufuji',
#  'Shishuyama',
#  'Takanofuji',
#  'Tochinohana',
#  'Otaka',
#  'Genkaiho',
#  'Toshoho',
#  'Kirinishiki',
#  'Kaneshiro',
#  'Ishinriki',
#  'Kotoinazuma',
#  'Kotoosugi',
#  'Fujinokawa',
#  'Ojishi',
#  'Iwatefuji',
#  'Takanomine',
#  'Arashifuji',
#  'Hananofuji',
#  'Tachinofuji',
#  'Hanaogi',
#  'Enazakura',
#  'Kaseda',
#  'Kobayashiyama',
#  'Wakanoumi',
#  'Taue',
#  'Kotofuji',
#  'Kuga',
#  'Tamakirin',
#  'Saganobori',
#  'Takamichi',
#  'Tochinowaka',
#  'Hokutoumi',
#  'Futahaguro',
#  'Naruyama',
#  'Hananowaka',
#  'Kyokudozan',
#  'Yuho',
#  'Takanohama',
#  'Maenoarashi',
#  'Yamazaki',
#  'Kitakachidoki',
#  'Oishida',
#  'Nankairyu',
#  'Fujinoshin',
#  'Ryogoku',
#  'Daigaku',
#  'Tobimaru',
#  'Kotohakusan',
#  'Amamifuji',
#  'Akinoshima',
#  'Kotomatsuzawa',
#  'Kitafubuki',
#  'Morita',
#  'Fukuryudake',
#  'Kasugafuji',
#  'Kiraiho',
#  'Daizen',
#  'Dairyu',
#  'Maemiyama',
#  'Nishinoryu',
#  'Miyata',
#  'Kotonishiki',
#  'Kiyononada',
#  'Hidenohana',
#  'Dewanokuni',
#  'Kotobeppu',
#  'Koganefuji',
#  'Tachihikari',
#  'Owakamatsu',
#  'Zenshinyama',
#  'Oginohana',
#  'Kyokugozan',
#  'Komafudo',
#  'Kushima',
#  'Kyokueiko',
#  'Shidenryu',
#  'Asahisato',
#  'Morinosato',
#  'Yoshinobori',
#  'Kushimaumi',
#  'Takamishu',
#  'Goken',
#  'Kamakari',
#  'Yamanishiki',
#  'Takatoriki',
#  'Ryujuyama',
#  'Tamakairiki',
#  'Ryukozan',
#  'Takamio',
#  'Fuchita',
#  'Wakahanada',
#  'Takahanada',
#  'Suginohana',
#  'Tochitenko',
#  'Minatofuji',
#  'Akebono',
#  'Kumao',
#  'Osuzuki',
#  'Daishoyama',
#  'Tomoefuji',
#  'Kotonowaka',
#  'Ryugahama',
#  'Tokitsunada',
#  'Toyonoumi',
#  'Naminohana',
#  'Murata',
#  'Hayashi',
#  'Daikiko',
#  'Tatsuhikari',
#  'Nagao',
#  'Daishoho',
#  'Tsunenoyama',
#  'Namioka',
#  'Kenko',
#  'Seifu',
#  'Daishi',
#  'Takanonami',
#  'Seifuriki',
#  'Mainoumi',
#  'Hitachiryu',
#  'Musashimaru',
#  'Babaguchi',
#  'Wakashoyo',
#  'Nakajima',
#  'Tochisagami',
#  'Wakanoyama',
#  'Oginishiki',
#  'Akinomine',
#  'Kengaku',
#  'Kiyota',
#  'Murai',
#  'Ohidake',
#  'Koga',
#  'Teraki',
#  'Taishin',
#  'Ganyu',
#  'Kanechika',
#  'Asahiyutaka',
#  'Yutakafuji',
#  'Genkai',
#  'Kondo',
#  'Gassan',
#  'Aogiyama',
#  'Tochinofuji',
#  'Wakatosho',
#  'Hidenoumi',
#  'Mitsueyama',
#  'Higonoumi',
#  'Hoshitango',
#  'Akinokuni',
#  'Hoshiandesu',
#  'Rikio',
#  'Ota',
#  'Wakaadachi',
#  'Tomonohana',
#  'Yamanakayama',
#  'Asanonami',
#  'Hamasu',
#  'Daishoryu',
#  'Wakadozan',
#  'Kanesaku',
#  'Terunoumi',
#  'Hamanoshima',
#  'Asanowaka',
#  'Ozawa',
#  'Asasoyo',
#  'Takanohana',
#  'Yoshitane',
#  'Shigenoumi',
#  'Shikishima',
#  'Musoyama',
#  'Daitengo',
#  'Chokairyu',
#  'Kirinowaka',
#  'Umenosato',
#  'Kiyonofuji',
#  'Ikemori',
#  'Mineyama',
#  'Masakabuto',
#  'Mutsuhokkai',
#  'Shirasaki',
#  'Daiden',
#  'Ryudo',
#  'Oyamato',
#  'Ominato',
#  'Ohinode',
#  'Genkainami',
#  'Asanosho',
#  'Fukuzono',
#  'Kotoryu',
#  'Kurimoto',
#  'Mutetsuyama',
#  'Wakahayato',
#  'Sentoryu',
#  'Tosanoumi',
#  'Kotokanyu',
#  'Sunahama',
#  'Tsurunofuji',
#  'Goto',
#  'Daihisho',
#  'Tamakasuga',
#  'Yamato',
#  'Gokenzan',
#  'Kyokushuzan',
#  'Chiyotaikai',
#  'Gojoro',
#  'Ouchi',
#  'Aka',
#  'Takanonada',
#  'Wakanojo',
#  'Daiki',
#  'Sumiya',
#  'Saigo',
#  'Kotoarashi',
#  'Toyozakura',
#  'Otsukasa',
#  'Kotofujimoto',
#  'Shiga',
#  'Nanfu',
#  'Kyokutenho',
#  'Takamihana',
#  'Dewaarashi',
#  'Tochiazuma',
#  'Chiyonowaka',
#  'Kumagaya',
#  'Shoeito',
#  'Oikari',
#  'Dejima',
#  'Tochinonada',
#  'Akinoshu',
#  'Masunobori',
#  'Chiyotenzan',
#  'Tokitsuumi',
#  'Toki',
#  'Kogawa',
#  'Kaiho',
#  'Susanoumi',
#  'Kotoiwakuni',
#  'Arashi',
#  'Suzuki',
#  'Wakanosato',
#  'Hokutohikari',
#  'Kinkaiyama',
#  'Takaozaki',
#  'Kaigatake',
#  'Masutsuyoshi',
#  'Kaishinzan',
#  'Okamoto',
#  'Tochinoiwa',
#  'Dewataira',
#  'Kitazakura',
#  'Yotsukasa',
#  'Otakayama',
#  'Futatsukuba',
#  'Takeuchi',
#  'Tominagayama',
#  'Miyabiyama',
#  'Yachi',
#  'Saito',
#  'Kobo',
#  'Hayateumi',
#  'Wakatsutomu',
#  'Takanowaka',
#  'Tamanokuni',
#  'Dewanofuji',
#  'Tochisakae',
#  'Wakakosho',
#  'Towanoyama',
#  'Kasuganishiki',
#  'Juzan',
#  'Tamarikido',
#  'Tamanonada',
#  'Kato',
#  'Kototamiya',
#  'Aminishiki',
#  'Jumonji',
#  'Kotomitsuki',
#  'Buyuzan',
#  'Tomikaze',
#  'Takamisakari',
#  'Hokutomine',
#  'Midorifuji',
#  'Minami',
#  'Senshuyama',
#  'Nodera',
#  'Tanaka',
#  'Wakatoryu',
#  'Takahama',
#  'Hamanishiki',
#  'Asashoryu',
#  'Kuniazuma',
#  'Haruyama',
#  'Harunoyama',
#  'Sumanofuji',
#  'Komahikari',
#  'Furuichi',
#  'Sekiyama',
#  'Komidori',
#  'Hokutoriki',
#  'Yamada',
#  'Otoryu',
#  'Takanotsuru',
#  'Tamanoshima',
#  'Shimotori',
#  'Wakaazuma',
#  'Torafusuyama',
#  'Wakatoba',
#  'Nishikikaze',
#  'Raido',
#  'Ushiomaru',
#  'Wakatenro',
#  'Tochinoyama',
#  'Hokutoiwa',
#  'Daimanazuru',
#  'Iwakiyama',
#  'Kasugao',
#  'Daishodai',
#  'Toyonokuni',
#  'Kotonomine',
#  'Asasekiryu',
#  'Narita',
#  'Takekaze',
#  'Kokkai',
#  'Ryuho',
#  'Shishio',
#  'Hidenokuni',
#  'Asamiyoshi',
#  'Asofuji',
#  'Kakizoe',
#  'Uchida',
#  'Fujinohana',
#  'Kaito',
#  'Nakao',
#  'Futeno',
#  'Asahibenten',
#  'Tochifudo',
#  'Kaido',
#  'Bushuyama',
#  'Tokitenku',
#  'Hokutojo',
#  'Ama',
#  'Wakainami',
#  'Raiko',
#  'Hakuho',
#  'Roho',
#  'Nadatsukasa',
#  'Ichinotani',
#  'Hagiwara',
#  'Kotooshu',
#  'Toyonoshima',
#  'Kotokasuga',
#  'Maikaze',
#  'Ishide',
#  'Kotoshogiku',
#  'Katayama',
#  'Yoshiazuma',
#  'Suzukawa',
#  'Takamifuji',
#  'Hakurozan',
#  'Wakakirin',
#  'Hochiyama',
#  'Tamaasuka',
#  'Chiyohakuho',
#  'Kisenosato',
#  'Kaishozan',
#  'Kyokunankai',
#  'Kotokuni',
#  'Fukkoyama',
#  'Asahimaru',
#  'Dewanosato',
#  'Kanbayashi',
#  'Masatsukasa',
#  'Onishi',
#  'Shiraishi',
#  'Yoshikaze',
#  'Tamamitsukuni',
#  'Dairaido',
#  'Baruto',
#  'Daishoma',
#  'Kakuryu',
#  'Shunketsu',
#  'Mokonami',
#  'Homasho',
#  'Satoyama',
#  'Sawai',
#  'Ryuo',
#  'Oga',
#  'Dewaotori',
#  'Hakuba',
#  'Kimurayama',
#  'Shimoda',
#  'Kageyama',
#  'Tochiozan',
#  'Yakigaya',
#  'Kadomoto',
#  'Goeido',
#  'Wakanoho',
#  'Toyohibiki',
#  'Shirononami',
#  'Sakaizawa',
#  'Musashiryu',
#  'Ichihara',
#  'Hoshihikari',
#  'Kitataiki',
#  'Shimootori',
#  'Isobe',
#  'Sokokurai',
#  'Hokutokuni',
#  'Sagatsukasa',
#  'Tochinoshin',
#  'Tamawashi',
#  'Wakakoyu',
#  'Tosayutaka',
#  'Shotenro',
#  'Daiyubu',
#  'Yamamotoyama',
#  'Mori',
#  'Aran',
#  'Hoshikaze',
#  'Tokusegawa',
#  'Daishoumi',
#  'Yotsuguruma',
#  'Kotoyutaka',
#  'Kiyoseumi',
#  'Harumafuji',
#  'Fukuoka',
#  'Sensho',
#  'Kasugakuni',
#  'Okinoumi',
#  'Gagamaru',
#  'Shoketsu',
#  'Sotairyu',
#  'Tokushinho',
#  'Sadanofuji',
#  'Nakanokuni',
#  'Miyamoto',
#  'Surugatsukasa',
#  'Myogiryu',
#  'Kurosawa',
#  'Nakanishi',
#  'Daido',
#  'Matsutani',
#  'Masuraumi',
#  'Kaisei',
#  'Takarafuji',
#  'Tsurugidake',
#  'Takanoyama',
#  'Fukao',
#  'Maeta',
#  'Shironoryu',
#  'Fujiazuma',
#  'Akiseyama',
#  'Masunoyama',
#  'Takayasu',
#  'Aoki',
#  'Ikioi',
#  'Nionoumi',
#  'Aoiyama',
#  'Kitaharima',
#  'Mochimaru',
#  'Kaonishiki',
#  'Arawashi',
#  'Tochitsubasa',
#  'Hitenryu',
#  'Chiyonokuni',
#  'Tenkaiho',
#  'Oniarashi',
#  'Kyokushuho',
#  'Chiyozakura',
#  'Chiyoarashi',
#  'Kotoyuki',
#  'Naoe',
#  'Tokushoryu',
#  'Hishofuji',
#  'Kimikaze',
#  'Oiwato',
#  'Tochihiryu',
#  'Kitazono',
#  'Azumaryu',
#  'Asahisho',
#  'Shohozan',
#  'Meigetsuin',
#  'Homarefuji',
#  'Chiyotairyu',
#  'Amuru',
#  'Chokozan',
#  'Chiyootori',
#  'Wakanoshima',
#  'Hakiai',
#  'Sakumayama',
#  'Higonojo',
#  'Takanoiwa',
#  'Jokoryu',
#  'Masakaze',
#  'Kei',
#  'Terashita',
#  'Kairyu',
#  'Tanzo',
#  'Keitenkai',
#  'Daikiho',
#  'Tochiyashiki',
#  'Ryuden',
#  'Seiro',
#  'Chiyoo',
#  'Kagamio',
#  'Nishikigi',
#  'Kawanari',
#  'Chiyomaru',
#  'Kizenryu',
#  'Kotomisen',
#  'Endo',
#  'Osunaarashi',
#  'Sakigake',
#  'Wakamisho',
#  'Terunofuji',
#  'Shoho',
#  'Kihonoumi',
#  'Kansei',
#  'Yamatofuji',
#  'Higoarashi',
#  'Ichinojo',
#  'Daieisho',
#  'Kyokutaisei',
#  'Ishiura',
#  'Horyuyama',
#  'Dewahayate',
#  'Iwasaki',
#  'Kotoeko',
#  'Tatsu',
#  'Kagayaki',
#  'Abiko',
#  'Onosho',
#  'Horikiri',
#  'Amakaze',
#  'Abi',
#  'Kawabata',
#  'Shodai',
#  'Daishomaru',
#  'Mitakeumi',
#  'Hokaho',
#  'Takaryu',
#  'Asabenkei',
#  'Kisenoyama',
#  'Chiyoshoma',
#  'Tsurugisho',
#  'Ura',
#  'Akua',
#  'Terutsuyoshi',
#  'Hakuyozan',
#  'Sato',
#  'Shimanoumi',
#  'Oyanagi',
#  'Yamaguchi',
#  'Meisei',
#  'Hokutofuji',
#  'Sakamoto',
#  'Daiamami',
#  'Rikishin',
#  'Takakeisho',
#  'Tochimaru',
#  'Shiba',
#  'Takagenji',
#  'Asanoyama',
#  'Yutakayama',
#  'Tobizaru',
#  'Daiseido',
#  'Yago',
#  'Chiyonoo',
#  'Masunosho',
#  'Kizaki',
#  'Takanosho',
#  'Mitoryu',
#  'Tamaki',
#  'Enho',
#  'Takayoshitoshi',
#  'Wakatakakage',
#  'Chiyonoumi',
#  'Churanoumi',
#  'Gokushindo',
#  'Ichiyamamoto',
#  'Kiribayama',
#  'Tomokaze',
#  'Irodori',
#  'Kotodaigo',
#  'Ryuko',
#  'Wakamotoharu',
#  'Kotokuzan',
#  'Kotokamatani',
#  'Kizakiumi',
#  'Hoshoryu',
#  'Kaisho',
#  'Asagyokusei',
#  'Nishikifuji',
#  'Kototebakari',
#  'Kotoshoho',
#  'Oho',
#  'Bushozan',
#  'Tohakuryu',
#  'Hiradoumi',
#  'Atamifuji',
#  'Hokuseiho',
#  'Oshoma',
#  'Kinbozan',
#  'Shonannoumi',
#  'Gonoyama',
#  'Hakuoho',
#  'Roga',
#  'Shimazuumi',
#  'Tamashoho']

# %%
#There are two lines for each match, one for the winner and one for the loser.
#So as not to show duplicates of every match, we'll just show the winners with sumo_only_wins
sumo_only_wins = sumo[sumo.rikishi1_win == int("1")] #could also use sumo.loc[sumo.rikishi1_win == 1]

sumo_only_wins[['rikishi1_shikona', 'kimarite']]
#sumo_only_wins
# Out:
#        rikishi1_shikona    kimarite
# 1                 Ofuji    yorikiri
# 2          Tochitsukasa   oshidashi
# 5            Harunafuji    yorikiri
# 7           Hakuryuyama  tsukidashi
# 9               Hachiya  hatakikomi
# ...                 ...         ...
# 227763       Kotonowaka    yorikiri
# 227765        Asanoyama    yorikiri
# 227766        Takanosho  hikiotoshi
# 227768         Hoshoryu   uwatenage
# 227770              Abi    yorikiri
#
# [113886 rows x 2 columns]

# %%
#Same as above, but now we'll just show the losers with sumo_only_losses
sumo_only_losses = sumo[sumo.rikishi1_win == int("0")]

sumo_only_losses[['rikishi1_shikona', 'kimarite']]
# Out:
#        rikishi1_shikona    kimarite
# 0           Chikubayama    yorikiri
# 3              Shiraiwa   oshidashi
# 4            Tamakiyama    yorikiri
# 6            Kotogatake  tsukidashi
# 8            Zaonishiki  hatakikomi
# ...                 ...         ...
# 227762           Ryuden    yorikiri
# 227764     Wakamotoharu    yorikiri
# 227767         Daieisho  hikiotoshi
# 227769          Hakuoho   uwatenage
# 227771        Kirishima    yorikiri
#
# [113886 rows x 2 columns]

# %%
#kaio_wins = sumo_only_wins.loc[sumo.rikishi1_shikona == 'Kaio']
#len(kaio_wins)

win_count = {}

for r in rikishi_list:
    #print(r, len(sumo_only_wins.loc[sumo.rikishi1_shikona == r]))
    win_count[r] = len(sumo_only_wins.loc[sumo.rikishi1_shikona == r])
    

wins_df= pd.DataFrame.from_dict(win_count, orient="index")
# df.sort_values(by=['Country'])
# wins_df.sort_values(by=win_count)
wins_df
# Out:
#                 0
# Chikubayama   181
# Ofuji          25
# Tochitsukasa  414
# Shiraiwa       37
# Tamakiyama     20
# ...           ...
# Gonoyama       11
# Hakuoho        11
# Roga            1
# Shimazuumi      0
# Tamashoho       1
#
# [733 rows x 1 columns]

# %%
sorted_win_count = sorted(win_count.items(), key=lambda x:x[1], reverse=True)
sorted_win_count

sorted_win_count_df = pd.DataFrame.from_dict(sorted_win_count)
sorted_win_count_df.columns = ['Shikona', 'Wins']
sorted_win_count_df.head()
# Out:
#       Shikona  Wins
# 0      Hakuho  1121
# 1        Kaio   986
# 2  Aminishiki   831
# 3  Kyokutenho   827
# 4  Kotonowaka   812

# %%
##Same thing but for losses
loss_count = {}

for r in rikishi_list:
    loss_count[r] = len(sumo_only_losses.loc[sumo.rikishi1_shikona == r])
    

sorted_loss_count = sorted(loss_count.items(), key=lambda x:x[1], reverse=True)
sorted_loss_count

sorted_loss_count_df = pd.DataFrame.from_dict(sorted_loss_count)
sorted_loss_count_df.columns = ['Shikona', 'Losses']
sorted_loss_count_df.head()
# Out:
#        Shikona  Losses
# 0   Kyokutenho     888
# 1   Aminishiki     869
# 2        Terao     847
# 3   Kotonowaka     802
# 4  Tochinowaka     796

# %%
won_loss_df = pd.merge(sorted_win_count_df, sorted_loss_count_df)
won_loss_df
# Out:
#           Shikona  Wins  Losses
# 0          Hakuho  1121     212
# 1            Kaio   986     676
# 2      Aminishiki   831     869
# 3      Kyokutenho   827     888
# 4      Kotonowaka   812     802
# ..            ...   ...     ...
# 728     Tochimaru     0       1
# 729         Shiba     0       1
# 730     Kotodaigo     0       2
# 731  Kototebakari     0       1
# 732    Shimazuumi     0       1
#
# [733 rows x 3 columns]

# %%
wp = won_loss_df[won_loss_df.Shikona == "Kaio"].Wins / (won_loss_df[won_loss_df.Shikona == "Kaio"].Wins + won_loss_df[won_loss_df.Shikona == "Kaio"].Losses)
p = 59.3
wp = round(wp, 2)
wp = int(wp)
print(f"Kaio had a winning percentage of {p}%.")

# sumo_only_wins = sumo[sumo.rikishi1_win == int("1")]
# Out:
# Kaio had a winning percentage of 59.3%.
# C:\Users\Platypus\AppData\Local\Temp\ipykernel_8332\2672335949.py:4: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   wp = int(wp)

# %%
#ww.columns['Rikishi', 'Total Wins']
wins_df.columns = ['Wins']
#wins_df.rename_axis('Rikishi').rename_axis('Rikishi2', axis=1)
#wins_df.columns.name = 'Rikishi'
wins_df.sort_values(by='Wins', ascending=False)

with_500_wins = wins_df.loc[wins_df.Wins >=500].sort_values(by='Wins', ascending=False)

#with_500_wins

# %%
#What is the highest rank each rikishi on the list achieved?
#The information in rikishi1_rank includes a designation of "e" or "w" ("east" or "west" on the banzuke), but as that is immaterial to ranking, we can strip it out.
#A simple excision of the final character doesn't work, so I can't do the following: sumo.rikishi1_rank.str[:-1]
#See, some rankings appear on the spreadsheet with an "HD" at the end, so I have to work with a list of characters to remove in order to clean this out.

char_to_remove = ['e', 'w', 'HD']
cleaned_rankings = sumo['rikishi1_rank']
for character in char_to_remove:
    cleaned_rankings = cleaned_rankings.str.replace(character, '')
#print(cleaned_rankings)


#But this ranking only shows a rikishi's rank for each match. That rank stays the same throughout any given tournament, but can be adjusted for the next tournament.
#So we want to see what the highest rank achieved by each rikishi.
#Starting at the top, the ranks are Y (Yokozuna), O (Ozeki), S (Sekiwake), K (Komusubi). These are the san'yaku ranks, the highest set of rankings.
#Then comes M (Maegashira, the best being M1 then increasing in number), then J (Juryo, J1, then increasing), Ms (Makushita, Ms1, then increasing).
#For the top san'yaku ranks, we see things like Y1 and Y2 on the banzuke, but that is just for matching purposes. The numberings only matter at lower levels,
#which is why the following value assignment gives equal values to each Y/O/S/K rank but differing values for the lower ranks.
ranking_dict = {'Y1': '1', 'Y2': '1', 'Y1YO': '1', 'Y2YO': '1', 'O1': '2', 'O2': '2', 'O3': '2', 'S1': '3', 'S2': '3', 'K1': '4', 'K2': '4', 'K3': '4', 'K4': '4', 'M1': '5', 'M2': '6', 'M3': '7', 'M4': '8', 'M5': '9', 'M6': '10', 'M7': '11',
                'M8': '12', 'M9': '13', 'M10': '14', 'M11': '15', 'M12': '16', 'M13': '17', 'M14': '18', 'M15': '19', 'M16': '20', 'M17': '21', 'M18': '22', 'J1': '23', 'J2': '24', 'J3': '25',
                'J4': '26', 'J5': '27', 'J6': '28', 'J7': '29', 'J8': '30', 'J9': '31', 'J10': '32', 'J11': '33', 'J12': '34', 'J13': '35', 'J14': '36', 'Ms1': '37', 'Ms2': '38', 'Ms3': '39',
                'Ms4': '40', 'Ms5': '41', 'Ms6': '42', 'Ms7': '43', 'Ms8': '44', 'Ms9': '45', 'Ms10': '46', 'Ms11': '47', 'Ms12': '48', 'Ms13': '49', 'Ms14': '50'}
#The following is a test to make sure no rankings are excluded from this cleanup set. If test = [] after this, we're good to go.
test = []
for i in sumo["rikishi1_rank"].unique():
    if (i in ranking_dict):
        test
    else:
        test.append(i)

test
# best_rank = {}
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Platypus\Documents\2023\2023DataAnalysis\Sumo\Sumo Results.ipynb Cell 14 line 9
#       <a href='vscode-notebook-cell:/c%3A/Users/Platypus/Documents/2023/2023DataAnalysis/Sumo/Sumo%20Results.ipynb#X15sZmlsZQ%3D%3D?line=6'>7</a> cleaned_rankings = sumo['rikishi1_rank']
#       <a href='vscode-notebook-cell:/c%3A/Users/Platypus/Documents/2023/2023DataAnalysis/Sumo/Sumo%20Results.ipynb#X15sZmlsZQ%3D%3D?line=7'>8</a> for character in char_to_remove:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Platypus/Documents/2023/2023DataAnalysis/Sumo/Sumo%20Results.ipynb#X15sZmlsZQ%3D%3D?line=8'>9</a>     cleaned_rankings = cleaned_rankings.str.replace(character, '')
#      <a href='vscode-notebook-cell:/c%3A/Users/Platypus/Documents/2023/2023DataAnalysis/Sumo/Sumo%20Results.ipynb#X15sZmlsZQ%3D%3D?line=9'>10</a> #print(cleaned_rankings)
#      <a href='vscode-notebook-cell:/c%3A/Users/Platypus/Documents/2023/2023DataAnalysis/Sumo/Sumo%20Results.ipynb#X15sZmlsZQ%3D%3D?line=10'>11</a>
#      <a href='vscode-notebook-cell:/c%3A/Users/Platypus/Documents/2023/2023DataAnalysis/Sumo/Sumo%20Results.ipynb#X15sZmlsZQ%3D%3D?line=11'>12</a>
#    (...)
#      <a href='vscode-notebook-cell:/c%3A/Users/Platypus/Documents/2023/2023DataAnalysis/Sumo/Sumo%20Results.ipynb#X15sZmlsZQ%3D%3D?line=16'>17</a> #For the top san'yaku ranks, we see things like Y1 and Y2 on the banzuke, but that is just for matching purposes. The numberings only matter at lower levels,
#      <a href='vscode-notebook-cell:/c%3A/Users/Platypus/Documents/2023/2023DataAnalysis/Sumo/Sumo%20Results.ipynb#X15sZmlsZQ%3D%3D?line=17'>18</a> #which is why the following value assignment gives equal values to each Y/O/S/K rank but differing values for the lower ranks.
#      <a href='vscode-notebook-cell:/c%3A/Users/Platypus/Documents/2023/2023DataAnalysis/Sumo/Sumo%20Results.ipynb#X15sZmlsZQ%3D%3D?line=18'>19</a> ranking_dict = {'Y1': '1', 'Y2': '1', 'Y1YO': '1', 'Y2YO': '1', 'O1': '2', 'O2': '2', 'O3': '2', 'S1': '3', 'S2': '3', 'K1': '4', 'K2': '4', 'K3': '4', 'K4': '4', 'M1': '5', 'M2': '6', 'M3': '7', 'M4': '8', 'M5': '9', 'M6': '10', 'M7': '11',
#      <a href='vscode-notebook-cell:/c%3A/Users/Platypus/Documents/2023/2023DataAnalysis/Sumo/Sumo%20Results.ipynb#X15sZmlsZQ%3D%3D?line=19'>20</a>                 'M8': '12', 'M9': '13', 'M10': '14', 'M11': '15', 'M12': '16', 'M13': '17', 'M14': '18', 'M15': '19', 'M16': '20', 'M17': '21', 'M18': '22', 'J1': '23', 'J2': '24', 'J3': '25',
#      <a href='vscode-notebook-cell:/c%3A/Users/Platypus/Documents/2023/2023DataAnalysis/Sumo/Sumo%20Results.ipynb#X15sZmlsZQ%3D%3D?line=20'>21</a>                 'J4': '26', 'J5': '27', 'J6': '28', 'J7': '29', 'J8': '30', 'J9': '31', 'J10': '32', 'J11': '33', 'J12': '34', 'J13': '35', 'J14': '36', 'Ms1': '37', 'Ms2': '38', 'Ms3': '39',
#      <a href='vscode-notebook-cell:/c%3A/Users/Platypus/Documents/2023/2023DataAnalysis/Sumo/Sumo%20Results.ipynb#X15sZmlsZQ%3D%3D?line=21'>22</a>                 'Ms4': '40', 'Ms5': '41', 'Ms6': '42', 'Ms7': '43', 'Ms8': '44', 'Ms9': '45', 'Ms10': '46', 'Ms11': '47', 'Ms12': '48', 'Ms13': '49', 'Ms14': '50'}
#
# File c:\Users\Platypus\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:6202, in NDFrame.__getattr__(self, name)
#    6195 if (
#    6196     name not in self._internal_names_set
#    6197     and name not in self._metadata
#    6198     and name not in self._accessors
#    6199     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6200 ):
#    6201     return self[name]
# -> 6202 return object.__getattribute__(self, name)
#
# File c:\Users\Platypus\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File c:\Users\Platypus\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\strings\accessor.py:190, in StringMethods.__init__(self, data)
#     187 def __init__(self, data) -> None:
#     188     from pandas.core.arrays.string_ import StringDtype
# --> 190     self._inferred_dtype = self._validate(data)
#     191     self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     192     self._is_string = isinstance(data.dtype, StringDtype)
#
# File c:\Users\Platypus\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\strings\accessor.py:244, in StringMethods._validate(data)
#     241 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     243 if inferred_dtype not in allowed_types:
# --> 244     raise AttributeError("Can only use .str accessor with string values!")
#     245 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
sumo_cleaned = sumo
sumo_cleaned.rikishi1_rank = cleaned_rankings
sumo_cleaned
# Out:
#           basho day  rikishi1_id rikishi1_rank rikishi1_shikona  \
# 0       1983.01   1         4140           J13      Chikubayama
# 1       1983.01   1         4306           Ms1            Ofuji
# 2       1983.01   1         1337           J12     Tochitsukasa
# 3       1983.01   1         4323           J13         Shiraiwa
# 4       1983.01   1         4097           J12       Tamakiyama
# ...         ...  ..          ...           ...              ...
# 227767  2023.07  15        11985            S1         Daieisho
# 227768  2023.07  15        12451            S1         Hoshoryu
# 227769  2023.07  15        12796           M17          Hakuoho
# 227770  2023.07  15        12094            K1              Abi
# 227771  2023.07  15        12231            O1        Kirishima
#
#        rikishi1_result  rikishi1_win    kimarite  rikishi2_id rikishi2_rank  \
# 0            0-1 (7-8)             0    yorikiri         4306          Ms1e
# 1            1-0 (6-1)             1    yorikiri         4140          J13w
# 2            1-0 (9-6)             1   oshidashi         4323          J13e
# 3           0-1 (3-12)             0   oshidashi         1337          J12w
# 4            0-1 (8-7)             0    yorikiri         4319          J11w
# ...                ...           ...         ...          ...           ...
# 227767             9-6             0  hikiotoshi        11855           M9e
# 227768            12-3             1   uwatenage        12796          M17w
# 227769            11-4             0   uwatenage        12451           S1e
# 227770             6-9             1    yorikiri        12231           O1w
# 227771           6-7-2             0    yorikiri        12094           K1w
#
#        rikishi2_shikona rikishi2_result rikishi2_win
# 0                 Ofuji       1-0 (6-1)            1
# 1           Chikubayama       0-1 (7-8)            0
# 2              Shiraiwa      0-1 (3-12)            0
# 3          Tochitsukasa       1-0 (9-6)            1
# 4            Harunafuji      1-0 (5-10)            1
# ...                 ...             ...          ...
# 227767        Takanosho             8-7            1
# 227768          Hakuoho            11-4            0
# 227769         Hoshoryu            12-3            1
# 227770        Kirishima           6-7-2            0
# 227771              Abi             6-9            1
#
# [227772 rows x 13 columns]

# %%
# test2 = []
# for i in range(len(sumo)):
#    bmi = i
#    test.append(bmi)
# test

# for i in sumo["rikishi1_rank"]:
#     for i in ranking_dict.keys():
#          i = ranking_dict[i]
#          test2.append(i)
# test2
sumo.replace({"rikishi1_rank": ranking_dict}, inplace=True)

sumo.rikishi1_rank
sumo.head()
# Out:
#      basho day  rikishi1_id rikishi1_rank rikishi1_shikona rikishi1_result  \
# 0  1983.01   1         4140            35      Chikubayama       0-1 (7-8)
# 1  1983.01   1         4306            37            Ofuji       1-0 (6-1)
# 2  1983.01   1         1337            34     Tochitsukasa       1-0 (9-6)
# 3  1983.01   1         4323            35         Shiraiwa      0-1 (3-12)
# 4  1983.01   1         4097            34       Tamakiyama       0-1 (8-7)
#
#    rikishi1_win   kimarite  rikishi2_id rikishi2_rank rikishi2_shikona  \
# 0             0   yorikiri         4306          Ms1e            Ofuji
# 1             1   yorikiri         4140          J13w      Chikubayama
# 2             1  oshidashi         4323          J13e         Shiraiwa
# 3             0  oshidashi         1337          J12w     Tochitsukasa
# 4             0   yorikiri         4319          J11w       Harunafuji
#
#   rikishi2_result rikishi2_win
# 0       1-0 (6-1)            1
# 1       0-1 (7-8)            0
# 2      0-1 (3-12)            0
# 3       1-0 (9-6)            1
# 4      1-0 (5-10)            1

# %%
sumo["rikishi1_rank"] = sumo["rikishi1_rank"].astype(int)

for i in sumo["rikishi1_rank"]:
    i = i+1
sumo.head()
# Out:
#      basho day  rikishi1_id  rikishi1_rank rikishi1_shikona rikishi1_result  \
# 0  1983.01   1         4140             35      Chikubayama       0-1 (7-8)
# 1  1983.01   1         4306             37            Ofuji       1-0 (6-1)
# 2  1983.01   1         1337             34     Tochitsukasa       1-0 (9-6)
# 3  1983.01   1         4323             35         Shiraiwa      0-1 (3-12)
# 4  1983.01   1         4097             34       Tamakiyama       0-1 (8-7)
#
#    rikishi1_win   kimarite  rikishi2_id rikishi2_rank rikishi2_shikona  \
# 0             0   yorikiri         4306          Ms1e            Ofuji
# 1             1   yorikiri         4140          J13w      Chikubayama
# 2             1  oshidashi         4323          J13e         Shiraiwa
# 3             0  oshidashi         1337          J12w     Tochitsukasa
# 4             0   yorikiri         4319          J11w       Harunafuji
#
#   rikishi2_result rikishi2_win
# 0       1-0 (6-1)            1
# 1       0-1 (7-8)            0
# 2      0-1 (3-12)            0
# 3       1-0 (9-6)            1
# 4      1-0 (5-10)            1

# %%
kaio_wins = sumo_cleaned.loc[sumo_cleaned.rikishi1_shikona == 'Kaio']
kaio_wins['rikishi1_rank']
kaio_best = ""
#for k in kaio_wins:
    #if kaio_wins['rikishi1_rank']
    #print(k, kaio_wins['rikishi1_rank'])

#for rr in sumo_cleaned.rikishi1_rank:
#     if rr in ranking_dict:
#         rr.str.replace(rr, ranking_dict[rr], inplace=True)
#         print(rr, ranking_dict[rr])

sumo_cleaned.replace('J13', 35, inplace=True)
sumo_cleaned
# Out:
#           basho day  rikishi1_id  rikishi1_rank rikishi1_shikona  \
# 0       1983.01   1         4140             35      Chikubayama
# 1       1983.01   1         4306             37            Ofuji
# 2       1983.01   1         1337             34     Tochitsukasa
# 3       1983.01   1         4323             35         Shiraiwa
# 4       1983.01   1         4097             34       Tamakiyama
# ...         ...  ..          ...            ...              ...
# 227767  2023.07  15        11985              3         Daieisho
# 227768  2023.07  15        12451              3         Hoshoryu
# 227769  2023.07  15        12796             21          Hakuoho
# 227770  2023.07  15        12094              4              Abi
# 227771  2023.07  15        12231              2        Kirishima
#
#        rikishi1_result  rikishi1_win    kimarite  rikishi2_id rikishi2_rank  \
# 0            0-1 (7-8)             0    yorikiri         4306          Ms1e
# 1            1-0 (6-1)             1    yorikiri         4140          J13w
# 2            1-0 (9-6)             1   oshidashi         4323          J13e
# 3           0-1 (3-12)             0   oshidashi         1337          J12w
# 4            0-1 (8-7)             0    yorikiri         4319          J11w
# ...                ...           ...         ...          ...           ...
# 227767             9-6             0  hikiotoshi        11855           M9e
# 227768            12-3             1   uwatenage        12796          M17w
# 227769            11-4             0   uwatenage        12451           S1e
# 227770             6-9             1    yorikiri        12231           O1w
# 227771           6-7-2             0    yorikiri        12094           K1w
#
#        rikishi2_shikona rikishi2_result rikishi2_win
# 0                 Ofuji       1-0 (6-1)            1
# 1           Chikubayama       0-1 (7-8)            0
# 2              Shiraiwa      0-1 (3-12)            0
# 3          Tochitsukasa       1-0 (9-6)            1
# 4            Harunafuji      1-0 (5-10)            1
# ...                 ...             ...          ...
# 227767        Takanosho             8-7            1
# 227768          Hakuoho            11-4            0
# 227769         Hoshoryu            12-3            1
# 227770        Kirishima           6-7-2            0
# 227771              Abi             6-9            1
#
# [227772 rows x 13 columns]

# %%
import matplotlib
sumo.plot()
# Out:
# <Axes: >
