# %%
import pandas as pd

sumo = pd.read_csv("data/results.csv", dtype={'basho': 'string', 'day': 'string', 'rikishi1_id': 'int64', 'rikishi1_rank': 'string', 'rikishi1_shikona': 'string', 'rikishi1_result': 'string', 'rikishi1_win': 'int64', 'kimarite': 'string', 'rikishi2_id': 'int64', 'rikishi2_rank': 'string', 'rikishi2_shikona': 'string', 'rikishi2_result': 'string', 'rikishi2_win': 'string'})

# %%
#print(results.loc[5, 'rikishi1_shikona'])
sumo
# Out:
#           basho day  rikishi1_id rikishi1_rank rikishi1_shikona  \
# 0       1983.01   1         4140          J13w      Chikubayama
# 1       1983.01   1         4306          Ms1e            Ofuji
# 2       1983.01   1         1337          J12w     Tochitsukasa
# 3       1983.01   1         4323          J13e         Shiraiwa
# 4       1983.01   1         4097          J12e       Tamakiyama
# ...         ...  ..          ...           ...              ...
# 227767  2023.07  15        11985           S1w         Daieisho
# 227768  2023.07  15        12451           S1e         Hoshoryu
# 227769  2023.07  15        12796          M17w          Hakuoho
# 227770  2023.07  15        12094           K1w              Abi
# 227771  2023.07  15        12231           O1w        Kirishima
#
#        rikishi1_result  rikishi1_win    kimarite  rikishi2_id rikishi2_rank  \
# 0            0-1 (7-8)             0    yorikiri         4306          Ms1e
# ...

# %%
sumo.sort_values(by='rikishi1_id')
# Out:
#           basho day  rikishi1_id rikishi1_rank rikishi1_shikona  \
# 101238  2000.09   7            1           Y1e          Akebono
# 98016   2000.01  15            1           Y2w          Akebono
# 57810   1993.03   5            1           Y1e          Akebono
# 69412   1995.03   3            1           Y1w          Akebono
# 78780   1996.09  12            1           Y1w          Akebono
# ...         ...  ..          ...           ...              ...
# 227545  2023.07  10        12796          M17w          Hakuoho
# 227703  2023.07  14        12796          M17w          Hakuoho
# 227501  2023.07   9        12796          M17w          Hakuoho
# 227385  2023.07   6        12796          M17w          Hakuoho
# 227685  2023.07  13        12796          M17w          Hakuoho
#
#        rikishi1_result  rikishi1_win     kimarite  rikishi2_id rikishi2_rank  \
# 101238      6-1 (13-2)             1     yorikiri           29           M1w
# ...

# %%
rikishi_id_list = []
for i in sumo["rikishi1_id"].unique():
    rikishi_id_list.append(i)

rikishi_id_list
# Out:
# [4140,
#  4306,
#  1337,
#  4323,
#  4097,
#  4319,
#  4109,
#  4129,
#  4111,
#  4130,
#  1302,
#  4318,
#  1361,
#  4316,
#  1385,
#  4125,
#  1347,
#  4311,
#  1332,
#  4322,
#  1380,
#  4128,
#  1350,
#  1359,
#  4087,
#  4091,
#  1342,
#  4103,
#  4122,
#  4131,
#  1348,
#  4124,
#  1334,
#  4118,
#  1345,
#  4100,
#  1352,
#  4132,
#  4050,
#  4117,
#  1378,
#  4133,
#  1338,
#  4077,
#  1375,
#  4102,
#  1369,
#  4107,
#  4099,
#  4126,
#  1374,
#  1379,
#  4078,
#  4127,
#  1363,
#  4112,
#  4094,
#  4104,
#  4095,
#  4116,
#  1353,
#  4080,
#  1354,
#  4134,
#  1381,
#  1364,
#  1417,
#  4303,
#  4119,
#  1451,
#  1317,
#  1339,
#  1356,
#  4324,
#  5070,
#  1301,
#  1496,
#  6773,
#  1373,
#  4135,
#  6780,
#  4329,
#  4136,
#  4325,
#  1362,
#  4138,
#  4328,
#  4137,
#  1423,
#  4139,
#  1376,
#  1358,
#  1383,
#  1377,
#  28,
#  4327,
#  1287,
#  4312,
#  1372,
#  1292,
#  4326,
#  1430,
#  1653,
#  1311,
#  4330,
#  5064,
#  33,
#  4334,
#  4315,
#  5063,
#  49,
# ...

# %%
#There are two lines for each match, one for the winner and one for the loser.
#So as not to show duplicates of every match, we'll just show the winners with sumo_only_wins
sumo_only_wins = sumo[sumo.rikishi1_win == int("1")] #could also use sumo.loc[sumo.rikishi1_win == 1]

sumo_only_wins[['rikishi1_id', 'kimarite']]
#sumo_only_wins
# Out:
#         rikishi1_id    kimarite
# 1              4306    yorikiri
# 2              1337   oshidashi
# 5              4319    yorikiri
# 7              4129  tsukidashi
# 9              4130  hatakikomi
# ...             ...         ...
# 227763        12270    yorikiri
# 227765        12291    yorikiri
# 227766        11855  hikiotoshi
# 227768        12451   uwatenage
# 227770        12094    yorikiri
#
# [113886 rows x 2 columns]

# %%
#Same as above, but now we'll just show the losers with sumo_only_losses
sumo_only_losses = sumo[sumo.rikishi1_win == int("0")]

sumo_only_losses[['rikishi1_id', 'kimarite']]
# Out:
#         rikishi1_id    kimarite
# 0              4140    yorikiri
# 3              4323   oshidashi
# 4              4097    yorikiri
# 6              4109  tsukidashi
# 8              4111  hatakikomi
# ...             ...         ...
# 227762         6594    yorikiri
# 227764        11980    yorikiri
# 227767        11985  hikiotoshi
# 227769        12796   uwatenage
# 227771        12231    yorikiri
#
# [113886 rows x 2 columns]

# %%
#kaio_wins = sumo_only_wins.loc[sumo.rikishi1_shikona == 'Kaio']
#len(kaio_wins)

win_count = {}

for r in rikishi_list:
    #print(r, len(sumo_only_wins.loc[sumo.rikishi1_shikona == r]))
    win_count[r] = len(sumo_only_wins.loc[sumo.rikishi1_id == r])
    

wins_df= pd.DataFrame.from_dict(win_count, orient="index")
# df.sort_values(by=['Country'])
# wins_df.sort_values(by=win_count)
wins_df
# Out:
#          0
# 4140   181
# 4306    25
# 1337   414
# 4323    37
# 4097    20
# ...    ...
# 12688   11
# 12796   11
# 12516    1
# 12013    0
# 11976    1
#
# [597 rows x 1 columns]

# %%
sorted_win_count = sorted(win_count.items(), key=lambda x:x[1], reverse=True)
sorted_win_count

sorted_win_count_df = pd.DataFrame.from_dict(sorted_win_count)
sorted_win_count_df.columns = ['id', 'wins']
sorted_win_count_df.head()
# Out:
#      id  wins
# 0  1123  1121
# 1     7   956
# 2    89   831
# 3    41   827
# 4    39   781

# %%
##Same thing but for losses
loss_count = {}

for r in rikishi_list:
    loss_count[r] = len(sumo_only_losses.loc[sumo.rikishi1_id == r])
    

sorted_loss_count = sorted(loss_count.items(), key=lambda x:x[1], reverse=True)
sorted_loss_count

sorted_loss_count_df = pd.DataFrame.from_dict(sorted_loss_count)
sorted_loss_count_df.columns = ['id', 'losses']
sorted_loss_count_df.head()
# Out:
#      id  losses
# 0    41     888
# 1    89     869
# 2    33     855
# 3  1284     744
# 4    13     731

# %%
won_loss_df = pd.merge(sorted_win_count_df, sorted_loss_count_df)
won_loss_df
# Out:
#         id  wins  losses
# 0     1123  1121     212
# 1        7   956     642
# 2       89   831     869
# 3       41   827     888
# 4       39   781     692
# ..     ...   ...     ...
# 592  11965     0       1
# 593  12141     0       1
# 594  12369     0       1
# 595  11949     0       2
# 596  12013     0       1
#
# [597 rows x 3 columns]

# %%
wp = int(won_loss_df[won_loss_df.id == 14].wins) / int((won_loss_df[won_loss_df.id == 14].wins) + int(won_loss_df[won_loss_df.id == 14].losses))
p = 59.3
wp = round(wp, 2)
# wp = int(wp)
print(f"14 had a winning percentage of {wp}%.")

# sumo_only_wins = sumo[sumo.rikishi1_win == int("1")]
# Out:
# Ama/Harumafuji had a winning percentage of 0.49%.
# C:\Users\Platypus\AppData\Local\Temp\ipykernel_13968\1601735744.py:1: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   wp = int(won_loss_df[won_loss_df.id == 14].wins) / int((won_loss_df[won_loss_df.id == 14].wins) + int(won_loss_df[won_loss_df.id == 14].losses))
# C:\Users\Platypus\AppData\Local\Temp\ipykernel_13968\1601735744.py:1: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   wp = int(won_loss_df[won_loss_df.id == 14].wins) / int((won_loss_df[won_loss_df.id == 14].wins) + int(won_loss_df[won_loss_df.id == 14].losses))

# %%
#ww.columns['Rikishi', 'Total Wins']
wins_df.columns = ['wins']
#wins_df.rename_axis('Rikishi').rename_axis('Rikishi2', axis=1)
#wins_df.columns.name = 'Rikishi'
wins_df.sort_values(by='wins', ascending=False)

with_500_wins = wins_df.loc[wins_df.wins >=500].sort_values(by='wins', ascending=False)

with_500_wins
# Out:
#        wins
# 1123   1121
# 7       956
# 89      831
# 41      827
# 39      781
# 1226    760
# 1111    752
# 2       751
# 1235    742
# 33      740
# 4       733
# 13      713
# 8       703
# 9       694
# 1287    690
# 1219    689
# 5       688
# 5944    685
# 1284    678
# 28      675
# 6468    645
# 10      644
# 842     641
# 14      638
# 878     622
# 1009    616
# 6599    610
# 5967    605
# 18      604
# 6473    604
# 1       604
# 37      596
# 31      582
# 1227    582
# 30      575
# 1292    573
# 17      571
# 6463    566
# 6480    561
# 12      559
# 1301    558
# 11728   550
# 876     549
# 23      548
# 51      542
# 1354    541
# 6       540
# 40      540
# 63      531
# 49      530
# 11784   527
# 11786   527
# 875     526
# 1302    523
# 34      522
# 3       521
# 19      518
# 60      515
# 152     514
# 2818    504

# %%
#What is the highest rank each rikishi on the list achieved?
#The information in rikishi1_rank includes a designation of "e" or "w" ("east" or "west" on the banzuke), but as that is immaterial to ranking, we can strip it out.
#A simple excision of the final character doesn't work, so I can't do the following: sumo.rikishi1_rank.str[:-1]
#See, some rankings appear on the spreadsheet with an "HD" at the end, so I have to work with a list of characters to remove in order to clean this out.

char_to_remove = ['e', 'w', 'HD']
cleaned_rankings = sumo['rikishi1_rank']
for character in char_to_remove:
    cleaned_rankings = cleaned_rankings.str.replace(character, '')
#print(cleaned_rankings)


#But this ranking only shows a rikishi's rank for each match. That rank stays the same throughout any given tournament, but can be adjusted for the next tournament.
#So we want to see what the highest rank achieved by each rikishi.
#Starting at the top, the ranks are Y (Yokozuna), O (Ozeki), S (Sekiwake), K (Komusubi). These are the san'yaku ranks, the highest set of rankings.
#Then comes M (Maegashira, the best being M1 then increasing in number), then J (Juryo, J1, then increasing), Ms (Makushita, Ms1, then increasing).
#For the top san'yaku ranks, we see things like Y1 and Y2 on the banzuke, but that is just for matching purposes. The numberings only matter at lower levels,
#which is why the following value assignment gives equal values to each Y/O/S/K rank but differing values for the lower ranks.
ranking_dict = {'Y1': '1', 'Y2': '1', 'Y1YO': '1', 'Y2YO': '1', 'O1': '2', 'O2': '2', 'O3': '2', 'S1': '3', 'S2': '3', 'K1': '4', 'K2': '4', 'K3': '4', 'K4': '4', 'M1': '5', 'M2': '6', 'M3': '7', 'M4': '8', 'M5': '9', 'M6': '10', 'M7': '11',
                'M8': '12', 'M9': '13', 'M10': '14', 'M11': '15', 'M12': '16', 'M13': '17', 'M14': '18', 'M15': '19', 'M16': '20', 'M17': '21', 'M18': '22', 'J1': '23', 'J2': '24', 'J3': '25',
                'J4': '26', 'J5': '27', 'J6': '28', 'J7': '29', 'J8': '30', 'J9': '31', 'J10': '32', 'J11': '33', 'J12': '34', 'J13': '35', 'J14': '36', 'Ms1': '37', 'Ms2': '38', 'Ms3': '39',
                'Ms4': '40', 'Ms5': '41', 'Ms6': '42', 'Ms7': '43', 'Ms8': '44', 'Ms9': '45', 'Ms10': '46', 'Ms11': '47', 'Ms12': '48', 'Ms13': '49', 'Ms14': '50'}
#The following is a test to make sure no rankings are excluded from this cleanup set. If test = [] after this, we're good to go.
test = []
for i in sumo["rikishi1_rank"].unique():
    if (i in ranking_dict):
        test
    else:
        test.append(i)

test
# best_rank = {}
# Out:
# ['J13w',
#  'Ms1e',
#  'J12w',
#  'J13e',
#  'J12e',
#  'J11w',
#  'J10w',
#  'J11e',
#  'J10e',
#  'J9w',
#  'J9e',
#  'J8w',
#  'J8e',
#  'J7w',
#  'J6w',
#  'J7e',
#  'J6e',
#  'J5w',
#  'J4w',
#  'J5e',
#  'J3w',
#  'J4e',
#  'J2w',
#  'J3e',
#  'J2e',
#  'J1w',
#  'J1e',
#  'M14w',
#  'M14e',
#  'M13w',
#  'M13e',
#  'M12w',
#  'M11w',
#  'M12e',
#  'M11e',
#  'M10w',
#  'M9w',
#  'M10e',
#  'M9e',
#  'M8w',
#  'M8e',
#  'M7w',
#  'M7e',
#  'M6w',
#  'M6e',
#  'M4w',
#  'M3e',
#  'M4e',
#  'M2e',
#  'M2w',
#  'M1w',
#  'S1w',
#  'M1e',
#  'O2wHD',
#  'S1e',
#  'O1w',
#  'M5w',
#  'O1e',
#  'Y2eHD',
#  'K1e',
#  'M5e',
#  'Y1w',
#  'Y1e',
#  'K1w',
#  'Ms1w',
#  'Ms2e',
#  'Ms3e',
#  'Ms3wHD',
#  'Ms3w',
#  'Ms4w',
#  'Ms2w',
#  'M3w',
#  'O2eHD',
#  'Ms4e',
#  'Ms5e',
#  'Ms6w',
#  'Ms5w',
#  'Ms7w',
#  'Ms6e',
#  'Ms8e',
#  'Ms10w',
#  'Ms7e',
#  'M9eHD',
#  'O3eHD',
#  'Ms14e',
#  'Ms9w',
#  'Ms8w',
#  'S2eHD',
#  'Ms9e',
#  'O3wHD',
#  'Y2wHD',
#  'M15w',
#  'M15e',
# ...

# %%
sumo_cleaned = sumo
sumo_cleaned.rikishi1_rank = cleaned_rankings
sumo_cleaned
# Out:
#           basho day  rikishi1_id rikishi1_rank rikishi1_shikona  \
# 0       1983.01   1         4140           J13      Chikubayama
# 1       1983.01   1         4306           Ms1            Ofuji
# 2       1983.01   1         1337           J12     Tochitsukasa
# 3       1983.01   1         4323           J13         Shiraiwa
# 4       1983.01   1         4097           J12       Tamakiyama
# ...         ...  ..          ...           ...              ...
# 227767  2023.07  15        11985            S1         Daieisho
# 227768  2023.07  15        12451            S1         Hoshoryu
# 227769  2023.07  15        12796           M17          Hakuoho
# 227770  2023.07  15        12094            K1              Abi
# 227771  2023.07  15        12231            O1        Kirishima
#
#        rikishi1_result  rikishi1_win    kimarite  rikishi2_id rikishi2_rank  \
# 0            0-1 (7-8)             0    yorikiri         4306          Ms1e
# ...

# %%
# test = []

# for i in range(len(sumo)):
#    bmi = i
#    test.append(bmi)
# test

# for i in sumo["rikishi1_rank"]:
#     for i in ranking_dict.keys():
#         test.append(i)

sumo.replace({"rikishi1_rank": ranking_dict})

sumo
# Out:
#           basho day  rikishi1_id rikishi1_rank rikishi1_shikona  \
# 0       1983.01   1         4140           J13      Chikubayama
# 1       1983.01   1         4306           Ms1            Ofuji
# 2       1983.01   1         1337           J12     Tochitsukasa
# 3       1983.01   1         4323           J13         Shiraiwa
# 4       1983.01   1         4097           J12       Tamakiyama
# ...         ...  ..          ...           ...              ...
# 227767  2023.07  15        11985            S1         Daieisho
# 227768  2023.07  15        12451            S1         Hoshoryu
# 227769  2023.07  15        12796           M17          Hakuoho
# 227770  2023.07  15        12094            K1              Abi
# 227771  2023.07  15        12231            O1        Kirishima
#
#        rikishi1_result  rikishi1_win    kimarite  rikishi2_id rikishi2_rank  \
# 0            0-1 (7-8)             0    yorikiri         4306          Ms1e
# ...

# %%
kaio_wins = sumo_cleaned.loc[sumo_cleaned.rikishi1_shikona == 'Kaio']
kaio_wins['rikishi1_rank']
kaio_best = ""
#for k in kaio_wins:
    #if kaio_wins['rikishi1_rank']
    #print(k, kaio_wins['rikishi1_rank'])

#for rr in sumo_cleaned.rikishi1_rank:
#     if rr in ranking_dict:
#         rr.str.replace(rr, ranking_dict[rr], inplace=True)
#         print(rr, ranking_dict[rr])

sumo_cleaned.replace('J13', '35', inplace=True)
sumo_cleaned
# Out:
#           basho day  rikishi1_id rikishi1_rank rikishi1_shikona  \
# 0       1983.01   1         4140            35      Chikubayama
# 1       1983.01   1         4306           Ms1            Ofuji
# 2       1983.01   1         1337           J12     Tochitsukasa
# 3       1983.01   1         4323            35         Shiraiwa
# 4       1983.01   1         4097           J12       Tamakiyama
# ...         ...  ..          ...           ...              ...
# 227767  2023.07  15        11985            S1         Daieisho
# 227768  2023.07  15        12451            S1         Hoshoryu
# 227769  2023.07  15        12796           M17          Hakuoho
# 227770  2023.07  15        12094            K1              Abi
# 227771  2023.07  15        12231            O1        Kirishima
#
#        rikishi1_result  rikishi1_win    kimarite  rikishi2_id rikishi2_rank  \
# 0            0-1 (7-8)             0    yorikiri         4306          Ms1e
# ...

# %%
import matplotlib
sumo.plot()
# Out:
# <Axes: >

# %%
# rikishi_id_list = []
# rikishi_id_dict = {}

# for i in sumo["rikishi1_id"].unique():
#     rikishi_id_list.append(sumo["rikishi1_shikona"][0])
#     rikishi_id_dict.update({i: sumo["rikishi1_shikona"][i]})
#     if (i ==)

# rikishi_id_dict

# %%
rikishi_id_dict = {}

# Initializes a key for every number sumo["rikishi1_id"] but still only adds one shikona as a value per key, overwriting old shikona.
for i in range(len(sumo)):
     rikishi_id_dict.update({sumo["rikishi1_id"][i]: [sumo["rikishi1_shikona"][i]]})

# for i in rikishi_id_dict:
#     rikishi_id_dict[i].extend(['test'])

# Works, but adds redundant names instead of just unique ones.
# for index, row in sumo.iterrows():
#     rikishi_id_dict[row["rikishi1_id"]].append(row["rikishi1_shikona"])

# This one works perfectly. Easy to test on id 1111, which adds both Ama and harumafuji, two names for the same rikishi.
for index, row in sumo.iterrows():
    if row["rikishi1_shikona"] not in rikishi_id_dict[row["rikishi1_id"]]:
        rikishi_id_dict[row["rikishi1_id"]].append(row["rikishi1_shikona"])

rikishi_id_dict
# Out:
# {4140: ['Chikubayama'],
#  4306: ['Ofuji'],
#  1337: ['Tochitsukasa'],
#  4323: ['Shiraiwa'],
#  4097: ['Tamakiyama'],
#  4319: ['Harunafuji'],
#  4109: ['Kotogatake'],
#  4129: ['Hakuryuyama'],
#  4111: ['Zaonishiki'],
#  4130: ['Hachiya'],
#  1302: ['Takamisugi'],
#  4318: ['Tengoyama'],
#  1361: ['Daitetsu'],
#  4316: ['Kakureizan'],
#  1385: ['Tochiakagi'],
#  4125: ['Shinko'],
#  1347: ['Itai'],
#  4311: ['Hakuryu'],
#  1332: ['Sakahoko'],
#  4322: ['Sanofuji'],
#  1380: ['Hidanohana'],
#  4128: ['Kotochitose'],
#  1350: ['Onokuni'],
#  1359: ['Koboyama'],
#  4087: ['Wakajishi'],
#  4091: ['Washuyama'],
#  1342: ['Asahifuji'],
#  4103: ['Banryuyama'],
#  4122: ['Kurosegawa'],
#  4131: ['Tochitsurugi'],
#  1348: ['Jingaku'],
#  4124: ['Shishiho'],
#  1334: ['Wakasegawa'],
#  4118: ['Amanoyama'],
#  1345: ['Tamaryu'],
#  4100: ['Kaneshiro', 'Tochihikari'],
#  1352: ['Tagaryu'],
#  4132: ['Wakanofuji'],
#  4050: ['Takamiyama'],
#  4117: ['Misugiiso', 'Azumanada'],
# ...

# %% [markdown]
# <!-- TO DO: re-do all those win/loss things, but with ID instead of Shikona -->

# %%
# wp = int(won_loss_df[won_loss_df.id == 14].wins) / int(
#     (won_loss_df[won_loss_df.id == 14].wins)
#     + int(won_loss_df[won_loss_df.id == 14].losses)
# )
# p = 59.3
# wp = round(wp, 2)
# # wp = int(wp)
# print(f"14 had a winning percentage of {wp}%.")


for key, value in rikishi_id_dict.items():
    wp = round(
        int(won_loss_df[won_loss_df.id == 14].wins)
        / int(
            (won_loss_df[won_loss_df.id == 14].wins)
            + int(won_loss_df[won_loss_df.id == 14].losses),
        ),
        2,
    )
    print(f"{value[0]} had a winning percentage of {wp}%.")
# sumo_only_wins = sumo[sumo.rikishi1_win == int("1")]
# Out:
# C:\Users\Platypus\AppData\Local\Temp\ipykernel_13968\4200980105.py:13: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   int(won_loss_df[won_loss_df.id == 14].wins)
# C:\Users\Platypus\AppData\Local\Temp\ipykernel_13968\4200980105.py:16: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   + int(won_loss_df[won_loss_df.id == 14].losses),
# C:\Users\Platypus\AppData\Local\Temp\ipykernel_13968\4200980105.py:14: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   / int(
# C:\Users\Platypus\AppData\Local\Temp\ipykernel_13968\4200980105.py:13: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
# ...
