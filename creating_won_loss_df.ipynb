# %%
import pandas as pd

# This results.csv file to be cleaned and analyzed here was compiled by Mikhail Zhilkin and is hosted at https://data.world/cervus/sumo-japan
results = pd.read_csv("data/results.csv", dtype={'basho': 'string', 'day': 'string', 'rikishi1_id': 'int64', 'rikishi1_rank': 'string', 'rikishi1_shikona': 'string', 'rikishi1_result': 'string', 'rikishi1_win': 'int64', 'kimarite': 'string', 'rikishi2_id': 'int64', 'rikishi2_rank': 'string', 'rikishi2_shikona': 'string', 'rikishi2_result': 'string', 'rikishi2_win': 'string'})

# %%
results
# Out:
#           basho day  rikishi1_id rikishi1_rank rikishi1_shikona  \
# 0       1983.01   1         4140          J13w      Chikubayama
# 1       1983.01   1         4306          Ms1e            Ofuji
# 2       1983.01   1         1337          J12w     Tochitsukasa
# 3       1983.01   1         4323          J13e         Shiraiwa
# 4       1983.01   1         4097          J12e       Tamakiyama
# ...         ...  ..          ...           ...              ...
# 227767  2023.07  15        11985           S1w         Daieisho
# 227768  2023.07  15        12451           S1e         Hoshoryu
# 227769  2023.07  15        12796          M17w          Hakuoho
# 227770  2023.07  15        12094           K1w              Abi
# 227771  2023.07  15        12231           O1w        Kirishima
#
#        rikishi1_result  rikishi1_win    kimarite  rikishi2_id rikishi2_rank  \
# 0            0-1 (7-8)             0    yorikiri         4306          Ms1e
# 1            1-0 (6-1)             1    yorikiri         4140          J13w
# 2            1-0 (9-6)             1   oshidashi         4323          J13e
# 3           0-1 (3-12)             0   oshidashi         1337          J12w
# 4            0-1 (8-7)             0    yorikiri         4319          J11w
# ...                ...           ...         ...          ...           ...
# 227767             9-6             0  hikiotoshi        11855           M9e
# 227768            12-3             1   uwatenage        12796          M17w
# 227769            11-4             0   uwatenage        12451           S1e
# 227770             6-9             1    yorikiri        12231           O1w
# 227771           6-7-2             0    yorikiri        12094           K1w
#
#        rikishi2_shikona rikishi2_result rikishi2_win
# 0                 Ofuji       1-0 (6-1)            1
# 1           Chikubayama       0-1 (7-8)            0
# 2              Shiraiwa      0-1 (3-12)            0
# 3          Tochitsukasa       1-0 (9-6)            1
# 4            Harunafuji      1-0 (5-10)            1
# ...                 ...             ...          ...
# 227767        Takanosho             8-7            1
# 227768          Hakuoho            11-4            0
# 227769         Hoshoryu            12-3            1
# 227770        Kirishima           6-7-2            0
# 227771              Abi             6-9            1
#
# [227772 rows x 13 columns]

# %%
# Sumo wrestlers in these datasets can best be identified by their unique ID numbers. Although each wrestler has his own name (shikona), some wrestlers
# may reuse the same name, and other wrestlers may change names during their career. Since the ID number is the one identifier that remains stable,
# this is the best identifier to which I will anchor my analysis. Here I make a quick list of unique ID numbers for later use.

rikishi_id_list = []

for i in results["rikishi1_id"].unique():

    rikishi_id_list.append(i)

# Next to make a dictionary that holds each wrestler's unique ID number as a key, with values being each name associated with that wrestler.
# The vast majority of ID numbers will only feature one name, but this will make sure to include any additional names as well.

rikishi_id_dict = {}

# Initializes a key for every number sumo["rikishi1_id"] but still only adds one shikona (wrestler name) as a value per key, overwriting old shikona.
# So while this fills out the dictionary, it remains incomplete.
for i in range(len(results)):
    rikishi_id_dict.update({results["rikishi1_id"][i]: [results["rikishi1_shikona"][i]]})


# This fills out the dictionary with all associated names.
# Easy to test on rikishi_id_dict[1111], which shows both names for this wrestler, "Ama" and "Harumafuji."
# The first entry in every names list is the *most recent* name the wrestler used. So rikishi_id_dict[1111][0] shows "Harumafuji."
# This is useful to know, because when referring to a wrestler in the present day, one generally refers to them by their most current name.
# So when we reference this dictionary to indicate a wrestler's name, we will go by their most recent name, even if they have used others in the past.
for index, row in results.iterrows():
    if row["rikishi1_shikona"] not in rikishi_id_dict[row["rikishi1_id"]]:
        rikishi_id_dict[row["rikishi1_id"]].append(row["rikishi1_shikona"])

rikishi_id_dict
# Out:
# {4140: ['Chikubayama'],
#  4306: ['Ofuji'],
#  1337: ['Tochitsukasa'],
#  4323: ['Shiraiwa'],
#  4097: ['Tamakiyama'],
#  4319: ['Harunafuji'],
#  4109: ['Kotogatake'],
#  4129: ['Hakuryuyama'],
#  4111: ['Zaonishiki'],
#  4130: ['Hachiya'],
#  1302: ['Takamisugi'],
#  4318: ['Tengoyama'],
#  1361: ['Daitetsu'],
#  4316: ['Kakureizan'],
#  1385: ['Tochiakagi'],
#  4125: ['Shinko'],
#  1347: ['Itai'],
#  4311: ['Hakuryu'],
#  1332: ['Sakahoko'],
#  4322: ['Sanofuji'],
#  1380: ['Hidanohana'],
#  4128: ['Kotochitose'],
#  1350: ['Onokuni'],
#  1359: ['Koboyama'],
#  4087: ['Wakajishi'],
#  4091: ['Washuyama'],
#  1342: ['Asahifuji'],
#  4103: ['Banryuyama'],
#  4122: ['Kurosegawa'],
#  4131: ['Tochitsurugi'],
#  1348: ['Jingaku'],
#  4124: ['Shishiho'],
#  1334: ['Wakasegawa'],
#  4118: ['Amanoyama'],
#  1345: ['Tamaryu'],
#  4100: ['Kaneshiro', 'Tochihikari'],
#  1352: ['Tagaryu'],
#  4132: ['Wakanofuji'],
#  4050: ['Takamiyama'],
#  4117: ['Misugiiso', 'Azumanada'],
#  1378: ['Hoo'],
#  4133: ['Takarakuni', 'Saisu'],
#  1338: ['Ozutsu'],
#  4077: ['Fujizakura'],
#  1375: ['Masudayama'],
#  4102: ['Aobajo'],
#  1369: ['Toryu'],
#  4107: ['Kaiki'],
#  4099: ['Kirinji'],
#  4126: ['Sadanoumi'],
#  1374: ['Kurama'],
#  1379: ['Asashio'],
#  4078: ['Oshio'],
#  4127: ['Wakashimazu'],
#  1363: ['Hokutenyu'],
#  4112: ['Kotokaze'],
#  4094: ['Onishiki'],
#  4104: ['Takanosato'],
#  4095: ['Wakanohana'],
#  4116: ['Dewanohana'],
#  1353: ['Daijuyama'],
#  4080: ['Kitanoumi'],
#  1354: ['Chiyonofuji'],
#  4134: ['Oyutaka'],
#  1381: ['Dewanoshima'],
#  1364: ['Masurao', 'Tejima'],
#  1417: ['Ichinowatari'],
#  4303: ['Suiryu'],
#  4119: ['Kotowaka'],
#  1451: ['Tochiizumi'],
#  1317: ['Hananokuni'],
#  1339: ['Hokutoumi', 'Hoshi'],
#  1356: ['Kinoarashi'],
#  4324: ['Genkaiho', 'Rinho'],
#  5070: ['Arai'],
#  1301: ['Kirishima'],
#  1496: ['Seionada'],
#  6773: ['Taigiyama'],
#  1373: ['Fukunosato'],
#  4135: ['Oko'],
#  6780: ['Tochiomi'],
#  4329: ['Fujinosato'],
#  4136: ['Futahaguro', 'Kitao'],
#  4325: ['Kiyomidake'],
#  1362: ['Onohana'],
#  4138: ['Tochimatoi'],
#  4328: ['Hanaarashi'],
#  4137: ['Fujinokawa', 'Hattori'],
#  1423: ['Wakanoumi', 'Hanaguruma', 'Hanaogi'],
#  4139: ['Koryu'],
#  1376: ['Hananoumi'],
#  1358: ['Hoshiiwato', 'Hoshikabuto'],
#  1383: ['Sekinohana'],
#  1377: ['Iwatefuji', 'Futasekaze'],
#  28: ['Mitoizumi'],
#  4327: ['Hiyama'],
#  1287: ['Konishiki'],
#  4312: ['Kotonoryu'],
#  1372: ['Maenoshin'],
#  1292: ['Kotogaume'],
#  4326: ['Hanaryu', 'Shushi'],
#  1430: ['Minenofuji'],
#  1653: ['Asahizakura'],
#  1311: ['Kototsubaki'],
#  4330: ['Wakatsukuba'],
#  5064: ['Byakuhoyama'],
#  33: ['Terao', 'Genjiyama'],
#  4334: ['Takuetsuyama'],
#  4315: ['Arashifuji', 'Fujinoiwa'],
#  5063: ['Suiseizan'],
#  49: ['Misugisato'],
#  6775: ['Hakusan'],
#  4321: ['Kaio'],
#  1333: ['Sasshunada'],
#  1470: ['Tenkoyama'],
#  4331: ['Iyozakura', 'Ichiki'],
#  1367: ['Fujinoshin', 'Fujihikari'],
#  4333: ['Tachinofuji', 'Tatsufuji'],
#  4991: ['Shishuyama'],
#  1335: ['Takanofuji'],
#  4332: ['Tochinohana'],
#  1476: ['Otaka'],
#  1390: ['Kondo', 'Toshoho'],
#  1310: ['Kirinishiki'],
#  1397: ['Ishinriki'],
#  37: ['Kotoinazuma'],
#  1303: ['Kotofuji', 'Kotoosugi'],
#  4335: ['Ojishi'],
#  1366: ['Takanomine'],
#  1365: ['Hananofuji'],
#  1315: ['Enazakura'],
#  23: ['Tochinowaka', 'Kaseda'],
#  1330: ['Ryogoku', 'Kobayashiyama'],
#  4336: ['Tamakirin', 'Taue'],
#  30: ['Kitakachidoki', 'Kuga'],
#  1331: ['Saganobori'],
#  1370: ['Morinosato', 'Takamichi'],
#  4988: ['Naruyama'],
#  1313: ['Komafudo', 'Hananowaka'],
#  1295: ['Kyokudozan'],
#  1442: ['Yuho'],
#  60: ['Toyonoumi', 'Takanohama'],
#  1489: ['Maenoarashi'],
#  1357: ['Yamanishiki', 'Yamazaki'],
#  1360: ['Oishida'],
#  4141: ['Nankairyu'],
#  1329: ['Daigaku'],
#  1425: ['Tobimaru'],
#  1349: ['Kotohakusan'],
#  5123: ['Amamifuji'],
#  9: ['Akinoshima'],
#  12: ['Kotonishiki', 'Kotomatsuzawa'],
#  1433: ['Kitafubuki'],
#  1355: ['Goken', 'Morita'],
#  1512: ['Fukuryudake'],
#  1296: ['Kasugafuji'],
#  1299: ['Kiraiho'],
#  51: ['Daizen'],
#  1297: ['Dairyu'],
#  1463: ['Maemiyama'],
#  1326: ['Tsunenoyama', 'Nishinoryu'],
#  1368: ['Ryukozan', 'Miyata'],
#  4337: ['Kiyononada'],
#  1520: ['Hidenohana'],
#  1321: ['Dewanokuni'],
#  1288: ['Kotobeppu'],
#  1418: ['Koganefuji'],
#  1319: ['Tachihikari'],
#  1314: ['Owakamatsu'],
#  55: ['Zenshinyama'],
#  48: ['Oginohana'],
#  1305: ['Kyokugozan'],
#  44: ['Kushimaumi', 'Kushima'],
#  5051: ['Kyokueiko'],
#  1290: ['Wakashoyo', 'Shidenryu', 'Babaguchi'],
#  1285: ['Asahisato'],
#  1327: ['Yoshinobori'],
#  1382: ['Takamishu'],
#  18: ['Takatoriki', 'Kamakari'],
#  1371: ['Ryujuyama'],
#  1309: ['Tamakairiki'],
#  1384: ['Takamio'],
#  1386: ['Fuchita'],
#  3: ['Wakanohana', 'Wakahanada'],
#  2: ['Takanohana', 'Takahanada'],
#  1387: ['Suginohana'],
#  82: ['Tochitenko'],
#  16: ['Minatofuji'],
#  1: ['Akebono'],
#  1323: ['Kumao'],
#  77: ['Yutakafuji', 'Osuzuki'],
#  1307: ['Daishoyama'],
#  157: ['Tomoefuji'],
#  14: ['Kotonowaka'],
#  1351: ['Ryugahama'],
#  53: ['Tokitsunada'],
#  1294: ['Naminohana'],
#  45: ['Daishoho', 'Murata'],
#  1324: ['Terunoumi', 'Hayashi', 'Daikiko'],
#  160: ['Tatsuhikari'],
#  42: ['Mainoumi', 'Nagao'],
#  5: ['Takanonami', 'Namioka'],
#  1286: ['Kenko'],
#  1341: ['Seifuriki', 'Seifu'],
#  62: ['Daishi'],
#  1306: ['Hitachiryu'],
#  4: ['Musashimaru'],
#  1336: ['Takanonada', 'Nakajima'],
#  1388: ['Tochisagami'],
#  87: ['Wakanoyama'],
#  15: ['Oginishiki'],
#  1344: ['Akinomine'],
#  1346: ['Kengaku'],
#  159: ['Kiyota'],
#  1340: ['Taishin', 'Murai'],
#  140: ['Ohidake'],
#  7: ['Kaio', 'Koga'],
#  11: ['Aogiyama', 'Teraki'],
#  24: ['Ganyu'],
#  73: ['Kanechika', 'Gassan'],
#  21: ['Asahiyutaka'],
#  133: ['Genkai'],
#  67: ['Tochinofuji'],
#  1325: ['Wakatosho'],
#  1322: ['Hidenoumi'],
#  1391: ['Mitsueyama'],
#  26: ['Higonoumi'],
#  76: ['Hoshitango'],
#  1392: ['Akinokuni'],
#  91: ['Hoshiandesu'],
#  1289: ['Rikio'],
#  209: ['Asanonami', 'Ota'],
#  34: ['Asanowaka', 'Wakaadachi'],
#  52: ['Tomonohana'],
#  1328: ['Yamanakayama'],
#  25: ['Hamanoshima', 'Hamasu'],
#  1393: ['Daishoryu'],
#  1394: ['Wakadozan'],
#  59: ['Susanoumi', 'Kanesaku', 'Masakabuto'],
#  36: ['Asanosho', 'Ozawa', 'Asasoyo'],
#  20: ['Shikishima', 'Yoshitane'],
#  1318: ['Shigenoumi'],
#  6: ['Musoyama'],
#  1395: ['Daitengo'],
#  372: ['Chokairyu'],
#  178: ['Shoeito', 'Kirinowaka'],
#  238: ['Umenosato'],
#  191: ['Kiyonofuji'],
#  144: ['Ryudo', 'Ikemori'],
#  145: ['Kobo', 'Mineyama'],
#  174: ['Mutsuhokkai'],
#  1316: ['Oyamato', 'Shirasaki'],
#  143: ['Daiden'],
#  108: ['Ominato'],
#  54: ['Ohinode'],
#  188: ['Genkainami'],
#  134: ['Fukuzono', 'Tsurunofuji'],
#  29: ['Kotoryu'],
#  177: ['Mutetsuyama', 'Kurimoto'],
#  66: ['Wakahayato'],
#  138: ['Sentoryu', 'Kaishinzan'],
#  13: ['Tosanoumi'],
#  74: ['Kotokanyu'],
#  1291: ['Sunahama'],
#  68: ['Gokenzan', 'Goto'],
#  75: ['Daihisho'],
#  17: ['Tamakasuga'],
#  57: ['Yamato'],
#  35: ['Kyokushuzan'],
#  8: ['Chiyotaikai'],
#  22: ['Gojoro'],
#  63: ['Otsukasa', 'Ouchi'],
#  27: ['Wakanojo', 'Aka'],
#  1300: ['Daiki'],
#  124: ['Sumiya', 'Saigo'],
#  1298: ['Kotoarashi'],
#  78: ['Toyozakura'],
#  79: ['Kotoiwakuni', 'Kotofujimoto'],
#  19: ['Tochiazuma', 'Shiga'],
#  1398: ['Nanfu'],
#  41: ['Kyokutenho'],
#  119: ['Takamihana'],
#  46: ['Dewaarashi'],
#  1293: ['Chiyonowaka'],
#  40: ['Kaiho', 'Kumagaya'],
#  58: ['Oikari'],
#  31: ['Dejima'],
#  10: ['Tochinonada', 'Goto'],
#  32: ['Akinoshu'],
#  121: ['Masunobori'],
#  47: ['Chiyotenzan'],
#  50: ['Tokitsuumi'],
#  38: ['Toki'],
#  39: ['Wakanosato', 'Kogawa'],
#  83: ['Arashi'],
#  64: ['Yotsukasa', 'Suzuki'],
#  61: ['Hokutohikari'],
#  43: ['Kinkaiyama'],
#  71: ['Takanowaka', 'Takaozaki'],
#  96: ['Jumonji', 'Kaigatake'],
#  56: ['Masutsuyoshi'],
#  72: ['Tochisakae', 'Okamoto', 'Tochinoiwa'],
#  65: ['Dewataira'],
#  70: ['Kitazakura'],
#  69: ['Towanoyama', 'Otakayama'],
#  86: ['Futatsukuba'],
#  842: ['Miyabiyama', 'Takeuchi'],
#  105: ['Buyuzan', 'Tominagayama'],
#  97: ['Tochinohana', 'Yachi'],
#  129: ['Hayateumi', 'Saito'],
#  116: ['Nakao', 'Wakatsutomu'],
#  167: ['Tamamitsukuni', 'Tamanokuni'],
#  101: ['Dewanofuji'],
#  81: ['Wakakosho'],
#  107: ['Kasuganishiki'],
#  149: ['Juzan'],
#  88: ['Tamarikido'],
#  152: ['Tamanoshima', 'Tamanonada'],
#  875: ['Takamisakari', 'Kato'],
#  876: ['Kotomitsuki', 'Kototamiya'],
#  89: ['Aminishiki'],
#  84: ['Tomikaze'],
#  312: ['Hokutomine'],
#  118: ['Midorifuji'],
#  205: ['Fujinohana', 'Goto'],
#  147: ['Toyonokuni', 'Minami'],
#  163: ['Senshuyama'],
#  251: ['Wakatoryu', 'Nodera'],
#  130: ['Kaido', 'Tanaka', 'Kaito'],
#  874: ['Hamanishiki', 'Takahama'],
#  878: ['Asashoryu'],
#  199: ['Kuniazuma'],
#  92: ['Harunoyama', 'Haruyama'],
#  222: ['Sumanofuji'],
#  99: ['Shunketsu', 'Komahikari', 'Ishide'],
#  785: ['Furuichi', 'Komidori'],
#  225: ['Takanotsuru', 'Sekiyama'],
#  135: ['Hokutoriki'],
#  287: ['Wakatoba', 'Yamada'],
#  80: ['Otoryu'],
#  1018: ['Shimotori', 'Shimootori'],
#  104: ['Wakaazuma'],
#  106: ['Torafusuyama'],
#  128: ['Nishikikaze'],
#  300: ['Dairaido', 'Raido'],
#  175: ['Ushiomaru'],
#  226: ['Wakatenro'],
#  126: ['Tochinoyama'],
#  168: ['Hokutoiwa'],
#  122: ['Daimanazuru'],
#  1087: ['Iwakiyama'],
#  865: ['Kasugao'],
#  784: ['Daishodai'],
#  132: ['Kotonomine'],
#  1009: ['Asasekiryu'],
#  1284: ['Takekaze', 'Narita'],
#  1187: ['Kokkai'],
#  204: ['Ryuho'],
#  264: ['Shishio'],
#  95: ['Hidenokuni'],
#  1225: ['Asahimaru', 'Asamiyoshi'],
#  113: ['Asofuji'],
#  1204: ['Kakizoe'],
#  2834: ['Futeno', 'Uchida'],
#  102: ['Asahibenten'],
#  103: ['Tochifudo'],
#  864: ['Bushuyama'],
#  2818: ['Tokitenku'],
#  334: ['Hokutojo'],
#  1111: ['Harumafuji', 'Ama'],
#  180: ['Wakainami'],
#  216: ['Raiko'],
#  1123: ['Hakuho'],
#  1421: ['Roho'],
#  315: ['Nadatsukasa'],
#  240: ['Ichinotani'],
#  1235: ['Kisenosato', 'Hagiwara'],
#  2830: ['Kotooshu'],
#  1227: ['Toyonoshima'],
#  206: ['Kotokasuga'],
#  239: ['Maikaze'],
#  1226: ['Kotoshogiku'],
#  1243: ['Katayama'],
#  296: ['Yoshiazuma'],
#  924: ['Wakakirin', 'Suzukawa'],
#  5977: ['Takamifuji'],
#  1402: ['Hakurozan'],
#  1032: ['Hochiyama'],
#  795: ['Tamaasuka'],
#  898: ['Chiyohakuho'],
#  244: ['Kaishozan'],
#  371: ['Kyokunankai'],
#  365: ['Kotokuni'],
#  90: ['Fukkoyama'],
#  136: ['Dewanosato'],
#  5988: ['Oiwato', 'Kanbayashi'],
#  2847: ['Masatsukasa'],
#  5967: ['Yoshikaze', 'Onishi'],
#  5984: ['Shirononami', 'Shiraishi'],
#  6432: ['Baruto'],
#  1109: ['Daishoma'],
#  1219: ['Kakuryu'],
#  1136: ['Mokonami'],
#  6018: ['Homasho'],
#  5985: ['Satoyama'],
#  6468: ['Goeido', 'Sawai'],
#  1031: ['Ryuo'],
#  247: ['Oga'],
#  1106: ['Koryu'],
#  6012: ['Dewaotori'],
#  1011: ['Hakuba'],
#  929: ['Kirinowaka'],
#  6010: ['Kimurayama'],
#  6643: ['Shimoda'],
#  6473: ['Tochiozan', 'Kageyama'],
#  900: ['Wakakoyu', 'Yakigaya'],
#  6467: ['Toyohibiki', 'Kadomoto'],
#  6527: ['Wakanoho'],
#  6620: ['Sakaizawa'],
#  1141: ['Shotenro', 'Musashiryu'],
#  6766: ['Kiyoseumi', 'Ichihara'],
#  1104: ['Hoshihikari'],
#  813: ['Kitataiki'],
#  6034: ['Sagatsukasa', 'Isobe'],
#  4980: ['Sokokurai'],
#  1127: ['Hokutokuni'],
#  6599: ['Tochinoshin'],
#  5944: ['Tamawashi'],
#  7115: ['Tosayutaka'],
#  1152: ['Daiyubu'],
#  6769: ['Yamamotoyama'],
#  7138: ['Daishoumi', 'Mori'],
#  6771: ['Aran'],
#  2831: ['Hoshikaze'],
#  2930: ['Tokusegawa'],
#  511: ['Yotsuguruma'],
#  662: ['Kotoyutaka'],
#  6463: ['Okinoumi', 'Fukuoka'],
#  1137: ['Sensho'],
#  1053: ['Kasugakuni'],
#  6572: ['Gagamaru'],
#  335: ['Shoketsu'],
#  6552: ['Sotairyu'],
#  7121: ['Tokushinho'],
#  2842: ['Sadanofuji'],
#  2820: ['Nakanokuni'],
#  11784: ['Myogiryu', 'Miyamoto'],
#  866: ['Surugatsukasa'],
#  6042: ['Masuraumi', 'Kurosawa'],
#  6497: ['Daido', 'Nakanishi'],
#  6614: ['Shohozan', 'Matsutani'],
#  2879: ['Sadanoumi'],
#  6753: ['Kaisei'],
#  11728: ['Takarafuji'],
#  1134: ['Tsurugidake'],
#  1215: ['Takanoyama'],
#  8900: ['Akiseyama', 'Fukao'],
#  6483: ['Maeta'],
#  6767: ['Tochinowaka'],
#  2835: ['Shironoryu'],
#  2851: ['Fujiazuma'],
#  6654: ['Masunoyama'],
#  6480: ['Takayasu'],
#  11726: ['Tokushoryu', 'Aoki'],
#  6491: ['Ikioi'],
#  1266: ['Nionoumi'],
#  11786: ['Aoiyama'],
#  6770: ['Tenkaiho', 'Minami'],
#  1241: ['Kitaharima'],
#  1054: ['Hitenryu', 'Mochimaru'],
#  1190: ['Kaonishiki'],
#  2832: ['Arawashi'],
#  2858: ['Tochitsubasa'],
#  6642: ['Chiyonokuni'],
#  1097: ['Oniarashi'],
#  7239: ['Kyokushuho'],
#  11850: ['Chiyozakura'],
#  7109: ['Chiyoarashi'],
#  9079: ['Kotoyuki'],
#  11729: ['Kimikaze', 'Naoe'],
#  6512: ['Hishofuji'],
#  6600: ['Tochihiryu'],
#  6622: ['Masakaze', 'Kitazono'],
#  11723: ['Azumaryu'],
#  6531: ['Asahisho'],
#  11934: ['Chiyotairyu', 'Meigetsuin'],
#  8904: ['Homarefuji'],
#  1405: ['Amuru'],
#  489: ['Chokozan'],
#  6928: ['Chiyootori'],
#  1058: ['Wakanoshima'],
#  6476: ['Hakiai'],
#  11971: ['Jokoryu', 'Sakumayama'],
#  8154: ['Higonojo'],
#  11724: ['Takanoiwa'],
#  8903: ['Keitenkai', 'Kei'],
#  7125: ['Tanzo', 'Terashita'],
#  6506: ['Kairyu'],
#  11989: ['Yamaguchi', 'Daikiho'],
#  9064: ['Tochiyashiki'],
#  6594: ['Ryuden'],
#  6559: ['Seiro'],
#  11840: ['Chiyonoo', 'Chiyoo'],
#  2929: ['Kagamio'],
#  6596: ['Nishikigi'],
#  7143: ['Amakaze', 'Kawanari'],
#  7240: ['Chiyomaru'],
#  9077: ['Kizenryu'],
#  940: ['Kotomisen'],
#  12055: ['Endo'],
#  11987: ['Osunaarashi'],
#  2909: ['Sakigake'],
#  11927: ['Terunofuji', 'Wakamisho'],
#  6445: ['Shoho'],
#  1052: ['Kihonoumi'],
#  9097: ['Kansei'],
#  6458: ['Yamatofuji'],
#  6646: ['Higoarashi'],
#  12107: ['Ichinojo'],
#  11985: ['Daieisho'],
#  8899: ['Kyokutaisei'],
#  12051: ['Ishiura'],
#  11764: ['Horyuyama'],
#  6013: ['Dewahayate'],
#  12026: ['Hidenoumi', 'Iwasaki'],
#  7153: ['Kotoeko'],
#  11845: ['Kagayaki', 'Tatsu'],
#  12113: ['Tsurugisho', 'Abiko'],
#  12043: ['Onosho'],
#  12094: ['Abi', 'Horikiri'],
#  12144: ['Daishomaru', 'Kawabata'],
#  12130: ['Shodai'],
#  12210: ['Mitakeumi'],
#  7156: ['Hokaho'],
#  12140: ['Takaryu'],
#  7127: ['Asabenkei'],
#  8901: ['Kisenoyama'],
#  12040: ['Daishoho'],
#  11785: ['Chiyoshoma'],
#  12226: ['Ura'],
#  11918: ['Akua'],
#  11868: ['Terutsuyoshi'],
#  11943: ['Hakuyozan'],
#  12191: ['Takakeisho', 'Sato'],
#  12239: ['Hokutofuji', 'Daiki'],
#  12024: ['Shimanoumi'],
#  12292: ['Yutakayama', 'Oyanagi'],
#  11946: ['Meisei'],
#  12273: ['Daiamami', 'Sakamoto'],
#  11947: ['Rikishin'],
#  11965: ['Tochimaru'],
#  12141: ['Shiba'],
#  12077: ['Takagenji'],
#  12291: ['Asanoyama'],
#  12203: ['Tobizaru', 'Iwasaki'],
#  11972: ['Daiseido'],
#  12425: ['Yago'],
#  11855: ['Takanosho', 'Masunosho'],
#  12320: ['Churanoumi', 'Kizaki'],
#  12406: ['Mitoryu'],
#  12285: ['Asagyokusei', 'Tamaki'],
#  12412: ['Enho'],
#  12076: ['Takanofuji', 'Takayoshitoshi'],
#  12370: ['Wakatakakage'],
#  12255: ['Chiyonoumi'],
#  12369: ['Murata'],
#  12015: ['Gokushindo'],
#  12362: ['Ichiyamamoto'],
#  12231: ['Kirishima', 'Kiribayama'],
#  12427: ['Tomokaze'],
#  7111: ['Irodori'],
#  11949: ['Kotodaigo'],
#  12367: ['Ryuko'],
#  11980: ['Wakamotoharu'],
#  11809: ['Kotokuzan'],
#  12270: ['Kotonowaka', 'Kotokamatani'],
#  12470: ['Kizakiumi'],
#  12451: ['Hoshoryu'],
#  12075: ['Kaisho'],
#  12351: ['Nishikifuji'],
#  12449: ['Kotoshoho', 'Kototebakari'],
#  12352: ['Midorifuji'],
#  12453: ['Oho'],
#  12117: ['Bushozan'],
#  12575: ['Tohakuryu'],
#  12484: ['Asanowaka'],
#  12314: ['Hiradoumi'],
#  12664: ['Atamifuji'],
#  12646: ['Hokuseiho'],
#  12717: ['Oshoma'],
#  12721: ['Kinbozan'],
#  12162: ['Shonannoumi'],
#  12688: ['Gonoyama'],
#  12796: ['Hakuoho'],
#  12516: ['Roga'],
#  12013: ['Shimazuumi'],
#  11976: ['Tamashoho']}

# %%
# Now to creates a dataframe using this dictionary, listing each wrestler's ID with any shikona (name) associated with that wrestler.
# As mentioned in the previous cell, the first value in the shikona list is the most recent name the wrestler has used,
# which is why I'm making it the default with the column "shikona," while older names are listed as "alt_shikona."
shikona_df = pd.DataFrame.from_dict([([key] + value) for key, value in rikishi_id_dict.items()])
shikona_df.rename(columns={0: "id", 1: "shikona", 2: "alt_shikona2", 3: "alt_shikona3"}, inplace=True)
shikona_df.head()
# Out:
#      id       shikona alt_shikona2 alt_shikona3
# 0  4140   Chikubayama         None         None
# 1  4306         Ofuji         None         None
# 2  1337  Tochitsukasa         None         None
# 3  4323      Shiraiwa         None         None
# 4  4097    Tamakiyama         None         None

# %%
# There are two lines for each match in the original csv file, one for the winner and one for the loser.
# So as not to show duplicates of every match, we'll just show the winners with the "sumo_only_wins" list.

sumo_only_wins = results[results.rikishi1_win == int("1")] #could also use sumo.loc[sumo.rikishi1_win == 1]
sumo_only_wins
# Out:
#           basho day  rikishi1_id rikishi1_rank rikishi1_shikona  \
# 1       1983.01   1         4306          Ms1e            Ofuji
# 2       1983.01   1         1337          J12w     Tochitsukasa
# 5       1983.01   1         4319          J11w       Harunafuji
# 7       1983.01   1         4129          J11e      Hakuryuyama
# 9       1983.01   1         4130           J9w          Hachiya
# ...         ...  ..          ...           ...              ...
# 227763  2023.07  15        12270           K1e       Kotonowaka
# 227765  2023.07  15        12291           M4e        Asanoyama
# 227766  2023.07  15        11855           M9e        Takanosho
# 227768  2023.07  15        12451           S1e         Hoshoryu
# 227770  2023.07  15        12094           K1w              Abi
#
#        rikishi1_result  rikishi1_win    kimarite  rikishi2_id rikishi2_rank  \
# 1            1-0 (6-1)             1    yorikiri         4140          J13w
# 2            1-0 (9-6)             1   oshidashi         4323          J13e
# 5           1-0 (5-10)             1    yorikiri         4097          J12e
# 7           1-0 (3-12)             1  tsukidashi         4109          J10w
# 9            1-0 (8-7)             1  hatakikomi         4111          J10e
# ...                ...           ...         ...          ...           ...
# 227763            11-4             1    yorikiri         6594          M15e
# 227765           8-4-3             1    yorikiri        11980           S2w
# 227766             8-7             1  hikiotoshi        11985           S1w
# 227768            12-3             1   uwatenage        12796          M17w
# 227770             6-9             1    yorikiri        12231           O1w
#
#        rikishi2_shikona rikishi2_result rikishi2_win
# 1           Chikubayama       0-1 (7-8)            0
# 2              Shiraiwa      0-1 (3-12)            0
# 5            Tamakiyama       0-1 (8-7)            0
# 7            Kotogatake       0-1 (7-8)            0
# 9            Zaonishiki      0-1 (4-11)            0
# ...                 ...             ...          ...
# 227763           Ryuden            10-5            0
# 227765     Wakamotoharu             9-6            0
# 227766         Daieisho             9-6            0
# 227768          Hakuoho            11-4            0
# 227770        Kirishima           6-7-2            0
#
# [113886 rows x 13 columns]

# %%
#Same as above, but now we'll just show the losers with the "sumo_only_losses" list.

sumo_only_losses = results[results.rikishi1_win == int("0")]
sumo_only_losses
# Out:
#           basho day  rikishi1_id rikishi1_rank rikishi1_shikona  \
# 0       1983.01   1         4140          J13w      Chikubayama
# 3       1983.01   1         4323          J13e         Shiraiwa
# 4       1983.01   1         4097          J12e       Tamakiyama
# 6       1983.01   1         4109          J10w       Kotogatake
# 8       1983.01   1         4111          J10e       Zaonishiki
# ...         ...  ..          ...           ...              ...
# 227762  2023.07  15         6594          M15e           Ryuden
# 227764  2023.07  15        11980           S2w     Wakamotoharu
# 227767  2023.07  15        11985           S1w         Daieisho
# 227769  2023.07  15        12796          M17w          Hakuoho
# 227771  2023.07  15        12231           O1w        Kirishima
#
#        rikishi1_result  rikishi1_win    kimarite  rikishi2_id rikishi2_rank  \
# 0            0-1 (7-8)             0    yorikiri         4306          Ms1e
# 3           0-1 (3-12)             0   oshidashi         1337          J12w
# 4            0-1 (8-7)             0    yorikiri         4319          J11w
# 6            0-1 (7-8)             0  tsukidashi         4129          J11e
# 8           0-1 (4-11)             0  hatakikomi         4130           J9w
# ...                ...           ...         ...          ...           ...
# 227762            10-5             0    yorikiri        12270           K1e
# 227764             9-6             0    yorikiri        12291           M4e
# 227767             9-6             0  hikiotoshi        11855           M9e
# 227769            11-4             0   uwatenage        12451           S1e
# 227771           6-7-2             0    yorikiri        12094           K1w
#
#        rikishi2_shikona rikishi2_result rikishi2_win
# 0                 Ofuji       1-0 (6-1)            1
# 3          Tochitsukasa       1-0 (9-6)            1
# 4            Harunafuji      1-0 (5-10)            1
# 6           Hakuryuyama      1-0 (3-12)            1
# 8               Hachiya       1-0 (8-7)            1
# ...                 ...             ...          ...
# 227762       Kotonowaka            11-4            1
# 227764        Asanoyama           8-4-3            1
# 227767        Takanosho             8-7            1
# 227769         Hoshoryu            12-3            1
# 227771              Abi             6-9            1
#
# [113886 rows x 13 columns]

# %%
# For each wrestler's ID, this tallies up their total number of wins.
win_count = {}

for r in rikishi_id_list:
    win_count[r] = len(sumo_only_wins.loc[results.rikishi1_id == r])
    
# I now create a dataframe that sorts the win tallies from highest to lowest.
sorted_win_count = sorted(win_count.items(), key=lambda x:x[1], reverse=True)

sorted_win_count_df = pd.DataFrame.from_dict(sorted_win_count)
sorted_win_count_df.columns = ['id', 'wins']
sorted_win_count_df.head()
# Out:
#      id  wins
# 0  1123  1121
# 1     7   956
# 2    89   831
# 3    41   827
# 4    39   781

# %%
# I now do the same thing but for each wrestler's total number of losses.
loss_count = {}

for r in rikishi_id_list:
    loss_count[r] = len(sumo_only_losses.loc[results.rikishi1_id == r])
    
sorted_loss_count = sorted(loss_count.items(), key=lambda x:x[1], reverse=True)

sorted_loss_count_df = pd.DataFrame.from_dict(sorted_loss_count)
sorted_loss_count_df.columns = ['id', 'losses']
sorted_loss_count_df.head()
# Out:
#      id  losses
# 0    41     888
# 1    89     869
# 2    33     855
# 3  1284     744
# 4    13     731

# %%
# I now combine the dataframe for wins the with dataframe for losses.
won_loss_df = pd.merge(sorted_win_count_df, sorted_loss_count_df)
won_loss_df
# Out:
#         id  wins  losses
# 0     1123  1121     212
# 1        7   956     642
# 2       89   831     869
# 3       41   827     888
# 4       39   781     692
# ..     ...   ...     ...
# 592  11965     0       1
# 593  12141     0       1
# 594  12369     0       1
# 595  11949     0       2
# 596  12013     0       1
#
# [597 rows x 3 columns]

# %%
# With the won-loss totals in a single dataframe, now I calculate each wrestler's winning percentage.
pct_list = []

for i in range(len(won_loss_df)):
    pct = round(int(won_loss_df[won_loss_df.id == won_loss_df['id'][i]].wins.iloc[0]) / int(
    (won_loss_df[won_loss_df.id == won_loss_df['id'][i]].wins.iloc[0])
    + int(won_loss_df[won_loss_df.id == won_loss_df['id'][i]].losses.iloc[0])
), 2)
    pct_list.append(pct)

won_loss_df["pct"] = pct_list
won_loss_df
# Out:
#         id  wins  losses   pct
# 0     1123  1121     212  0.84
# 1        7   956     642  0.60
# 2       89   831     869  0.49
# 3       41   827     888  0.48
# 4       39   781     692  0.53
# ..     ...   ...     ...   ...
# 592  11965     0       1  0.00
# 593  12141     0       1  0.00
# 594  12369     0       1  0.00
# 595  11949     0       2  0.00
# 596  12013     0       1  0.00
#
# [597 rows x 4 columns]

# %%
# This takes the won_loss_df and merges it with the shikona_df

new_won_loss_df = pd.merge(won_loss_df, shikona_df)
new_won_loss_df = new_won_loss_df.iloc[:, [0, 4, 1, 2, 3, 5, 6]]
new_won_loss_df.head()
# Out:
#      id     shikona  wins  losses   pct alt_shikona2 alt_shikona3
# 0  1123      Hakuho  1121     212  0.84         None         None
# 1     7        Kaio   956     642  0.60         Koga         None
# 2    89  Aminishiki   831     869  0.49         None         None
# 3    41  Kyokutenho   827     888  0.48         None         None
# 4    39  Wakanosato   781     692  0.53       Kogawa         None

# %%
# The information in rikishi1_rank includes a designation of "e" or "w" ("east" or "west" on the banzuke), but as that is immaterial to ranking, we can strip it out.
# A simple excision of the final character doesn't work, so I can't do the following: sumo.rikishi1_rank.str[:-1]
# See, some rankings appear on the spreadsheet with an "HD" at the end, so I have to work with a list of characters to remove in order to clean this out.

char_to_remove = ["e", "w", "HD"]
cleaned_rankings = results["rikishi1_rank"]
for character in char_to_remove:
    cleaned_rankings = cleaned_rankings.str.replace(character, "")

results_cleaned_rank = results
results_cleaned_rank["rikishi1_rank"] = cleaned_rankings

results_cleaned_rank["rikishi1_rank"] = results_cleaned_rank["rikishi1_rank"].str.replace("Ms", "makushita") # temporarily lowercase so as not to affect "M" in "Maegashira"
results_cleaned_rank["rikishi1_rank"] = results_cleaned_rank["rikishi1_rank"].str.replace("J", "Juryo")
results_cleaned_rank["rikishi1_rank"] = results_cleaned_rank["rikishi1_rank"].str.replace("M", "Maegashira")
results_cleaned_rank["rikishi1_rank"] = results_cleaned_rank["rikishi1_rank"].str.replace("makushita", "Makushita") # now that "Maegashira" is done, change back to uppercase
results_cleaned_rank["rikishi1_rank"] = results_cleaned_rank["rikishi1_rank"].str.replace("Y1YO", "Yokozuna") # usually "Yokozuna" is either "Y1" or "Y2," but this is one outlier in the data
results_cleaned_rank["rikishi1_rank"] = results_cleaned_rank["rikishi1_rank"].str.replace("Y2YO", "Yokozuna")
results_cleaned_rank["rikishi1_rank"] = results_cleaned_rank["rikishi1_rank"].str.replace("Y1", "Yokozuna")
results_cleaned_rank["rikishi1_rank"] = results_cleaned_rank["rikishi1_rank"].str.replace("Y2", "Yokozuna")
results_cleaned_rank["rikishi1_rank"] = results_cleaned_rank["rikishi1_rank"].str.replace("O1", "Ozeki")
results_cleaned_rank["rikishi1_rank"] = results_cleaned_rank["rikishi1_rank"].str.replace("O2", "Ozeki")
results_cleaned_rank["rikishi1_rank"] = results_cleaned_rank["rikishi1_rank"].str.replace("O3", "Ozeki")
results_cleaned_rank["rikishi1_rank"] = results_cleaned_rank["rikishi1_rank"].str.replace("S1", "Sekiwake")
results_cleaned_rank["rikishi1_rank"] = results_cleaned_rank["rikishi1_rank"].str.replace("S2", "Sekiwake")
results_cleaned_rank["rikishi1_rank"] = results_cleaned_rank["rikishi1_rank"].str.replace("S3", "Sekiwake")
results_cleaned_rank["rikishi1_rank"] = results_cleaned_rank["rikishi1_rank"].str.replace("K1", "Komusubi")
results_cleaned_rank["rikishi1_rank"] = results_cleaned_rank["rikishi1_rank"].str.replace("K2", "Komusubi")
results_cleaned_rank["rikishi1_rank"] = results_cleaned_rank["rikishi1_rank"].str.replace("K3", "Komusubi")
results_cleaned_rank
# Out:
#           basho day  rikishi1_id rikishi1_rank rikishi1_shikona  \
# 0       1983.01   1         4140       Juryo13      Chikubayama
# 1       1983.01   1         4306    Makushita1            Ofuji
# 2       1983.01   1         1337       Juryo12     Tochitsukasa
# 3       1983.01   1         4323       Juryo13         Shiraiwa
# 4       1983.01   1         4097       Juryo12       Tamakiyama
# ...         ...  ..          ...           ...              ...
# 227767  2023.07  15        11985      Sekiwake         Daieisho
# 227768  2023.07  15        12451      Sekiwake         Hoshoryu
# 227769  2023.07  15        12796  Maegashira17          Hakuoho
# 227770  2023.07  15        12094      Komusubi              Abi
# 227771  2023.07  15        12231         Ozeki        Kirishima
#
#        rikishi1_result  rikishi1_win    kimarite  rikishi2_id rikishi2_rank  \
# 0            0-1 (7-8)             0    yorikiri         4306          Ms1e
# 1            1-0 (6-1)             1    yorikiri         4140          J13w
# 2            1-0 (9-6)             1   oshidashi         4323          J13e
# 3           0-1 (3-12)             0   oshidashi         1337          J12w
# 4            0-1 (8-7)             0    yorikiri         4319          J11w
# ...                ...           ...         ...          ...           ...
# 227767             9-6             0  hikiotoshi        11855           M9e
# 227768            12-3             1   uwatenage        12796          M17w
# 227769            11-4             0   uwatenage        12451           S1e
# 227770             6-9             1    yorikiri        12231           O1w
# 227771           6-7-2             0    yorikiri        12094           K1w
#
#        rikishi2_shikona rikishi2_result rikishi2_win
# 0                 Ofuji       1-0 (6-1)            1
# 1           Chikubayama       0-1 (7-8)            0
# 2              Shiraiwa      0-1 (3-12)            0
# 3          Tochitsukasa       1-0 (9-6)            1
# 4            Harunafuji      1-0 (5-10)            1
# ...                 ...             ...          ...
# 227767        Takanosho             8-7            1
# 227768          Hakuoho            11-4            0
# 227769         Hoshoryu            12-3            1
# 227770        Kirishima           6-7-2            0
# 227771              Abi             6-9            1
#
# [227772 rows x 13 columns]

# %%
# Here I want to create a dictionary that lists each wrestler by ID number as a key, and the value for that key is a list of each rank that wrestler
# had during the top-division matches covered by the data. Obviously, each wrestler had a career in the lower ranks before reaching the top division
# in the first place, and that is not reflected here. However, the main goal with this is to eventually determine the best rank for every top-divsion
# wrestler, so the focus will eventually be on the higher ranks anyway.

rank_dict = {}
rank_list = []

for r in rikishi_id_list:
    for i in results.loc[results.rikishi1_id == r]["rikishi1_rank"].unique(): # Repetitions of a rank won't be necessary, thus unique() is sufficient.
        rank_list.append(i)
        rank_list
    rank_dict[r] = rank_list
    rank_list = []

rank_dict
# Out:
# {4140: ['Juryo13',
#   'Makushita3',
#   'Makushita2',
#   'Juryo9',
#   'Juryo4',
#   'Juryo2',
#   'Juryo10',
#   'Juryo8',
#   'Juryo3',
#   'Juryo12',
#   'Juryo1',
#   'Maegashira13',
#   'Maegashira14',
#   'Juryo5',
#   'Makushita1'],
#  4306: ['Makushita1', 'Juryo12', 'Juryo8', 'Juryo11', 'Juryo7'],
#  1337: ['Juryo12',
#   'Juryo9',
#   'Juryo5',
#   'Juryo1',
#   'Maegashira13',
#   'Juryo2',
#   'Maegashira14',
#   'Maegashira8',
#   'Maegashira9',
#   'Maegashira1',
#   'Juryo4',
#   'Juryo3',
#   'Maegashira12',
#   'Maegashira5',
#   'Komusubi',
#   'Maegashira3',
#   'Maegashira4',
#   'Maegashira6',
#   'Maegashira11',
#   'Sekiwake',
#   'Maegashira7',
#   'Maegashira2',
#   'Maegashira10',
#   'Juryo6'],
#  4323: ['Juryo13', 'Juryo10', 'Juryo8', 'Juryo7', 'Juryo9', 'Makushita1'],
#  4097: ['Juryo12', 'Juryo11', 'Juryo13', 'Makushita7'],
#  4319: ['Juryo11',
#   'Juryo12',
#   'Makushita3',
#   'Juryo13',
#   'Juryo9',
#   'Juryo6',
#   'Juryo2',
#   'Juryo7',
#   'Makushita6',
#   'Makushita8'],
#  4109: ['Juryo10', 'Juryo13', 'Makushita6'],
#  4129: ['Juryo11'],
#  4111: ['Juryo10'],
#  4130: ['Juryo9',
#   'Juryo8',
#   'Juryo6',
#   'Juryo5',
#   'Juryo3',
#   'Maegashira14',
#   'Maegashira6',
#   'Maegashira11',
#   'Juryo2',
#   'Juryo4',
#   'Juryo12',
#   'Juryo7'],
#  1302: ['Juryo9',
#   'Makushita4',
#   'Makushita2',
#   'Juryo10',
#   'Juryo6',
#   'Juryo3',
#   'Maegashira13',
#   'Maegashira10',
#   'Maegashira5',
#   'Maegashira12',
#   'Maegashira11',
#   'Maegashira8',
#   'Maegashira4',
#   'Maegashira6',
#   'Maegashira14',
#   'Juryo2',
#   'Juryo7',
#   'Juryo1',
#   'Maegashira7',
#   'Maegashira1',
#   'Maegashira2',
#   'Maegashira3',
#   'Maegashira9',
#   'Komusubi',
#   'Maegashira15'],
#  4318: ['Juryo8', 'Juryo11', 'Juryo7', 'Juryo10', 'Juryo12', 'Makushita2'],
#  1361: ['Juryo8',
#   'Juryo4',
#   'Juryo1',
#   'Juryo7',
#   'Maegashira11',
#   'Maegashira9',
#   'Maegashira4',
#   'Maegashira6',
#   'Maegashira7',
#   'Maegashira3',
#   'Maegashira12',
#   'Maegashira8',
#   'Maegashira10',
#   'Maegashira1',
#   'Komusubi',
#   'Maegashira5',
#   'Maegashira13',
#   'Juryo2',
#   'Juryo5',
#   'Juryo10',
#   'Juryo3',
#   'Juryo9',
#   'Juryo11'],
#  4316: ['Juryo7', 'Juryo3', 'Juryo4', 'Juryo2'],
#  1385: ['Juryo6',
#   'Juryo5',
#   'Juryo2',
#   'Maegashira13',
#   'Juryo4',
#   'Juryo3',
#   'Juryo1',
#   'Juryo7',
#   'Maegashira12',
#   'Juryo11',
#   'Makushita2',
#   'Juryo13',
#   'Makushita6',
#   'Makushita3'],
#  4125: ['Juryo7', 'Juryo6', 'Juryo8', 'Juryo10', 'Juryo13'],
#  1347: ['Juryo6',
#   'Maegashira13',
#   'Maegashira5',
#   'Maegashira8',
#   'Maegashira6',
#   'Maegashira1',
#   'Maegashira7',
#   'Maegashira2',
#   'Maegashira4',
#   'Maegashira3',
#   'Maegashira9',
#   'Maegashira12',
#   'Maegashira10',
#   'Maegashira11',
#   'Komusubi',
#   'Maegashira14',
#   'Juryo9'],
#  4311: ['Juryo5',
#   'Juryo2',
#   'Juryo4',
#   'Juryo3',
#   'Juryo8',
#   'Juryo9',
#   'Juryo10',
#   'Makushita3',
#   'Makushita4',
#   'Juryo13',
#   'Juryo11',
#   'Juryo12',
#   'Juryo7'],
#  1332: ['Juryo4',
#   'Maegashira13',
#   'Maegashira5',
#   'Maegashira6',
#   'Maegashira8',
#   'Maegashira9',
#   'Maegashira3',
#   'Maegashira10',
#   'Sekiwake',
#   'Maegashira4',
#   'Maegashira1',
#   'Maegashira7',
#   'Komusubi',
#   'Maegashira2',
#   'Maegashira12',
#   'Maegashira15',
#   'Juryo5',
#   'Juryo11'],
#  4322: ['Juryo5', 'Juryo10', 'Makushita1', 'Juryo12', 'Makushita10'],
#  1380: ['Juryo3',
#   'Maegashira11',
#   'Maegashira4',
#   'Maegashira2',
#   'Maegashira8',
#   'Maegashira9',
#   'Maegashira10',
#   'Maegashira3',
#   'Maegashira12',
#   'Maegashira13',
#   'Juryo5',
#   'Juryo4',
#   'Juryo1',
#   'Maegashira14',
#   'Juryo10',
#   'Juryo6',
#   'Juryo7',
#   'Juryo8',
#   'Juryo12',
#   'Juryo9'],
#  4128: ['Juryo4',
#   'Juryo6',
#   'Juryo1',
#   'Juryo7',
#   'Juryo9',
#   'Juryo5',
#   'Juryo2',
#   'Maegashira14',
#   'Juryo8',
#   'Juryo10'],
#  1350: ['Juryo2',
#   'Maegashira9',
#   'Maegashira2',
#   'Maegashira5',
#   'Komusubi',
#   'Maegashira3',
#   'Sekiwake',
#   'Maegashira1',
#   'Ozeki',
#   'Yokozuna'],
#  1359: ['Juryo3',
#   'Maegashira12',
#   'Maegashira3',
#   'Maegashira7',
#   'Maegashira2',
#   'Sekiwake',
#   'Maegashira14',
#   'Maegashira10',
#   'Maegashira4',
#   'Maegashira6',
#   'Komusubi',
#   'Maegashira8',
#   'Maegashira11',
#   'Maegashira9',
#   'Maegashira13',
#   'Maegashira1',
#   'Maegashira5',
#   'Juryo8',
#   'Juryo6',
#   'Juryo11'],
#  4087: ['Juryo2', 'Juryo9'],
#  4091: ['Juryo1',
#   'Juryo3',
#   'Maegashira11',
#   'Maegashira12',
#   'Juryo2',
#   'Juryo7',
#   'Juryo8',
#   'Juryo4',
#   'Juryo6',
#   'Juryo11'],
#  1342: ['Juryo1',
#   'Maegashira10',
#   'Maegashira4',
#   'Maegashira11',
#   'Maegashira5',
#   'Komusubi',
#   'Maegashira14',
#   'Maegashira6',
#   'Maegashira2',
#   'Maegashira1',
#   'Sekiwake',
#   'Ozeki',
#   'Yokozuna'],
#  4103: ['Maegashira14',
#   'Juryo8',
#   'Juryo11',
#   'Makushita1',
#   'Juryo7',
#   'Juryo10',
#   'Makushita5'],
#  4122: ['Maegashira14',
#   'Juryo7',
#   'Juryo2',
#   'Juryo3',
#   'Juryo5',
#   'Juryo4',
#   'Juryo8',
#   'Juryo11'],
#  4131: ['Maegashira13',
#   'Juryo4',
#   'Juryo3',
#   'Juryo1',
#   'Maegashira12',
#   'Maegashira2',
#   'Maegashira9',
#   'Maegashira8',
#   'Maegashira4',
#   'Maegashira7',
#   'Maegashira10',
#   'Maegashira6',
#   'Maegashira5',
#   'Maegashira11',
#   'Maegashira3',
#   'Juryo2',
#   'Juryo12',
#   'Juryo8',
#   'Juryo5',
#   'Juryo10',
#   'Juryo7',
#   'Makushita6'],
#  1348: ['Maegashira13',
#   'Juryo5',
#   'Juryo7',
#   'Juryo9',
#   'Juryo8',
#   'Juryo4',
#   'Maegashira12',
#   'Maegashira5',
#   'Maegashira7',
#   'Maegashira3',
#   'Maegashira10',
#   'Maegashira6',
#   'Maegashira2',
#   'Maegashira8',
#   'Maegashira1',
#   'Maegashira9',
#   'Maegashira4',
#   'Komusubi',
#   'Maegashira11',
#   'Maegashira15'],
#  4124: ['Maegashira12',
#   'Maegashira4',
#   'Maegashira10',
#   'Maegashira2',
#   'Maegashira8',
#   'Juryo6',
#   'Juryo3',
#   'Juryo5',
#   'Juryo4',
#   'Juryo9',
#   'Juryo10',
#   'Juryo8',
#   'Juryo7',
#   'Juryo2',
#   'Maegashira13',
#   'Makushita1'],
#  1334: ['Maegashira11',
#   'Maegashira4',
#   'Maegashira1',
#   'Maegashira7',
#   'Maegashira13',
#   'Juryo6',
#   'Juryo10',
#   'Juryo7',
#   'Juryo4',
#   'Maegashira14',
#   'Juryo1',
#   'Juryo8',
#   'Juryo5',
#   'Juryo11',
#   'Juryo3',
#   'Juryo2',
#   'Maegashira10',
#   'Maegashira3',
#   'Maegashira8',
#   'Maegashira12',
#   'Maegashira9',
#   'Maegashira6',
#   'Maegashira2',
#   'Maegashira5'],
#  4118: ['Maegashira12',
#   'Juryo1',
#   'Juryo3',
#   'Maegashira9',
#   'Maegashira13',
#   'Maegashira8',
#   'Maegashira10',
#   'Juryo6',
#   'Makushita1',
#   'Juryo13',
#   'Makushita5',
#   'Juryo11',
#   'Makushita7',
#   'Makushita4'],
#  1345: ['Maegashira11',
#   'Maegashira7',
#   'Maegashira13',
#   'Maegashira8',
#   'Maegashira12',
#   'Juryo7',
#   'Juryo4',
#   'Juryo6',
#   'Juryo11',
#   'Juryo12',
#   'Maegashira9',
#   'Maegashira4',
#   'Maegashira14',
#   'Maegashira2',
#   'Maegashira10',
#   'Maegashira5',
#   'Komusubi',
#   'Juryo1',
#   'Juryo3',
#   'Juryo5',
#   'Juryo9',
#   'Juryo2',
#   'Juryo10'],
#  4100: ['Maegashira10',
#   'Maegashira6',
#   'Maegashira1',
#   'Maegashira12',
#   'Maegashira4',
#   'Maegashira5',
#   'Maegashira11',
#   'Juryo4',
#   'Juryo2',
#   'Maegashira13',
#   'Juryo8',
#   'Juryo5',
#   'Juryo7',
#   'Juryo3',
#   'Juryo13',
#   'Juryo11',
#   'Juryo9',
#   'Juryo12'],
#  1352: ['Maegashira9',
#   'Maegashira2',
#   'Maegashira8',
#   'Maegashira10',
#   'Maegashira4',
#   'Sekiwake',
#   'Maegashira3',
#   'Maegashira11',
#   'Maegashira12',
#   'Komusubi',
#   'Maegashira1',
#   'Maegashira6',
#   'Maegashira5',
#   'Juryo3',
#   'Maegashira7',
#   'Maegashira13',
#   'Juryo2',
#   'Maegashira14',
#   'Juryo9'],
#  4132: ['Maegashira10',
#   'Juryo7',
#   'Juryo9',
#   'Juryo2',
#   'Juryo1',
#   'Maegashira12',
#   'Maegashira3',
#   'Maegashira13',
#   'Maegashira9'],
#  4050: ['Maegashira9',
#   'Maegashira2',
#   'Maegashira7',
#   'Maegashira11',
#   'Maegashira8',
#   'Juryo3',
#   'Juryo12'],
#  4117: ['Maegashira8',
#   'Maegashira9',
#   'Maegashira10',
#   'Maegashira4',
#   'Juryo2',
#   'Juryo4',
#   'Juryo11',
#   'Juryo7',
#   'Juryo5',
#   'Juryo9',
#   'Juryo6',
#   'Juryo3',
#   'Maegashira13',
#   'Maegashira12',
#   'Juryo10'],
#  1378: ['Maegashira8',
#   'Juryo10',
#   'Juryo5',
#   'Juryo9',
#   'Juryo1',
#   'Maegashira10',
#   'Maegashira6',
#   'Maegashira2',
#   'Sekiwake',
#   'Maegashira4',
#   'Maegashira11',
#   'Maegashira7',
#   'Maegashira3',
#   'Maegashira13',
#   'Maegashira5',
#   'Juryo12',
#   'Juryo11',
#   'Juryo6',
#   'Juryo13',
#   'Makushita3',
#   'Juryo7',
#   'Juryo4',
#   'Juryo2',
#   'Maegashira9',
#   'Makushita6'],
#  4133: ['Maegashira7',
#   'Maegashira3',
#   'Maegashira8',
#   'Maegashira9',
#   'Maegashira2',
#   'Maegashira12',
#   'Juryo6',
#   'Juryo9',
#   'Juryo5',
#   'Juryo8',
#   'Juryo12',
#   'Makushita1',
#   'Juryo13',
#   'Makushita6',
#   'Makushita3'],
#  1338: ['Maegashira7',
#   'Komusubi',
#   'Maegashira2',
#   'Maegashira4',
#   'Sekiwake',
#   'Maegashira6',
#   'Maegashira1',
#   'Maegashira5',
#   'Maegashira3',
#   'Maegashira8',
#   'Maegashira9',
#   'Maegashira10',
#   'Maegashira12',
#   'Maegashira14',
#   'Maegashira13',
#   'Maegashira15',
#   'Juryo5',
#   'Juryo7'],
#  4077: ['Maegashira6',
#   'Maegashira11',
#   'Maegashira12',
#   'Maegashira10',
#   'Maegashira1',
#   'Juryo5',
#   'Juryo2',
#   'Juryo6',
#   'Juryo3',
#   'Juryo9'],
#  1375: ['Maegashira6',
#   'Maegashira1',
#   'Maegashira3',
#   'Komusubi',
#   'Sekiwake',
#   'Maegashira5',
#   'Maegashira11',
#   'Maegashira10',
#   'Maegashira14',
#   'Juryo7',
#   'Juryo3',
#   'Juryo2',
#   'Juryo1',
#   'Juryo9',
#   'Juryo5',
#   'Juryo4',
#   'Juryo8',
#   'Juryo6',
#   'Juryo11',
#   'Juryo10'],
#  4102: ['Maegashira4',
#   'Maegashira8',
#   'Maegashira1',
#   'Sekiwake',
#   'Maegashira5',
#   'Maegashira6',
#   'Maegashira2',
#   'Maegashira3',
#   'Maegashira9',
#   'Maegashira11',
#   'Maegashira12',
#   'Juryo4',
#   'Juryo2',
#   'Juryo10'],
#  1369: ['Maegashira3',
#   'Maegashira7',
#   'Maegashira1',
#   'Maegashira5',
#   'Maegashira6',
#   'Maegashira2',
#   'Maegashira4',
#   'Sekiwake',
#   'Maegashira9',
#   'Maegashira8',
#   'Maegashira11',
#   'Maegashira12',
#   'Maegashira10',
#   'Juryo2',
#   'Maegashira13',
#   'Juryo7',
#   'Juryo12',
#   'Juryo11',
#   'Juryo9',
#   'Juryo8'],
#  4107: ['Maegashira4',
#   'Maegashira8',
#   'Maegashira12',
#   'Maegashira7',
#   'Maegashira9',
#   'Maegashira3',
#   'Maegashira11',
#   'Maegashira13',
#   'Maegashira6',
#   'Maegashira14',
#   'Maegashira10',
#   'Juryo5',
#   'Juryo3'],
#  4099: ['Maegashira2',
#   'Maegashira10',
#   'Komusubi',
#   'Maegashira9',
#   'Maegashira1',
#   'Maegashira5',
#   'Maegashira12',
#   'Maegashira4',
#   'Maegashira6',
#   'Maegashira11',
#   'Maegashira8',
#   'Maegashira3',
#   'Maegashira7',
#   'Maegashira13'],
#  4126: ['Maegashira2',
#   'Maegashira5',
#   'Maegashira9',
#   'Maegashira3',
#   'Maegashira6',
#   'Komusubi',
#   'Maegashira1',
#   'Maegashira10',
#   'Maegashira8',
#   'Maegashira13',
#   'Maegashira4',
#   'Maegashira11',
#   'Maegashira7',
#   'Maegashira12',
#   'Juryo6',
#   'Juryo11'],
#  1374: ['Maegashira1',
#   'Maegashira6',
#   'Komusubi',
#   'Maegashira4',
#   'Maegashira7',
#   'Maegashira2',
#   'Maegashira10',
#   'Maegashira8',
#   'Maegashira13',
#   'Maegashira12',
#   'Juryo1',
#   'Maegashira9',
#   'Juryo5',
#   'Juryo3',
#   'Juryo6',
#   'Juryo4',
#   'Juryo2',
#   'Juryo7',
#   'Juryo9'],
#  1379: ['Sekiwake', 'Ozeki'],
#  4078: ['Maegashira1',
#   'Maegashira5',
#   'Maegashira6',
#   'Maegashira9',
#   'Maegashira11',
#   'Maegashira12',
#   'Juryo1',
#   'Juryo2',
#   'Juryo9',
#   'Juryo3',
#   'Juryo7',
#   'Juryo10',
#   'Juryo12',
#   'Juryo8',
#   'Juryo11',
#   'Juryo13',
#   'Makushita3',
#   'Juryo6',
#   'Makushita1'],
#  4127: ['Ozeki'],
#  1363: ['Sekiwake', 'Ozeki'],
#  4112: ['Ozeki', 'Maegashira10'],
#  4094: ['Maegashira5',
#   'Juryo1',
#   'Juryo5',
#   'Juryo4',
#   'Juryo2',
#   'Maegashira13',
#   'Juryo6',
#   'Maegashira4',
#   'Maegashira9',
#   'Maegashira10',
#   'Maegashira2',
#   'Maegashira12',
#   'Maegashira1',
#   'Maegashira3',
#   'Maegashira7',
#   'Maegashira11',
#   'Juryo3',
#   'Juryo9'],
#  4104: ['Ozeki', 'Yokozuna'],
#  4095: ['Yokozuna'],
#  4116: ['Komusubi',
#   'Maegashira1',
#   'Sekiwake',
#   'Maegashira5',
#   'Maegashira6',
#   'Maegashira7',
#   'Maegashira9',
#   'Maegashira4',
#   'Maegashira10'],
#  1353: ['Maegashira5',
#   'Komusubi',
#   'Maegashira9',
#   'Maegashira3',
#   'Maegashira10',
#   'Maegashira1',
#   'Maegashira4',
#   'Maegashira11',
#   'Maegashira6',
#   'Maegashira2',
#   'Maegashira7',
#   'Maegashira8',
#   'Maegashira13',
#   'Sekiwake',
#   'Maegashira14'],
#  4080: ['Yokozuna'],
#  1354: ['Yokozuna'],
#  4134: ['Komusubi',
#   'Maegashira3',
#   'Maegashira7',
#   'Maegashira10',
#   'Maegashira8',
#   'Maegashira5',
#   'Maegashira13',
#   'Juryo3',
#   'Juryo2',
#   'Juryo8',
#   'Juryo11',
#   'Juryo6',
#   'Makushita3'],
#  1381: ['Makushita1',
#   'Makushita7',
#   'Makushita3',
#   'Makushita2',
#   'Makushita5',
#   'Juryo11',
#   'Juryo9',
#   'Juryo8',
#   'Juryo12'],
#  1364: ['Makushita2',
#   'Makushita1',
#   'Makushita5',
#   'Juryo13',
#   'Juryo8',
#   'Juryo5',
#   'Juryo4',
#   'Juryo9',
#   'Juryo10',
#   'Juryo7',
#   'Maegashira14',
#   'Juryo2',
#   'Maegashira13',
#   'Maegashira4',
#   'Komusubi',
#   'Sekiwake',
#   'Maegashira3',
#   'Maegashira6',
#   'Maegashira1',
#   'Maegashira12',
#   'Juryo3',
#   'Maegashira2'],
#  1417: ['Makushita3',
#   'Juryo12',
#   'Juryo6',
#   'Juryo8',
#   'Juryo9',
#   'Makushita1',
#   'Makushita5',
#   'Juryo13',
#   'Juryo10',
#   'Juryo5',
#   'Makushita4'],
#  4303: ['Makushita3', 'Juryo13', 'Makushita4', 'Makushita1'],
#  4119: ['Makushita3', 'Juryo13'],
#  1451: ['Makushita4',
#   'Makushita3',
#   'Juryo12',
#   'Juryo4',
#   'Juryo3',
#   'Juryo10',
#   'Makushita6'],
#  1317: ['Makushita2',
#   'Makushita1',
#   'Juryo12',
#   'Makushita3',
#   'Juryo11',
#   'Juryo6',
#   'Juryo8',
#   'Juryo13',
#   'Juryo10',
#   'Makushita5',
#   'Juryo7',
#   'Juryo4',
#   'Juryo1',
#   'Maegashira14',
#   'Maegashira9',
#   'Maegashira3',
#   'Maegashira2',
#   'Maegashira5',
#   'Maegashira7',
#   'Maegashira4',
#   'Maegashira1',
#   'Maegashira6',
#   'Maegashira11',
#   'Maegashira8',
#   'Maegashira10',
#   'Juryo2',
#   'Maegashira16',
#   'Juryo3',
#   'Maegashira15',
#   'Juryo9'],
#  1339: ['Juryo10',
#   'Juryo6',
#   'Juryo5',
#   'Maegashira13',
#   'Maegashira7',
#   'Komusubi',
#   'Sekiwake',
#   'Maegashira1',
#   'Maegashira3',
#   'Ozeki',
#   'Yokozuna'],
#  1356: ['Juryo2',
#   'Juryo9',
#   'Makushita2',
#   'Makushita1',
#   'Juryo12',
#   'Makushita3',
#   'Juryo7',
#   'Juryo5',
#   'Juryo11',
#   'Juryo8',
#   'Juryo1',
#   'Maegashira14',
#   'Maegashira8',
#   'Maegashira12',
#   'Maegashira9',
#   'Juryo3',
#   'Maegashira10',
#   'Maegashira13',
#   'Juryo4',
#   'Juryo10',
#   'Juryo13'],
#  4324: ['Makushita2', 'Juryo11', 'Makushita3', 'Makushita5'],
#  5070: ['Makushita5', 'Makushita3'],
#  1301: ['Makushita4',
#   'Makushita2',
#   'Juryo10',
#   'Juryo5',
#   'Juryo1',
#   'Juryo3',
#   'Maegashira12',
#   'Maegashira8',
#   'Maegashira9',
#   'Maegashira5',
#   'Maegashira11',
#   'Maegashira7',
#   'Maegashira2',
#   'Maegashira13',
#   'Maegashira4',
#   'Maegashira1',
#   'Sekiwake',
#   'Maegashira6',
#   'Komusubi',
#   'Ozeki',
#   'Maegashira14',
#   'Maegashira10'],
#  1496: ['Makushita6', 'Juryo12', 'Makushita1', 'Juryo9', 'Juryo13'],
#  6773: ['Makushita4', 'Makushita5'],
#  1373: ['Makushita5', 'Makushita3', 'Makushita1', 'Juryo13'],
#  4135: ['Makushita6', 'Juryo12'],
#  6780: ['Makushita8'],
#  4329: ['Makushita10', 'Makushita5', 'Makushita1', 'Juryo13'],
#  4136: ['Makushita7',
#   'Makushita3',
#   'Makushita4',
#   'Juryo13',
#   'Juryo9',
#   'Juryo7',
#   'Juryo1',
#   'Maegashira8',
#   'Maegashira3',
#   'Komusubi',
#   'Sekiwake',
#   'Maegashira1',
#   'Ozeki',
#   'Yokozuna'],
#  4325: ['Juryo13', 'Makushita4'],
#  1362: ['Juryo11',
#   'Makushita8',
#   'Makushita1',
#   'Juryo9',
#   'Makushita4',
#   'Makushita5',
#   'Makushita3',
#   'Juryo13',
#   'Juryo10',
#   'Juryo5',
#   'Juryo2',
#   'Juryo6',
#   'Makushita2',
#   'Juryo1',
#   'Maegashira13',
#   'Juryo4',
#   'Juryo8',
#   'Juryo3',
#   'Juryo7',
#   'Juryo12'],
#  4138: ['Makushita2',
#   'Juryo11',
#   'Juryo12',
#   'Juryo4',
#   'Juryo6',
#   'Juryo1',
#   'Maegashira12',
#   'Juryo3',
#   'Juryo2',
#   'Juryo8',
#   'Maegashira11',
#   'Juryo9',
#   'Juryo13',
#   'Juryo10',
#   'Juryo5',
#   'Juryo7'],
#  4328: ['Makushita4',
#   'Juryo13',
#   'Makushita1',
#   'Juryo12',
#   'Juryo9',
#   'Makushita5'],
#  4137: ['Makushita2',
#   'Juryo13',
#   'Juryo7',
#   'Juryo4',
#   'Juryo2',
#   'Juryo5',
#   'Juryo1',
#   'Juryo3',
#   'Maegashira14',
#   'Maegashira10',
#   'Maegashira6',
#   'Maegashira5',
#   'Maegashira13',
#   'Maegashira7',
#   'Maegashira9',
#   'Maegashira3',
#   'Maegashira8',
#   'Maegashira11'],
#  1423: ['Makushita1',
#   'Makushita6',
#   'Makushita4',
#   'Juryo13',
#   'Juryo10',
#   'Juryo7',
#   'Juryo4'],
#  4139: ['Makushita5',
#   'Juryo13',
#   'Makushita3',
#   'Juryo12',
#   'Juryo9',
#   'Juryo5',
#   'Juryo3',
#   'Juryo1',
#   'Maegashira12',
#   'Maegashira10',
#   'Maegashira4'],
#  1376: ['Makushita6',
#   'Juryo10',
#   'Juryo6',
#   'Juryo8',
#   'Juryo3',
#   'Juryo2',
#   'Juryo7',
#   'Juryo1',
#   'Maegashira13',
#   'Maegashira6',
#   'Maegashira2',
#   'Maegashira9',
#   'Maegashira3',
#   'Maegashira1',
#   'Maegashira14',
#   'Maegashira5',
#   'Maegashira7',
#   'Komusubi',
#   'Maegashira8',
#   'Maegashira4',
#   'Maegashira10'],
#  1358: ['Makushita6',
#   'Makushita3',
#   'Juryo11',
#   'Juryo12',
#   'Juryo8',
#   'Makushita1',
#   'Makushita5',
#   'Makushita8',
#   'Makushita7',
#   'Makushita2',
#   'Juryo7',
#   'Juryo10',
#   'Juryo5',
#   'Juryo3',
#   'Juryo4',
#   'Juryo13',
#   'Juryo9',
#   'Juryo6',
#   'Juryo2',
#   'Maegashira14'],
#  1383: ['Makushita2', 'Juryo11', 'Makushita6', 'Makushita3', 'Makushita1'],
#  1377: ['Makushita5',
#   'Makushita7',
#   'Makushita4',
#   'Makushita2',
#   'Juryo13',
#   'Makushita6',
#   'Makushita1',
#   'Juryo12',
#   'Juryo11',
#   'Juryo8',
#   'Juryo10',
#   'Juryo6',
#   'Juryo7'],
#  28: ['Makushita4',
#   'Makushita5',
#   'Makushita1',
#   'Juryo8',
#   'Juryo3',
#   'Maegashira11',
#   'Maegashira13',
#   'Maegashira10',
#   'Maegashira1',
#   'Maegashira2',
#   'Maegashira14',
#   'Juryo6',
#   'Juryo4',
#   'Maegashira12',
#   'Maegashira6',
#   'Sekiwake',
#   'Juryo5',
#   'Juryo11',
#   'Juryo2',
#   'Maegashira8',
#   'Komusubi',
#   'Maegashira7',
#   'Maegashira3',
#   'Maegashira9',
#   'Maegashira5',
#   'Maegashira15',
#   'Juryo1',
#   'Juryo7'],
#  4327: ['Makushita3', 'Makushita2', 'Juryo12'],
#  1287: ['Makushita6',
#   'Juryo12',
#   'Juryo3',
#   'Juryo10',
#   'Juryo2',
#   'Maegashira11',
#   'Maegashira6',
#   'Sekiwake',
#   'Maegashira1',
#   'Maegashira3',
#   'Komusubi',
#   'Maegashira9',
#   'Maegashira4',
#   'Ozeki',
#   'Maegashira5',
#   'Maegashira12',
#   'Maegashira10',
#   'Maegashira8',
#   'Maegashira7',
#   'Maegashira13',
#   'Maegashira14',
#   'Maegashira2'],
#  4312: ['Makushita5'],
#  1372: ['Makushita4',
#   'Juryo10',
#   'Makushita3',
#   'Makushita2',
#   'Juryo13',
#   'Juryo7',
#   'Juryo4',
#   'Juryo2',
#   'Juryo3',
#   'Juryo1',
#   'Maegashira14',
#   'Maegashira10',
#   'Juryo8',
#   'Maegashira13',
#   'Maegashira8',
#   'Komusubi',
#   'Maegashira4',
#   'Maegashira6',
#   'Maegashira12',
#   'Juryo6'],
#  1292: ['Makushita14',
#   'Makushita2',
#   'Juryo11',
#   'Juryo13',
#   'Juryo7',
#   'Juryo3',
#   'Maegashira12',
#   'Maegashira9',
#   'Maegashira11',
#   'Maegashira7',
#   'Komusubi',
#   'Maegashira1',
#   'Maegashira2',
#   'Sekiwake',
#   'Maegashira13',
#   'Maegashira5',
#   'Maegashira10',
#   'Maegashira3',
#   'Maegashira4',
#   'Maegashira8',
#   'Maegashira14',
#   'Juryo6',
#   'Maegashira15',
#   'Juryo8',
#   'Juryo4',
#   'Juryo2',
#   'Maegashira16',
#   'Juryo5',
#   'Juryo9',
#   'Juryo10'],
#  4326: ['Juryo13', 'Juryo12'],
#  1430: ['Makushita4', 'Makushita6'],
#  1653: ['Makushita3', 'Makushita5', 'Makushita1'],
#  1311: ['Makushita2',
#   'Juryo13',
#   'Makushita3',
#   'Juryo11',
#   'Juryo9',
#   'Juryo5',
#   'Juryo8',
#   'Juryo4',
#   'Juryo3',
#   'Juryo1',
#   'Maegashira13',
#   'Maegashira6',
#   'Maegashira9',
#   'Maegashira12',
#   'Maegashira8',
#   'Maegashira5',
#   'Maegashira14',
#   'Maegashira3',
#   'Maegashira10',
#   'Juryo7',
#   'Maegashira16'],
#  4330: ['Makushita2',
#   'Juryo11',
#   'Juryo8',
#   'Juryo12',
#   'Juryo10',
#   'Juryo13',
#   'Makushita3',
#   'Makushita9'],
#  5064: ['Makushita3', 'Makushita2'],
#  33: ['Makushita4',
#   'Makushita1',
#   'Juryo10',
#   'Juryo11',
#   'Juryo8',
#   'Juryo7',
#   'Maegashira14',
#   'Juryo3',
#   'Maegashira12',
#   'Maegashira2',
#   'Maegashira5',
#   'Maegashira7',
#   'Maegashira9',
#   'Maegashira4',
#   'Maegashira8',
#   'Maegashira1',
#   'Maegashira6',
#   'Maegashira3',
#   'Sekiwake',
#   'Komusubi',
#   'Maegashira13',
#   'Maegashira11',
#   'Maegashira10',
#   'Maegashira16',
#   'Juryo6',
#   'Juryo5',
#   'Juryo2',
#   'Juryo1'],
#  4334: ['Makushita5',
#   'Makushita6',
#   'Makushita3',
#   'Makushita4',
#   'Makushita2',
#   'Juryo11',
#   'Juryo8',
#   'Juryo5',
#   'Juryo9',
#   'Makushita1'],
#  4315: ['Makushita6', 'Makushita4'],
#  5063: ['Makushita6'],
#  49: ['Makushita3',
#   'Juryo11',
#   'Makushita6',
#   'Makushita1',
#   'Juryo12',
#   'Juryo4',
#   'Juryo3',
#   'Juryo2',
#   'Juryo8',
#   'Juryo9',
#   'Juryo7',
#   'Maegashira13',
#   'Maegashira7',
#   'Maegashira12',
#   'Komusubi',
#   'Maegashira6',
#   'Maegashira2',
#   'Maegashira5',
#   'Maegashira3',
#   'Maegashira10',
#   'Maegashira8',
#   'Maegashira1',
#   'Maegashira9',
#   'Maegashira4',
#   'Maegashira14',
#   'Juryo1',
#   'Maegashira15',
#   'Juryo5',
#   'Juryo13'],
#  6775: ['Makushita9'],
#  4321: ['Makushita7',
#   'Makushita4',
#   'Makushita1',
#   'Juryo11',
#   'Makushita2',
#   'Juryo12',
#   'Juryo10',
#   'Juryo7'],
#  1333: ['Juryo11',
#   'Juryo8',
#   'Juryo6',
#   'Juryo5',
#   'Juryo1',
#   'Juryo3',
#   'Juryo2',
#   'Juryo4',
#   'Maegashira11',
#   'Maegashira6',
#   'Maegashira7',
#   'Maegashira13',
#   'Maegashira5',
#   'Maegashira1',
#   'Maegashira10',
#   'Maegashira9',
#   'Maegashira4',
#   'Maegashira14',
#   'Juryo7',
#   'Juryo10',
#   'Makushita1'],
#  1470: ['Makushita1', 'Juryo13', 'Makushita2'],
#  4331: ['Makushita3', 'Makushita2', 'Juryo11'],
#  1367: ['Makushita1',
#   'Juryo11',
#   'Juryo12',
#   'Makushita4',
#   'Juryo10',
#   'Juryo6',
#   'Juryo4',
#   'Juryo3',
#   'Maegashira13',
#   'Juryo5',
#   'Juryo9',
#   'Juryo2',
#   'Juryo1',
#   'Maegashira6',
#   'Maegashira1',
#   'Maegashira4',
#   'Maegashira9',
#   'Maegashira11',
#   'Maegashira10',
#   'Maegashira7',
#   'Maegashira3',
#   'Juryo7',
#   'Juryo13'],
#  4333: ['Makushita2', 'Makushita1', 'Juryo11', 'Makushita7', 'Juryo13'],
#  4991: ['Makushita4', 'Makushita1', 'Makushita6', 'Makushita2'],
#  1335: ['Makushita1',
#   'Juryo10',
#   'Juryo13',
#   'Makushita2',
#   'Juryo9',
#   'Juryo2',
#   'Maegashira14',
#   'Maegashira10',
#   'Maegashira3',
#   'Maegashira9',
#   'Maegashira5',
#   'Maegashira1',
#   'Maegashira2',
#   'Maegashira6',
#   'Maegashira12',
#   'Maegashira7',
#   'Maegashira11',
#   'Maegashira4',
#   'Komusubi',
#   'Maegashira15',
#   'Juryo3',
#   'Juryo6'],
#  4332: ['Makushita4',
#   'Makushita1',
#   'Juryo12',
#   'Juryo13',
#   'Juryo11',
#   'Juryo9',
#   'Juryo8',
#   'Juryo5',
#   'Juryo4',
#   'Juryo10',
#   'Makushita9'],
#  1476: ['Makushita5',
#   'Juryo12',
#   'Juryo9',
#   'Juryo4',
#   'Juryo11',
#   'Juryo6',
#   'Juryo8',
#   'Juryo7',
#   'Juryo10',
#   'Makushita2'],
#  1390: ['Makushita7', 'Makushita5'],
#  1310: ['Makushita9',
#   'Juryo10',
#   'Juryo3',
#   'Juryo1',
#   'Maegashira13',
#   'Juryo2',
#   'Maegashira12',
#   'Maegashira6',
#   'Maegashira2',
#   'Maegashira8',
#   'Maegashira9',
#   'Maegashira3',
#   'Maegashira4',
#   'Maegashira11',
#   'Juryo5',
#   'Maegashira5',
#   'Maegashira10',
#   'Juryo6',
#   'Juryo8',
#   'Juryo4',
#   'Juryo13',
#   'Juryo7',
#   'Juryo9',
#   'Makushita1'],
#  1397: ['Makushita6',
#   'Makushita3',
#   'Juryo10',
#   'Juryo7',
#   'Juryo11',
#   'Juryo9',
#   'Juryo5',
#   'Juryo6',
#   'Juryo2',
#   'Juryo8',
#   'Juryo12',
#   'Juryo1'],
#  37: ['Makushita4',
#   'Juryo13',
#   'Juryo8',
#   'Juryo6',
#   'Juryo12',
#   'Juryo7',
#   'Juryo11',
#   'Juryo4',
#   'Juryo1',
#   'Juryo2',
#   'Maegashira12',
#   'Maegashira11',
#   'Maegashira14',
#   'Maegashira10',
#   'Maegashira5',
#   'Maegashira9',
#   'Maegashira3',
#   'Maegashira6',
#   'Maegashira8',
#   'Juryo3',
#   'Maegashira15',
#   'Maegashira16',
#   'Maegashira13',
#   'Maegashira1',
#   'Komusubi',
#   'Maegashira2',
#   'Maegashira7',
#   'Juryo5'],
#  1303: ['Makushita7',
#   'Makushita2',
#   'Makushita4',
#   'Juryo13',
#   'Juryo7',
#   'Juryo11',
#   'Juryo8',
#   'Juryo6',
#   'Juryo4',
#   'Juryo1',
#   'Maegashira12',
#   'Maegashira4',
#   'Maegashira10',
#   'Maegashira13',
#   'Maegashira5',
#   'Maegashira11',
#   'Maegashira6',
#   'Maegashira2',
#   'Maegashira8',
#   'Maegashira1',
#   'Sekiwake',
#   'Maegashira3',
#   'Maegashira7',
#   'Komusubi',
#   'Maegashira15',
#   'Maegashira9',
#   'Maegashira14',
#   'Juryo3',
#   'Juryo10',
#   'Juryo9'],
#  4335: ['Makushita3', 'Juryo11', 'Makushita5', 'Makushita1'],
#  1366: ['Makushita5',
#   'Makushita10',
#   'Makushita8',
#   'Makushita2',
#   'Juryo11',
#   'Juryo8',
#   'Juryo1',
#   'Maegashira12',
#   'Juryo4',
#   'Juryo9',
#   'Juryo10',
#   'Juryo12',
#   'Juryo6',
#   'Juryo13',
#   'Makushita6'],
#  1365: ['Makushita9',
#   'Makushita1',
#   'Juryo12',
#   'Juryo10',
#   'Juryo11',
#   'Juryo8',
#   'Juryo5',
#   'Juryo1',
#   'Juryo6',
#   'Juryo4',
#   'Juryo3',
#   'Juryo7'],
#  1315: ['Makushita3',
#   'Juryo13',
#   'Juryo7',
#   'Juryo4',
#   'Juryo9',
#   'Juryo5',
#   'Juryo3',
#   'Juryo6',
#   'Juryo2',
#   'Maegashira13',
#   'Maegashira8',
#   'Maegashira3',
#   'Maegashira11',
#   'Maegashira12',
#   'Maegashira5',
#   'Maegashira7',
#   'Maegashira10',
#   'Maegashira1',
#   'Maegashira4',
#   'Maegashira14',
#   'Maegashira6',
#   'Juryo1',
#   'Juryo10',
#   'Juryo8',
#   'Maegashira15',
#   'Juryo11'],
#  23: ['Makushita8',
#   'Makushita2',
#   'Juryo8',
#   'Juryo3',
#   'Maegashira12',
#   'Maegashira13',
#   'Maegashira4',
#   'Komusubi',
#   'Sekiwake',
#   'Maegashira1',
#   'Maegashira11',
#   'Maegashira7',
#   'Maegashira3',
#   'Maegashira5',
#   'Maegashira2',
#   'Maegashira6',
#   'Maegashira8',
#   'Maegashira10',
#   'Maegashira9'],
#  1330: ['Juryo12',
#   'Makushita4',
#   'Juryo13',
#   'Juryo9',
#   'Juryo7',
#   'Juryo3',
#   'Maegashira12',
#   'Maegashira5',
#   'Komusubi',
#   'Maegashira2',
#   'Maegashira8',
#   'Maegashira1',
#   'Maegashira4',
#   'Maegashira3',
#   'Maegashira6',
#   'Maegashira13',
#   'Juryo1',
#   'Maegashira15',
#   'Maegashira7',
#   'Maegashira9',
#   'Maegashira10',
#   'Maegashira16',
#   'Maegashira11'],
#  4336: ['Makushita2',
#   'Juryo12',
#   'Makushita1',
#   'Juryo13',
#   'Juryo9',
#   'Juryo6',
#   'Juryo10',
#   'Juryo11'],
#  30: ['Makushita6',
#   'Juryo9',
#   'Juryo6',
#   'Juryo5',
#   'Juryo4',
#   'Juryo3',
#   'Juryo8',
#   'Maegashira13',
#   'Juryo2',
#   'Maegashira10',
#   'Juryo1',
#   'Juryo7',
#   'Maegashira14',
#   'Maegashira9',
#   'Maegashira4',
#   'Maegashira7',
#   'Maegashira5',
#   'Maegashira8',
#   'Maegashira3',
#   'Maegashira12',
#   'Maegashira6',
#   'Maegashira11',
#   'Juryo10'],
#  1331: ['Makushita2',
#   'Makushita6',
#   'Juryo13',
#   'Juryo10',
#   'Juryo12',
#   'Juryo11',
#   'Makushita1',
#   'Juryo9',
#   'Juryo3',
#   'Juryo6',
#   'Juryo1',
#   'Maegashira14',
#   'Juryo5',
#   'Juryo7',
#   'Juryo2',
#   'Juryo4',
#   'Juryo8',
#   'Makushita5'],
#  1370: ['Makushita2',
#   'Makushita3',
#   'Makushita1',
#   'Juryo10',
#   'Juryo13',
#   'Juryo9',
#   'Makushita4'],
#  4988: ['Makushita2'],
#  1313: ['Makushita6',
#   'Makushita1',
#   'Makushita3',
#   'Juryo11',
#   'Juryo13',
#   'Juryo9',
#   'Juryo2',
#   'Maegashira13',
#   'Juryo6',
#   'Juryo12',
#   'Makushita4',
#   'Juryo7',
#   'Juryo4',
#   'Juryo10',
#   'Makushita2'],
#  1295: ['Makushita5',
#   'Makushita2',
#   'Makushita4',
#   'Juryo12',
#   'Juryo5',
#   'Juryo2',
#   'Maegashira12',
#   'Maegashira5',
#   'Maegashira9',
#   'Maegashira7',
#   'Maegashira10',
#   'Maegashira6',
#   'Maegashira8',
#   'Maegashira13',
#   'Maegashira11',
#   'Maegashira3',
#   'Maegashira4',
#   'Maegashira2',
#   'Komusubi',
#   'Maegashira14',
#   'Maegashira15'],
#  1442: ['Makushita4'],
#  60: ['Makushita3',
#   'Makushita1',
#   'Juryo12',
#   'Juryo13',
#   'Juryo6',
#   'Juryo3',
#   'Juryo2',
#   'Juryo1',
#   'Juryo5',
#   'Maegashira13',
#   'Maegashira14',
#   'Maegashira8',
#   'Maegashira11',
#   'Maegashira10',
#   'Maegashira3',
#   'Maegashira15',
#   'Maegashira12',
#   'Maegashira5',
#   'Maegashira4',
#   'Maegashira1',
#   'Maegashira7',
#   'Maegashira6',
#   'Maegashira9',
#   'Juryo11',
#   'Juryo8',
#   'Juryo7',
#   'Juryo9',
#   'Juryo10'],
#  1489: ['Makushita4'],
#  1357: ['Makushita5', 'Makushita4', 'Makushita3', 'Juryo13', 'Juryo10'],
#  1360: ['Makushita3', 'Makushita6', 'Makushita1', 'Juryo13'],
#  4141: ['Makushita3',
#   'Juryo13',
#   'Juryo8',
#   'Juryo4',
#   'Maegashira12',
#   'Maegashira8',
#   'Maegashira2',
#   'Maegashira5'],
#  1329: ['Makushita4',
#   'Makushita5',
#   'Makushita2',
#   'Makushita1',
#   'Juryo11',
#   'Juryo8',
#   'Juryo5',
#   'Juryo10',
#   'Juryo7',
#   'Juryo9',
#   'Juryo4',
#   'Juryo2'],
#  1425: ['Makushita2'],
#  1349: ['Makushita4',
#   'Makushita1',
#   'Juryo13',
#   'Makushita2',
#   'Juryo4',
#   'Juryo7',
#   'Juryo8',
#   'Juryo10',
#   'Juryo11'],
#  5123: ['Makushita4'],
#  9: ['Juryo12',
#   'Juryo10',
#   'Juryo6',
#   'Juryo4',
#   'Maegashira12',
#   'Juryo1',
#   'Maegashira10',
#   'Maegashira2',
#   'Komusubi',
#   'Maegashira1',
#   'Sekiwake',
#   'Maegashira6',
#   'Maegashira3',
#   'Maegashira5',
#   'Maegashira14',
#   'Maegashira13',
#   'Maegashira4',
#   'Maegashira7',
#   'Maegashira9',
#   'Maegashira11',
#   'Maegashira15'],
#  12: ['Makushita2',
#   'Makushita4',
#   'Juryo12',
#   'Makushita1',
#   'Juryo5',
#   'Juryo2',
#   'Juryo6',
#   'Maegashira14',
#   'Maegashira12',
#   'Maegashira9',
#   'Maegashira11',
#   'Maegashira6',
#   'Maegashira2',
#   'Maegashira1',
#   'Komusubi',
#   'Sekiwake',
#   'Maegashira5',
#   'Maegashira3',
#   'Maegashira4',
#   'Maegashira7',
#   'Maegashira8',
#   'Juryo1'],
#  1433: ['Makushita7',
#   'Makushita2',
#   'Juryo9',
#   'Juryo12',
#   'Makushita4',
#   'Makushita9'],
#  1355: ['Makushita3',
#   'Makushita6',
#   'Makushita4',
#   'Juryo13',
#   'Juryo11',
#   'Juryo12',
#   'Makushita1',
#   'Juryo7',
#   'Juryo5'],
#  1512: ['Juryo12', 'Makushita4'],
#  1296: ['Makushita1',
#   'Juryo11',
#   'Juryo7',
#   'Juryo12',
#   'Juryo1',
#   'Maegashira10',
#   'Maegashira4',
#   'Maegashira11',
#   'Maegashira12',
#   'Maegashira6',
#   'Maegashira1',
#   'Maegashira3',
#   'Maegashira8',
#   'Maegashira5',
#   'Juryo3',
#   'Maegashira13',
#   'Maegashira15',
#   'Maegashira14',
#   'Maegashira9',
#   'Maegashira7',
#   'Juryo6'],
#  1299: ['Makushita4',
#   'Makushita2',
#   'Juryo10',
#   'Juryo12',
#   'Juryo8',
#   'Juryo3',
#   'Juryo9',
#   'Juryo11',
#   'Juryo7',
#   'Juryo6',
#   'Makushita3',
#   'Makushita6',
#   'Makushita1',
#   'Juryo4',
#   'Maegashira15',
#   'Maegashira10',
#   'Maegashira13',
#   'Maegashira7',
#   'Maegashira4',
#   'Maegashira11',
#   'Maegashira14',
#   'Maegashira12',
#   'Maegashira9',
#   'Maegashira8',
#   'Juryo5'],
#  51: ['Makushita1',
#   'Juryo9',
#   'Juryo6',
#   'Makushita2',
#   'Juryo13',
#   'Juryo11',
#   'Juryo7',
#   'Juryo5',
#   'Maegashira11',
#   'Maegashira13',
#   'Maegashira16',
#   'Juryo1',
#   'Maegashira14',
#   'Maegashira5',
#   'Maegashira4',
#   'Maegashira10',
#   'Maegashira12',
#   'Maegashira3',
#   'Komusubi',
#   'Maegashira9',
#   'Maegashira6',
#   'Juryo4',
#   'Juryo2',
#   'Juryo10',
#   'Juryo8',
#   'Juryo3',
#   'Maegashira8'],
#  1297: ['Makushita2',
#   'Juryo11',
#   'Juryo9',
#   'Juryo6',
#   'Juryo10',
#   'Juryo8',
#   'Juryo12',
#   'Makushita1',
#   'Juryo4',
#   'Juryo7',
#   'Makushita4',
#   'Juryo13'],
#  1463: ['Makushita5'],
#  1326: ['Makushita3',
#   'Juryo13',
#   'Juryo5',
#   'Juryo6',
#   'Juryo8',
#   'Juryo3',
#   'Juryo4',
#   'Juryo1',
#   'Maegashira15',
#   'Juryo7',
#   'Juryo9',
#   'Juryo12',
#   'Maegashira16',
#   'Maegashira12'],
#  1368: ['Makushita7', 'Juryo13', 'Juryo9', 'Juryo2', 'Maegashira10'],
#  4337: ['Juryo13'],
#  1520: ['Makushita1', 'Juryo13', 'Juryo5'],
#  1321: ['Makushita2',
#   'Juryo10',
#   'Juryo13',
#   'Juryo11',
#   'Juryo3',
#   'Juryo7',
#   'Makushita3'],
#  1288: ['Makushita5',
#   'Makushita1',
#   'Juryo12',
#   'Makushita2',
#   'Juryo13',
#   'Juryo5',
#   'Maegashira14',
#   'Maegashira9',
#   'Maegashira5',
#   'Maegashira12',
#   'Maegashira3',
#   'Maegashira8',
#   'Maegashira2',
#   'Maegashira6',
#   'Maegashira11',
#   'Maegashira7',
#   'Maegashira4',
#   'Maegashira1',
#   'Maegashira10',
#   'Maegashira16',
#   'Juryo3',
#   'Juryo10'],
#  1418: ['Makushita2', 'Makushita1'],
#  1319: ['Makushita4',
#   'Juryo13',
#   'Juryo9',
#   'Juryo10',
#   'Juryo7',
#   'Juryo12',
#   'Juryo11',
#   'Makushita3',
#   'Juryo3',
#   'Juryo1',
#   'Maegashira15',
#   'Makushita1'],
#  1314: ['Makushita5',
#   'Makushita2',
#   'Juryo13',
#   'Makushita3',
#   'Juryo5',
#   'Juryo4',
#   'Juryo3',
#   'Juryo8',
#   'Juryo2',
#   'Maegashira13',
#   'Juryo1',
#   'Maegashira16',
#   'Maegashira14',
#   'Makushita1'],
#  55: ['Makushita3',
#   'Juryo13',
#   'Juryo10',
#   'Makushita2',
#   'Makushita5',
#   'Juryo9',
#   'Juryo4',
#   'Juryo2',
#   'Juryo7',
#   'Juryo6',
#   'Juryo11',
#   'Juryo12',
#   'Juryo8',
#   'Juryo5',
#   'Juryo3'],
#  48: ['Makushita5',
#   'Makushita1',
#   'Makushita2',
#   'Juryo13',
#   'Juryo7',
#   'Juryo6',
#   'Maegashira11',
#   'Maegashira7',
#   'Maegashira2',
#   'Juryo2',
#   'Maegashira14',
#   'Maegashira6',
#   'Maegashira10',
#   'Juryo1',
#   'Maegashira13',
#   'Maegashira8',
#   'Maegashira3',
#   'Maegashira9',
#   'Maegashira4',
#   'Maegashira12',
#   'Juryo4',
#   'Juryo9',
#   'Juryo3',
#   'Maegashira15',
#   'Juryo5',
#   'Juryo8'],
#  1305: ['Makushita6',
#   'Makushita1',
#   'Juryo12',
#   'Juryo6',
#   'Juryo4',
#   'Juryo11',
#   'Juryo3',
#   'Maegashira14',
#   'Juryo1',
#   'Maegashira13',
#   'Maegashira9',
#   'Juryo10',
#   'Juryo5',
#   'Juryo9',
#   'Juryo2',
#   'Maegashira16',
#   'Juryo7'],
#  44: ['Makushita4',
#   'Makushita2',
#   'Makushita1',
#   'Juryo12',
#   'Juryo3',
#   'Maegashira13',
#   'Maegashira11',
#   'Maegashira5',
#   'Maegashira9',
#   'Maegashira14',
#   'Maegashira4',
#   'Maegashira8',
#   'Juryo1',
#   'Maegashira12',
#   'Maegashira6',
#   'Maegashira1',
#   'Maegashira10',
#   'Maegashira3',
#   'Maegashira2',
#   'Maegashira7',
#   'Juryo4',
#   'Juryo2',
#   'Maegashira15',
#   'Juryo5',
#   'Juryo6',
#   'Juryo7',
#   'Juryo9'],
#  5051: ['Makushita5'],
#  1290: ['Makushita4',
#   'Makushita3',
#   'Juryo11',
#   'Juryo3',
#   'Maegashira13',
#   'Juryo4',
#   'Maegashira15',
#   'Juryo2',
#   'Maegashira11',
#   'Juryo1',
#   'Maegashira4',
#   'Maegashira3',
#   'Komusubi',
#   'Sekiwake',
#   'Maegashira1',
#   'Maegashira5',
#   'Maegashira2',
#   'Maegashira10',
#   'Juryo6',
#   'Maegashira12',
#   'Maegashira14',
#   'Juryo7',
#   'Juryo9',
#   'Juryo5'],
#  1285: ['Makushita3',
#   'Juryo13',
#   'Juryo9',
#   'Juryo6',
#   'Juryo11',
#   'Juryo7',
#   'Juryo4',
#   'Juryo1',
#   'Maegashira14',
#   'Juryo8',
#   'Juryo2',
#   'Juryo5',
#   'Juryo3',
#   'Juryo12',
#   'Maegashira16',
#   'Juryo10'],
#  1327: ['Makushita3',
#   'Juryo13',
#   'Juryo9',
#   'Juryo11',
#   'Juryo6',
#   'Juryo4',
#   'Juryo8',
#   'Juryo12',
#   'Juryo7'],
#  1382: ['Makushita2'],
#  18: ['Makushita5',
#   'Juryo13',
#   'Makushita2',
#   'Juryo10',
#   'Juryo12',
#   'Juryo8',
#   'Juryo3',
#   'Juryo1',
#   'Maegashira13',
#   'Maegashira2',
#   'Maegashira8',
#   'Maegashira1',
#   'Komusubi',
#   'Sekiwake',
#   'Maegashira5',
#   'Maegashira12',
#   'Maegashira6',
#   'Maegashira7',
#   'Maegashira3',
#   'Maegashira4',
#   'Maegashira10',
#   'Maegashira14',
#   'Maegashira9',
#   'Juryo2',
#   'Juryo7',
#   'Juryo11'],
#  1371: ['Makushita1', 'Makushita5', 'Makushita2', 'Juryo13', 'Juryo8'],
#  1309: ['Makushita2',
#   'Makushita1',
#   'Juryo12',
#   'Juryo13',
#   'Juryo9',
#   'Juryo4',
#   'Juryo6',
#   'Juryo5',
#   'Juryo7',
#   'Maegashira15',
#   'Juryo1',
#   'Maegashira13',
#   'Maegashira14',
#   'Maegashira8',
#   'Maegashira12',
#   'Juryo3',
#   'Maegashira16',
#   'Maegashira9',
#   'Juryo11',
#   'Juryo8',
#   'Juryo10'],
#  1384: ['Makushita2'],
#  1386: ['Makushita3'],
#  3: ['Makushita5',
#   'Makushita2',
#   'Juryo13',
#   'Juryo8',
#   'Juryo2',
#   'Maegashira10',
#   'Maegashira5',
#   'Maegashira12',
#   'Maegashira7',
#   'Maegashira2',
#   'Maegashira3',
#   'Komusubi',
#   'Maegashira1',
#   'Maegashira9',
#   'Maegashira4',
#   'Sekiwake',
#   'Ozeki',
#   'Yokozuna'],
#  2: ['Juryo10',
#   'Juryo6',
#   'Juryo3',
#   'Maegashira14',
#   'Juryo5',
#   'Juryo2',
#   'Maegashira12',
#   'Maegashira9',
#   'Maegashira13',
#   'Maegashira1',
#   'Komusubi',
#   'Sekiwake',
#   'Maegashira2',
#   'Ozeki',
#   'Yokozuna'],
#  1387: ['Makushita1'],
#  82: ['Makushita2',
#   'Makushita5',
#   'Makushita3',
#   'Juryo13',
#   'Juryo9',
#   'Juryo11',
#   'Juryo12',
#   'Juryo8',
#   'Juryo4',
#   'Makushita4'],
#  16: ['Makushita4',
#   'Makushita3',
#   'Makushita2',
#   'Makushita1',
#   'Juryo13',
#   'Juryo10',
#   'Juryo8',
#   'Juryo11',
#   'Maegashira15',
#   'Maegashira8',
#   'Juryo2',
#   'Maegashira9',
#   'Maegashira10',
#   'Maegashira14',
#   'Maegashira11',
#   'Maegashira6',
#   'Maegashira2',
#   'Maegashira5',
#   'Maegashira3',
#   'Maegashira4',
#   'Maegashira7',
#   'Maegashira12',
#   'Maegashira13',
#   'Juryo3',
#   'Juryo6'],
#  1: ['Makushita2',
#   'Juryo12',
#   'Juryo10',
#   'Juryo3',
#   'Maegashira14',
#   'Maegashira7',
#   'Maegashira1',
#   'Komusubi',
#   'Sekiwake',
#   'Ozeki',
#   'Yokozuna'],
#  1323: ['Makushita5',
#   'Juryo11',
#   'Makushita2',
#   'Juryo12',
#   'Juryo5',
#   'Juryo9',
#   'Juryo7',
#   'Juryo8',
#   'Makushita4',
#   'Makushita1',
#   'Juryo6'],
#  77: ['Makushita2',
#   'Juryo12',
#   'Juryo13',
#   'Makushita4',
#   'Juryo8',
#   'Juryo9',
#   'Juryo11',
#   'Juryo5',
#   'Makushita1'],
#  1307: ['Juryo11',
#   'Juryo2',
#   'Maegashira12',
#   'Maegashira8',
#   'Maegashira2',
#   'Maegashira4',
#   'Maegashira9',
#   'Maegashira7',
#   'Maegashira3',
#   'Maegashira6',
#   'Maegashira14',
#   'Maegashira10',
#   'Maegashira15',
#   'Juryo4',
#   'Juryo9',
#   'Juryo6',
#   'Juryo7',
#   'Juryo8'],
#  157: ['Juryo12',
#   'Juryo9',
#   'Juryo4',
#   'Maegashira15',
#   'Maegashira6',
#   'Maegashira13',
#   'Maegashira9',
#   'Maegashira4',
#   'Maegashira16',
#   'Maegashira12',
#   'Maegashira1',
#   'Komusubi',
#   'Maegashira2',
#   'Maegashira8',
#   'Juryo5',
#   'Juryo8',
#   'Juryo7',
#   'Juryo3',
#   'Juryo1',
#   'Makushita1'],
#  14: ['Juryo11',
#   'Juryo6',
#   'Maegashira14',
#   'Juryo1',
#   'Maegashira11',
#   'Maegashira8',
#   'Maegashira6',
#   'Maegashira9',
#   'Maegashira12',
#   'Maegashira10',
#   'Maegashira4',
#   'Maegashira7',
#   'Maegashira2',
#   'Komusubi',
#   'Maegashira1',
#   'Maegashira3',
#   'Maegashira5',
#   'Sekiwake',
#   'Maegashira13'],
#  1351: ['Makushita1',
#   'Juryo12',
#   'Juryo7',
#   'Juryo8',
#   'Juryo11',
#   'Juryo13',
#   'Makushita4'],
#  53: ['Juryo13',
#   'Juryo8',
#   'Makushita2',
#   'Makushita3',
#   'Juryo6',
#   'Juryo4',
#   'Maegashira14',
#   'Maegashira11',
#   'Maegashira7',
#   'Maegashira12',
#   'Maegashira10',
#   'Juryo2',
#   'Maegashira13',
#   'Maegashira4',
#   'Maegashira15',
#   'Maegashira6',
#   'Maegashira5',
#   'Juryo1',
#   'Juryo3',
#   'Juryo5',
#   'Juryo7',
#   'Juryo9',
#   'Makushita1'],
#  1294: ['Makushita3',
#   'Juryo12',
#   'Juryo4',
#   'Juryo10',
#   'Juryo8',
#   'Juryo9',
#   'Makushita2',
#   'Juryo11',
#   'Juryo6',
#   'Juryo2',
#   'Maegashira15',
#   'Juryo1',
#   'Maegashira14',
#   'Maegashira7',
#   'Maegashira13',
#   'Juryo5',
#   'Komusubi',
#   'Maegashira2',
#   'Maegashira4',
#   'Maegashira11',
#   'Maegashira5',
#   'Maegashira9',
#   'Maegashira1',
#   'Maegashira3'],
#  45: ['Makushita4',
#   'Makushita1',
#   'Juryo12',
#   'Juryo6',
#   'Juryo2',
#   'Maegashira13',
#   'Maegashira10',
#   'Maegashira12',
#   'Maegashira14',
#   'Maegashira9',
#   'Maegashira4',
#   'Maegashira2',
#   'Maegashira8',
#   'Maegashira1',
#   'Komusubi',
#   'Maegashira5',
#   'Maegashira3',
#   'Maegashira7',
#   'Maegashira11',
#   'Juryo11',
#   'Juryo9',
#   'Juryo4',
#   'Juryo7',
#   'Juryo3',
#   'Juryo10',
#   'Juryo5'],
#  1324: ['Makushita4',
#   'Juryo9',
#   'Maegashira15',
#   'Juryo4',
#   'Juryo6',
#   'Juryo1',
#   'Juryo10',
#   'Makushita1',
#   'Juryo13'],
#  160: ['Makushita4',
#   'Juryo10',
#   'Makushita2',
#   'Juryo2',
#   'Juryo5',
#   'Maegashira14',
#   'Maegashira15',
#   'Maegashira9',
#   'Maegashira6',
#   'Maegashira12',
#   'Maegashira13',
#   'Juryo7',
#   'Juryo6',
#   'Juryo9',
#   'Juryo8'],
#  42: ['Makushita5',
#   'Makushita1',
#   'Juryo12',
#   'Juryo6',
#   'Juryo2',
#   'Maegashira12',
#   'Maegashira9',
#   'Maegashira7',
#   'Maegashira15',
#   'Maegashira8',
#   'Maegashira11',
#   'Maegashira6',
#   'Maegashira16',
#   'Maegashira14',
#   'Maegashira4',
#   'Komusubi',
#   'Maegashira3',
#   'Juryo4',
#   'Juryo3',
#   'Maegashira10',
#   'Juryo1',
#   'Juryo7',
#   'Juryo10',
#   'Juryo5'],
#  5: ['Makushita4',
#   'Juryo13',
#   'Juryo7',
#   'Juryo4',
#   'Juryo6',
#   'Maegashira13',
#   'Maegashira11',
#   'Maegashira4',
#   'Maegashira10',
#   'Maegashira12',
#   'Maegashira5',
#   'Maegashira7',
#   'Maegashira1',
#   'Komusubi',
#   'Sekiwake',
#   'Ozeki',
#   'Maegashira3',
#   'Maegashira2',
#   'Maegashira8'],
#  1286: ['Makushita3',
#   'Juryo12',
#   'Makushita4',
#   'Juryo13',
#   'Juryo8',
#   'Juryo4',
#   'Juryo1',
#   'Juryo5',
#   'Juryo2',
#   'Maegashira14',
#   'Juryo6',
#   'Juryo3',
#   'Maegashira6',
#   'Maegashira13',
#   'Maegashira4',
#   'Maegashira5',
#   'Maegashira9',
#   'Maegashira2',
#   'Maegashira10',
#   'Maegashira8',
#   'Maegashira7',
#   'Komusubi',
#   'Maegashira1',
#   'Maegashira11'],
#  1341: ['Makushita1',
#   'Juryo13',
#   'Makushita5',
#   'Makushita3',
#   'Juryo12',
#   'Makushita4'],
#  62: ['Makushita3',
#   'Makushita1',
#   'Juryo10',
#   'Juryo13',
#   'Juryo7',
#   'Juryo5',
#   'Juryo6',
#   'Juryo1',
#   'Maegashira15',
#   'Maegashira14',
#   'Maegashira6',
#   'Maegashira10',
#   'Maegashira5',
#   'Maegashira4',
#   'Maegashira13',
#   'Maegashira7',
#   'Maegashira11',
#   'Maegashira3',
#   'Maegashira9',
#   'Juryo9',
#   'Juryo4',
#   'Juryo11',
#   'Juryo3'],
#  1306: ['Makushita1',
#   'Juryo13',
#   'Juryo11',
#   'Juryo12',
#   'Juryo8',
#   'Juryo6',
#   'Juryo9',
#   'Juryo3',
#   'Juryo1',
#   'Maegashira14',
#   'Maegashira16',
#   'Juryo7',
#   'Juryo5',
#   'Juryo4'],
#  4: ['Makushita4',
#   'Makushita1',
#   'Juryo11',
#   'Juryo3',
#   'Maegashira12',
#   'Maegashira3',
#   'Maegashira1',
#   'Komusubi',
#   'Sekiwake',
#   'Ozeki',
#   'Yokozuna'],
#  1336: ['Makushita2', 'Makushita4'],
#  1388: ['Makushita2', 'Makushita1', 'Makushita3'],
#  87: ['Juryo10',
#   'Juryo12',
#   'Juryo6',
#   'Juryo5',
#   'Juryo3',
#   'Maegashira12',
#   'Maegashira9',
#   'Maegashira15',
#   'Juryo1',
#   'Makushita1',
#   'Maegashira16',
#   'Juryo9',
#   'Juryo4',
#   'Juryo2',
#   'Makushita5',
#   'Makushita2',
#   'Juryo13',
#   'Maegashira13',
#   'Maegashira11',
#   'Maegashira6',
#   'Maegashira7',
#   'Maegashira1',
#   'Maegashira2',
#   'Maegashira4',
#   'Maegashira3',
#   'Komusubi',
#   'Maegashira10',
#   'Maegashira14',
#   'Juryo8',
#   'Juryo7'],
#  15: ['Makushita3',
#   'Makushita1',
#   'Juryo8',
#   'Juryo12',
#   'Juryo13',
#   'Juryo7',
#   'Juryo9',
#   'Juryo10',
#   'Juryo4',
#   'Juryo2',
#   'Juryo1',
#   'Maegashira16',
#   'Maegashira10',
#   'Maegashira5',
#   'Maegashira6',
#   'Maegashira1',
#   'Maegashira8',
#   'Maegashira14',
#   'Maegashira12',
#   'Maegashira15',
#   'Maegashira13',
#   'Maegashira3',
#   'Maegashira11',
#   'Maegashira4',
#   'Komusubi',
#   'Juryo3',
#   'Juryo5',
#   'Maegashira9',
#   'Juryo6'],
#  1344: ['Makushita5', 'Makushita2', 'Juryo11', 'Makushita3'],
#  1346: ['Makushita4', 'Juryo11'],
#  159: ['Makushita2'],
#  1340: ['Makushita1', 'Juryo9', 'Makushita2', 'Juryo12'],
#  140: ['Makushita3', 'Makushita1', 'Juryo11', 'Juryo7'],
#  7: ['Makushita5',
#   'Makushita2',
#   'Juryo10',
#   'Juryo11',
#   'Juryo8',
#   'Juryo3',
#   'Juryo5',
#   'Juryo1',
#   'Maegashira15',
#   'Juryo6',
#   'Maegashira6',
#   'Maegashira1',
#   'Komusubi',
#   'Maegashira2',
#   'Sekiwake',
#   'Maegashira3',
#   'Ozeki'],
#  11: ['Makushita6',
#   'Juryo13',
#   'Makushita3',
#   'Juryo12',
#   'Juryo4',
#   'Juryo2',
#   'Maegashira13',
#   'Maegashira15',
#   'Juryo5',
#   'Juryo1',
#   'Maegashira16',
#   'Juryo7',
#   'Juryo9',
#   'Juryo3',
#   'Maegashira11',
#   'Maegashira2',
#   'Maegashira7',
#   'Maegashira1',
#   'Maegashira6',
#   'Maegashira10',
#   'Maegashira4',
#   'Maegashira5',
#   'Maegashira8',
#   'Maegashira3',
#   'Maegashira14',
#   'Juryo6',
#   'Juryo10',
#   'Maegashira12',
#   'Juryo8'],
#  24: ['Makushita1',
#   'Juryo13',
#   'Juryo11',
#   'Juryo7',
#   'Juryo3',
#   'Juryo2',
#   'Maegashira15',
#   'Maegashira8',
#   'Maegashira13',
#   'Maegashira12',
#   'Maegashira7',
#   'Maegashira6',
#   'Maegashira1',
#   'Maegashira9',
#   'Maegashira3',
#   'Maegashira5',
#   'Maegashira11',
#   'Maegashira10',
#   'Maegashira14',
#   'Juryo10',
#   'Juryo12'],
#  73: ['Makushita4',
#   'Makushita2',
#   'Juryo10',
#   'Makushita5',
#   'Makushita1',
#   'Juryo13',
#   'Juryo9',
#   'Juryo8',
#   'Juryo5',
#   'Juryo2',
#   'Juryo6',
#   'Juryo4',
#   'Juryo7',
#   'Juryo11'],
#  21: ['Makushita7',
#   'Makushita1',
#   'Makushita5',
#   'Juryo10',
#   'Juryo7',
#   'Juryo8',
#   'Juryo5',
#   'Juryo2',
#   'Juryo6',
#   'Maegashira15',
#   'Maegashira10',
#   'Maegashira7',
#   'Maegashira8',
#   'Maegashira4',
#   'Maegashira6',
#   'Komusubi',
#   'Maegashira1',
#   'Maegashira3',
#   'Maegashira12',
#   'Maegashira5',
#   'Maegashira2',
#   'Maegashira11',
#   'Maegashira13'],
#  133: ['Makushita4',
#   'Makushita1',
#   'Juryo13',
#   'Makushita5',
#   'Makushita2',
#   'Juryo12',
#   'Makushita3'],
#  67: ['Makushita4',
#   'Makushita1',
#   'Juryo12',
#   'Juryo5',
#   'Juryo2',
#   'Juryo1',
#   'Maegashira13',
#   'Maegashira11',
#   'Juryo3',
#   'Juryo8',
#   'Juryo11',
#   'Juryo7',
#   'Juryo10',
#   'Makushita3',
#   'Juryo13',
#   'Makushita2'],
#  1325: ['Makushita3', 'Juryo13', 'Juryo9', 'Juryo10'],
#  1322: ['Makushita6', 'Makushita2', 'Juryo13', 'Juryo9'],
#  1391: ['Makushita6'],
#  26: ['Juryo10',
#   'Juryo8',
#   'Juryo5',
#   'Juryo3',
#   'Maegashira16',
#   'Maegashira9',
#   'Maegashira11',
#   'Maegashira5',
#   'Maegashira7',
#   'Maegashira13',
#   'Maegashira8',
#   'Maegashira2',
#   'Maegashira4',
#   'Maegashira6',
#   'Maegashira10',
#   'Maegashira1',
#   'Maegashira3',
#   'Maegashira14',
#   'Maegashira12',
#   'Juryo4',
#   'Juryo1',
#   'Juryo6',
#   'Juryo13'],
#  76: ['Makushita1',
#   'Juryo12',
#   'Makushita3',
#   'Makushita2',
#   'Juryo13',
#   'Juryo5',
#   'Juryo10',
#   'Juryo9',
#   'Juryo11',
#   'Juryo7',
#   'Juryo8',
#   'Juryo3'],
#  1392: ['Makushita3', 'Makushita1'],
#  91: ['Makushita1',
#   'Juryo12',
#   'Juryo8',
#   'Juryo11',
#   'Juryo7',
#   'Juryo10',
#   'Juryo9',
#   'Juryo6',
#   'Juryo3',
#   'Juryo2',
#   'Juryo5',
#   'Juryo4'],
#  1289: ['Makushita2',
#   'Makushita3',
#   'Juryo12',
#   'Makushita5',
#   'Juryo13',
#   'Juryo9',
#   'Juryo11',
#   'Juryo8',
#   'Juryo7',
#   'Juryo4',
#   'Juryo2',
#   'Juryo3',
#   'Maegashira14',
#   'Maegashira9',
#   'Maegashira15',
#   'Maegashira13',
#   'Maegashira12'],
#  209: ['Makushita3', 'Makushita1', 'Juryo10', 'Juryo3', 'Juryo13'],
#  34: ['Makushita4',
#   'Juryo11',
#   'Juryo4',
#   'Juryo12',
#   'Juryo9',
#   'Juryo8',
#   'Juryo1',
#   'Maegashira15',
#   'Maegashira11',
#   'Maegashira5',
#   'Maegashira9',
#   'Maegashira12',
#   'Maegashira10',
#   'Maegashira2',
#   'Maegashira3',
#   'Maegashira4',
#   'Maegashira8',
#   'Maegashira13',
#   'Maegashira16',
#   'Juryo2',
#   'Juryo3',
#   'Maegashira14',
#   'Maegashira1',
#   'Juryo5',
#   'Juryo6'],
#  52: ['Juryo13',
#   'Juryo7',
#   'Juryo2',
#   'Juryo1',
#   'Maegashira16',
#   'Maegashira10',
#   'Maegashira2',
#   'Komusubi',
#   'Maegashira5',
#   'Maegashira8',
#   'Maegashira4',
#   'Maegashira11',
#   'Maegashira7',
#   'Maegashira13',
#   'Maegashira15',
#   'Maegashira14',
#   'Juryo12',
#   'Juryo5',
#   'Juryo8',
#   'Juryo6',
#   'Juryo3',
#   'Juryo11',
#   'Juryo9',
#   'Juryo4',
#   'Juryo10'],
#  1328: ['Juryo13', 'Makushita1'],
#  25: ['Makushita2',
#   'Juryo12',
#   'Juryo5',
#   'Juryo2',
#   'Juryo3',
#   'Juryo1',
#   'Maegashira14',
#   'Maegashira11',
#   'Maegashira8',
#   'Maegashira2',
#   'Komusubi',
#   'Maegashira1',
#   'Maegashira3',
#   'Maegashira10',
#   'Maegashira12',
#   'Maegashira9',
#   'Maegashira13',
#   'Maegashira5',
#   'Maegashira7',
#   'Maegashira6',
#   'Juryo8',
#   'Juryo13',
#   'Makushita3'],
#  1393: ['Makushita3'],
#  1394: ['Makushita3'],
#  59: ['Makushita4',
#   'Juryo13',
#   'Makushita3',
#   'Makushita1',
#   'Juryo11',
#   'Juryo6',
#   'Juryo2',
#   'Juryo10',
#   'Juryo5',
#   'Juryo3',
#   'Juryo12',
#   'Juryo8',
#   'Juryo4'],
#  36: ['Makushita2',
#   'Juryo12',
#   'Juryo9',
#   'Makushita5',
#   'Juryo13',
#   'Juryo11',
#   'Juryo7',
#   'Juryo3',
#   'Juryo1',
#   'Maegashira16',
#   'Maegashira11',
#   'Maegashira8',
#   'Maegashira13',
#   'Maegashira12',
#   'Maegashira7',
#   'Maegashira5',
#   'Maegashira10',
#   'Maegashira4',
#   'Maegashira2',
#   'Maegashira3',
#   'Maegashira15',
#   'Maegashira14',
#   'Juryo5'],
#  20: ['Makushita1',
#   'Juryo13',
#   'Juryo12',
#   'Juryo8',
#   'Juryo11',
#   'Juryo3',
#   'Juryo5',
#   'Maegashira16',
#   'Juryo4',
#   'Juryo2',
#   'Juryo1',
#   'Juryo6',
#   'Maegashira15',
#   'Maegashira11',
#   'Maegashira14',
#   'Maegashira7',
#   'Maegashira10',
#   'Maegashira1',
#   'Maegashira6',
#   'Maegashira3',
#   'Maegashira8',
#   'Maegashira2',
#   'Maegashira4',
#   'Maegashira5',
#   'Maegashira12'],
#  1318: ['Makushita4', 'Makushita2', 'Juryo11'],
#  6: ['Juryo9',
#   'Juryo5',
#   'Maegashira15',
#   'Maegashira11',
#   'Maegashira3',
#   'Sekiwake',
#   'Komusubi',
#   'Maegashira4',
#   'Maegashira1',
#   'Maegashira6',
#   'Maegashira2',
#   'Ozeki'],
#  1395: ['Makushita2', 'Makushita5', 'Makushita1'],
#  372: ['Makushita4', 'Juryo12', 'Juryo13', 'Juryo9'],
#  178: ['Makushita4', 'Makushita3', 'Makushita5'],
#  238: ['Makushita5', 'Juryo13', 'Makushita3'],
#  191: ['Makushita2', 'Juryo11', 'Juryo13'],
#  144: ['Makushita4',
#   'Makushita1',
#   'Juryo12',
#   'Makushita2',
#   'Juryo13',
#   'Juryo8',
#   'Juryo11',
#   'Juryo10'],
#  145: ['Makushita6',
#   'Makushita3',
#   'Makushita2',
#   'Juryo12',
#   'Juryo6',
#   'Juryo4',
#   'Juryo9',
#   'Juryo10',
#   'Juryo11',
#   'Juryo8',
#   'Juryo1',
#   'Maegashira14',
#   'Maegashira9',
#   'Juryo2',
#   'Juryo7',
#   'Juryo3',
#   'Juryo5',
#   'Maegashira17',
#   'Juryo13',
#   'Makushita1'],
#  174: ['Juryo10',
#   'Juryo8',
#   'Juryo11',
#   'Juryo7',
#   'Makushita1',
#   'Juryo6',
#   'Juryo9',
#   'Makushita3'],
#  1316: ['Makushita4', 'Makushita1', 'Juryo12'],
#  143: ['Makushita3', 'Makushita2', 'Juryo13'],
#  108: ['Makushita3'],
#  54: ['Makushita4',
#   'Makushita2',
#   'Makushita6',
#   'Juryo12',
#   'Juryo10',
#   'Juryo7',
#   'Juryo9',
#   'Juryo4',
#   'Makushita1',
#   'Juryo11',
#   'Juryo6',
#   'Juryo3',
#   'Juryo1',
#   'Maegashira13',
#   'Maegashira9',
#   'Maegashira14',
#   'Maegashira15',
#   'Maegashira12'],
#  188: ['Makushita3'],
#  134: ['Makushita3',
#   'Makushita2',
#   'Makushita1',
#   'Juryo13',
#   'Juryo10',
#   'Juryo9',
#   'Juryo12'],
#  29: ['Makushita1',
#   'Juryo12',
#   'Makushita3',
#   'Juryo13',
#   'Juryo9',
#   'Juryo8',
#   'Juryo6',
#   'Juryo7',
#   'Juryo4',
#   'Juryo2',
#   'Maegashira15',
#   'Maegashira13',
#   'Maegashira8',
#   'Maegashira11',
#   'Maegashira4',
#   'Maegashira12',
#   'Maegashira14',
#   'Maegashira5',
#   'Maegashira10',
#   'Maegashira6',
#   'Maegashira1',
#   'Maegashira3',
#   'Maegashira7',
#   'Juryo1',
#   'Maegashira9'],
#  177: ['Makushita5', 'Juryo13', 'Makushita1', 'Juryo11'],
#  66: ['Makushita2',
#   'Juryo13',
#   'Juryo9',
#   'Juryo12',
#   'Makushita3',
#   'Juryo7',
#   'Juryo5',
#   'Juryo3',
#   'Juryo11',
#   'Makushita1',
#   'Juryo10',
#   'Juryo8',
#   'Juryo6',
#   'Makushita6'],
#  138: ['Makushita4',
# ...
#   'Juryo9',
#   'Juryo7',
#   'Juryo12',
#   'Juryo14',
#   'Juryo10',
#   'Juryo5',
#   'Juryo3',
#   'Juryo4',
#   'Juryo1',
#   'Maegashira15',
#   'Maegashira16',
#   'Juryo2',
#   'Maegashira14',
#   'Juryo11',
#   'Juryo8',
#   'Juryo6'],
#  11840: ['Makushita4',
#   'Makushita5',
#   'Juryo14',
#   'Makushita3',
#   'Juryo8',
#   'Juryo2',
#   'Juryo7',
#   'Juryo6',
#   'Juryo10',
#   'Juryo11',
#   'Juryo12',
#   'Maegashira15',
#   'Juryo3',
#   'Juryo9',
#   'Makushita2',
#   'Juryo1',
#   'Maegashira14'],
#  2929: ['Makushita4',
#   'Juryo14',
#   'Juryo12',
#   'Juryo13',
#   'Juryo4',
#   'Juryo8',
#   'Juryo1',
#   'Maegashira14',
#   'Maegashira16',
#   'Juryo2',
#   'Maegashira15',
#   'Juryo9',
#   'Maegashira9',
#   'Juryo5'],
#  6596: ['Makushita3',
#   'Makushita2',
#   'Juryo13',
#   'Juryo9',
#   'Juryo14',
#   'Juryo11',
#   'Juryo6',
#   'Juryo2',
#   'Maegashira14',
#   'Maegashira9',
#   'Maegashira6',
#   'Maegashira11',
#   'Maegashira16',
#   'Juryo4',
#   'Maegashira15',
#   'Maegashira13',
#   'Maegashira17',
#   'Maegashira10',
#   'Maegashira12',
#   'Maegashira3',
#   'Maegashira2',
#   'Juryo1',
#   'Juryo7',
#   'Maegashira8',
#   'Maegashira4',
#   'Maegashira5',
#   'Maegashira1'],
#  7143: ['Makushita5',
#   'Makushita1',
#   'Makushita3',
#   'Juryo12',
#   'Juryo5',
#   'Juryo7',
#   'Juryo10',
#   'Juryo11',
#   'Juryo13',
#   'Juryo9',
#   'Maegashira13',
#   'Juryo1',
#   'Juryo6',
#   'Juryo8'],
#  7240: ['Makushita2',
#   'Makushita5',
#   'Makushita1',
#   'Juryo13',
#   'Juryo6',
#   'Maegashira12',
#   'Maegashira11',
#   'Maegashira16',
#   'Maegashira14',
#   'Maegashira13',
#   'Juryo5',
#   'Juryo1',
#   'Juryo14',
#   'Juryo7',
#   'Juryo11',
#   'Juryo12',
#   'Juryo9',
#   'Juryo3',
#   'Juryo4',
#   'Juryo2',
#   'Maegashira15',
#   'Maegashira8',
#   'Maegashira9',
#   'Maegashira5',
#   'Maegashira7',
#   'Maegashira10',
#   'Maegashira17'],
#  9077: ['Juryo11',
#   'Makushita2',
#   'Makushita4',
#   'Juryo14',
#   'Makushita1',
#   'Makushita3',
#   'Juryo13'],
#  940: ['Makushita2', 'Juryo14', 'Juryo12', 'Makushita3'],
#  12055: ['Makushita3',
#   'Juryo13',
#   'Maegashira13',
#   'Maegashira7',
#   'Maegashira10',
#   'Maegashira1',
#   'Maegashira4',
#   'Maegashira5',
#   'Maegashira8',
#   'Maegashira3',
#   'Maegashira9',
#   'Maegashira12',
#   'Maegashira11',
#   'Juryo6',
#   'Maegashira15',
#   'Maegashira6',
#   'Maegashira14',
#   'Komusubi',
#   'Maegashira2',
#   'Maegashira16'],
#  11987: ['Makushita7',
#   'Juryo9',
#   'Juryo4',
#   'Maegashira15',
#   'Maegashira16',
#   'Maegashira11',
#   'Maegashira10',
#   'Maegashira3',
#   'Maegashira4',
#   'Maegashira5',
#   'Maegashira13',
#   'Maegashira8',
#   'Maegashira2',
#   'Maegashira1',
#   'Juryo1',
#   'Maegashira7',
#   'Juryo6',
#   'Juryo7',
#   'Juryo11',
#   'Juryo10',
#   'Juryo13',
#   'Juryo8'],
#  2909: ['Makushita2',
#   'Makushita1',
#   'Makushita4',
#   'Juryo13',
#   'Juryo12',
#   'Juryo10',
#   'Juryo14',
#   'Makushita3'],
#  11927: ['Makushita4',
#   'Juryo11',
#   'Juryo3',
#   'Juryo1',
#   'Maegashira10',
#   'Maegashira9',
#   'Maegashira6',
#   'Maegashira1',
#   'Maegashira3',
#   'Maegashira2',
#   'Sekiwake',
#   'Ozeki',
#   'Juryo5',
#   'Juryo8',
#   'Maegashira17',
#   'Komusubi',
#   'Yokozuna'],
#  6445: ['Makushita4'],
#  1052: ['Makushita2'],
#  9097: ['Makushita3'],
#  6458: ['Makushita2'],
#  6646: ['Makushita2'],
#  12107: ['Makushita3',
#   'Juryo10',
#   'Juryo3',
#   'Maegashira10',
#   'Sekiwake',
#   'Maegashira1',
#   'Komusubi',
#   'Maegashira4',
#   'Maegashira3',
#   'Maegashira11',
#   'Maegashira2',
#   'Maegashira7',
#   'Maegashira13',
#   'Maegashira9',
#   'Maegashira6',
#   'Juryo5',
#   'Maegashira17',
#   'Maegashira12'],
#  11985: ['Makushita2',
#   'Juryo12',
#   'Juryo9',
#   'Juryo11',
#   'Juryo13',
#   'Juryo6',
#   'Juryo7',
#   'Juryo1',
#   'Maegashira13',
#   'Maegashira14',
#   'Juryo3',
#   'Maegashira9',
#   'Maegashira11',
#   'Maegashira16',
#   'Juryo4',
#   'Juryo2',
#   'Maegashira3',
#   'Maegashira7',
#   'Maegashira8',
#   'Maegashira10',
#   'Maegashira2',
#   'Maegashira1',
#   'Komusubi',
#   'Sekiwake',
#   'Maegashira4'],
#  8899: ['Makushita3',
#   'Juryo13',
#   'Juryo14',
#   'Juryo7',
#   'Juryo9',
#   'Makushita2',
#   'Juryo11',
#   'Juryo6',
#   'Juryo3',
#   'Juryo4',
#   'Juryo1',
#   'Maegashira15',
#   'Maegashira8',
#   'Maegashira11',
#   'Juryo8',
#   'Maegashira16',
#   'Juryo2'],
#  12051: ['Makushita2',
#   'Juryo14',
#   'Juryo11',
#   'Juryo9',
#   'Juryo12',
#   'Juryo10',
#   'Juryo8',
#   'Juryo6',
#   'Juryo5',
#   'Maegashira15',
#   'Maegashira9',
#   'Maegashira11',
#   'Maegashira8',
#   'Maegashira10',
#   'Juryo1',
#   'Maegashira12',
#   'Maegashira13',
#   'Maegashira16',
#   'Juryo3',
#   'Juryo2',
#   'Maegashira5'],
#  11764: ['Makushita4', 'Makushita1'],
#  6013: ['Makushita2',
#   'Juryo14',
#   'Juryo12',
#   'Makushita4',
#   'Makushita1',
#   'Juryo13',
#   'Juryo9',
#   'Juryo11'],
#  12026: ['Makushita2',
#   'Juryo11',
#   'Juryo7',
#   'Juryo5',
#   'Maegashira13',
#   'Maegashira15',
#   'Juryo3',
#   'Juryo2',
#   'Maegashira12',
#   'Juryo4',
#   'Juryo1',
#   'Juryo10',
#   'Maegashira16',
#   'Juryo6',
#   'Juryo8',
#   'Maegashira6',
#   'Maegashira9'],
#  7153: ['Makushita3',
#   'Juryo12',
#   'Makushita1',
#   'Juryo13',
#   'Makushita4',
#   'Juryo14',
#   'Juryo10',
#   'Juryo2',
#   'Juryo6',
#   'Juryo5',
#   'Juryo9',
#   'Juryo7',
#   'Juryo8',
#   'Maegashira14',
#   'Juryo1',
#   'Maegashira15',
#   'Maegashira10',
#   'Maegashira7',
#   'Maegashira13',
#   'Maegashira16',
#   'Maegashira9',
#   'Maegashira11',
#   'Maegashira12',
#   'Maegashira4',
#   'Maegashira8',
#   'Maegashira17'],
#  11845: ['Makushita3',
#   'Juryo14',
#   'Juryo8',
#   'Juryo2',
#   'Juryo4',
#   'Juryo5',
#   'Maegashira16',
#   'Maegashira14',
#   'Maegashira9',
#   'Maegashira11',
#   'Maegashira4',
#   'Maegashira6',
#   'Maegashira12',
#   'Maegashira8',
#   'Maegashira13',
#   'Maegashira10',
#   'Maegashira3',
#   'Maegashira7',
#   'Juryo1',
#   'Maegashira17',
#   'Juryo3',
#   'Maegashira15'],
#  12113: ['Makushita4',
#   'Makushita3',
#   'Makushita2',
#   'Makushita5',
#   'Makushita1',
#   'Juryo12',
#   'Juryo9',
#   'Juryo10',
#   'Juryo7',
#   'Juryo5',
#   'Juryo8',
#   'Juryo6',
#   'Juryo14',
#   'Juryo11',
#   'Maegashira14',
#   'Maegashira7',
#   'Maegashira12',
#   'Maegashira15',
#   'Maegashira8',
#   'Maegashira13',
#   'Juryo1',
#   'Maegashira16',
#   'Juryo2',
#   'Juryo3',
#   'Maegashira11'],
#  12043: ['Juryo11',
#   'Juryo9',
#   'Juryo10',
#   'Juryo8',
#   'Juryo6',
#   'Juryo14',
#   'Juryo12',
#   'Makushita3',
#   'Juryo4',
#   'Juryo5',
#   'Juryo2',
#   'Maegashira14',
#   'Maegashira6',
#   'Maegashira3',
#   'Komusubi',
#   'Juryo1',
#   'Maegashira11',
#   'Maegashira13',
#   'Maegashira5',
#   'Maegashira10',
#   'Maegashira8',
#   'Maegashira7',
#   'Maegashira2',
#   'Maegashira9',
#   'Maegashira1',
#   'Maegashira15',
#   'Maegashira4'],
#  12094: ['Makushita2',
#   'Juryo12',
#   'Juryo13',
#   'Juryo10',
#   'Juryo11',
#   'Makushita1',
#   'Makushita4',
#   'Juryo14',
#   'Juryo5',
#   'Maegashira14',
#   'Maegashira7',
#   'Maegashira2',
#   'Maegashira3',
#   'Maegashira4',
#   'Maegashira10',
#   'Maegashira6',
#   'Komusubi',
#   'Maegashira5',
#   'Maegashira15',
#   'Sekiwake',
#   'Maegashira9',
#   'Maegashira1'],
#  12144: ['Makushita1',
#   'Juryo12',
#   'Makushita2',
#   'Juryo8',
#   'Juryo5',
#   'Maegashira14',
#   'Maegashira13',
#   'Maegashira7',
#   'Maegashira8',
#   'Maegashira12',
#   'Maegashira11',
#   'Maegashira9',
#   'Maegashira5',
#   'Maegashira16',
#   'Juryo7',
#   'Maegashira15',
#   'Juryo3',
#   'Juryo2'],
#  12130: ['Makushita3',
#   'Makushita2',
#   'Makushita1',
#   'Juryo12',
#   'Juryo5',
#   'Maegashira12',
#   'Maegashira6',
#   'Maegashira2',
#   'Maegashira5',
#   'Maegashira3',
#   'Sekiwake',
#   'Komusubi',
#   'Maegashira1',
#   'Maegashira7',
#   'Maegashira4',
#   'Maegashira10',
#   'Ozeki'],
#  12210: ['Makushita3',
#   'Juryo12',
#   'Juryo5',
#   'Maegashira11',
#   'Maegashira10',
#   'Maegashira13',
#   'Maegashira8',
#   'Maegashira1',
#   'Maegashira5',
#   'Komusubi',
#   'Sekiwake',
#   'Maegashira2',
#   'Maegashira3',
#   'Ozeki',
#   'Maegashira6'],
#  7156: ['Makushita7'],
#  12140: ['Juryo13', 'Makushita3'],
#  7127: ['Makushita1',
#   'Juryo9',
#   'Juryo11',
#   'Juryo12',
#   'Juryo7',
#   'Makushita3',
#   'Makushita2'],
#  8901: ['Makushita2', 'Makushita5'],
#  12040: ['Makushita2',
#   'Makushita5',
#   'Makushita3',
#   'Makushita4',
#   'Makushita1',
#   'Juryo12',
#   'Juryo13',
#   'Juryo9',
#   'Juryo6',
#   'Juryo5',
#   'Juryo3',
#   'Juryo2',
#   'Juryo1',
#   'Maegashira16',
#   'Maegashira9',
#   'Maegashira12',
#   'Maegashira15',
#   'Maegashira13',
#   'Maegashira11',
#   'Maegashira14'],
#  11785: ['Makushita3',
#   'Juryo12',
#   'Juryo10',
#   'Juryo2',
#   'Juryo3',
#   'Maegashira12',
#   'Maegashira10',
#   'Maegashira6',
#   'Maegashira7',
#   'Maegashira2',
#   'Maegashira5',
#   'Maegashira8',
#   'Maegashira15',
#   'Maegashira14',
#   'Maegashira17',
#   'Juryo1',
#   'Maegashira16',
#   'Maegashira13',
#   'Maegashira11'],
#  12226: ['Makushita2',
#   'Juryo13',
#   'Juryo8',
#   'Juryo1',
#   'Juryo5',
#   'Juryo3',
#   'Maegashira12',
#   'Maegashira10',
#   'Maegashira4',
#   'Juryo2',
#   'Maegashira13',
#   'Maegashira6',
#   'Maegashira7',
#   'Maegashira2',
#   'Maegashira1',
#   'Maegashira3',
#   'Maegashira8'],
#  11918: ['Makushita5',
#   'Makushita2',
#   'Makushita4',
#   'Juryo14',
#   'Makushita3',
#   'Maegashira16',
#   'Maegashira13',
#   'Juryo1',
#   'Maegashira17',
#   'Juryo2',
#   'Maegashira10',
#   'Maegashira15'],
#  11868: ['Makushita3',
#   'Juryo13',
#   'Juryo14',
#   'Juryo11',
#   'Juryo12',
#   'Juryo9',
#   'Makushita1',
#   'Juryo10',
#   'Juryo8',
#   'Juryo5',
#   'Juryo1',
#   'Maegashira14',
#   'Maegashira15',
#   'Maegashira16',
#   'Maegashira9',
#   'Maegashira11',
#   'Maegashira7',
#   'Maegashira3',
#   'Maegashira8',
#   'Maegashira12',
#   'Maegashira13',
#   'Maegashira10'],
#  11943: ['Makushita1', 'Juryo11', 'Juryo12', 'Juryo7', 'Juryo6', 'Juryo3'],
#  12191: ['Juryo13',
#   'Juryo6',
#   'Juryo9',
#   'Juryo3',
#   'Maegashira12',
#   'Maegashira13',
#   'Maegashira7',
#   'Maegashira1',
#   'Maegashira5',
#   'Komusubi',
#   'Maegashira3',
#   'Maegashira10',
#   'Sekiwake',
#   'Ozeki'],
#  12239: ['Makushita1',
#   'Juryo13',
#   'Juryo6',
#   'Maegashira11',
#   'Maegashira8',
#   'Maegashira5',
#   'Maegashira7',
#   'Maegashira2',
#   'Maegashira3',
#   'Maegashira1',
#   'Maegashira6',
#   'Maegashira9',
#   'Maegashira16',
#   'Komusubi',
#   'Maegashira4',
#   'Maegashira12'],
#  12024: ['Juryo14',
#   'Makushita5',
#   'Makushita2',
#   'Makushita3',
#   'Juryo11',
#   'Juryo7',
#   'Juryo8',
#   'Juryo9',
#   'Juryo1',
#   'Maegashira12',
#   'Maegashira6',
#   'Maegashira10',
#   'Maegashira14',
#   'Maegashira16',
#   'Maegashira11',
#   'Maegashira15',
#   'Maegashira17',
#   'Maegashira3',
#   'Maegashira9',
#   'Maegashira7',
#   'Maegashira8'],
#  12292: ['Makushita1',
#   'Juryo12',
#   'Juryo6',
#   'Juryo4',
#   'Maegashira16',
#   'Juryo5',
#   'Maegashira15',
#   'Juryo3',
#   'Maegashira14',
#   'Maegashira11',
#   'Maegashira3',
#   'Maegashira9',
#   'Maegashira2',
#   'Maegashira10',
#   'Maegashira1',
#   'Maegashira4',
#   'Maegashira12',
#   'Juryo1',
#   'Maegashira13'],
#  11946: ['Makushita3',
#   'Juryo14',
#   'Juryo11',
#   'Juryo8',
#   'Juryo4',
#   'Juryo3',
#   'Maegashira16',
#   'Juryo2',
#   'Maegashira15',
#   'Maegashira12',
#   'Maegashira11',
#   'Maegashira7',
#   'Maegashira4',
#   'Maegashira10',
#   'Maegashira2',
#   'Maegashira5',
#   'Maegashira17',
#   'Juryo1',
#   'Maegashira13',
#   'Maegashira3',
#   'Komusubi',
#   'Sekiwake',
#   'Maegashira6'],
#  12273: ['Makushita1',
#   'Juryo13',
#   'Juryo9',
#   'Juryo7',
#   'Juryo8',
#   'Juryo3',
#   'Maegashira14',
#   'Maegashira17',
#   'Maegashira16',
#   'Maegashira11',
#   'Juryo2',
#   'Juryo4',
#   'Maegashira15',
#   'Juryo1',
#   'Maegashira13'],
#  11947: ['Juryo12', 'Juryo13', 'Juryo10'],
#  11965: ['Makushita3'],
#  12141: ['Makushita5'],
#  12077: ['Makushita4',
#   'Makushita1',
#   'Juryo14',
#   'Juryo11',
#   'Juryo10',
#   'Juryo8',
#   'Juryo2',
#   'Juryo5',
#   'Juryo4',
#   'Maegashira10',
#   'Maegashira17'],
#  12291: ['Juryo12',
#   'Juryo7',
#   'Juryo5',
#   'Maegashira16',
#   'Maegashira11',
#   'Maegashira13',
#   'Maegashira12',
#   'Maegashira5',
#   'Maegashira8',
#   'Maegashira1',
#   'Maegashira2',
#   'Komusubi',
#   'Sekiwake',
#   'Ozeki',
#   'Juryo1',
#   'Maegashira14',
#   'Maegashira4'],
#  12203: ['Makushita3',
#   'Makushita2',
#   'Juryo14',
#   'Makushita1',
#   'Juryo13',
#   'Juryo10',
#   'Juryo11',
#   'Juryo12',
#   'Juryo6',
#   'Juryo8',
#   'Juryo2',
#   'Maegashira14',
#   'Maegashira4',
#   'Maegashira7',
#   'Maegashira8',
#   'Maegashira2',
#   'Maegashira3',
#   'Maegashira9',
#   'Maegashira5',
#   'Maegashira6',
#   'Maegashira1',
#   'Komusubi'],
#  11972: ['Makushita3', 'Juryo14', 'Juryo12', 'Makushita2', 'Makushita1'],
#  12425: ['Juryo13',
#   'Juryo14',
#   'Makushita1',
#   'Juryo11',
#   'Juryo12',
#   'Juryo8',
#   'Juryo2',
#   'Juryo1',
#   'Maegashira13',
#   'Maegashira10',
#   'Maegashira12',
#   'Maegashira15',
#   'Juryo4'],
#  11855: ['Makushita3',
#   'Juryo13',
#   'Juryo9',
#   'Juryo6',
#   'Juryo3',
#   'Juryo4',
#   'Maegashira14',
#   'Maegashira13',
#   'Juryo2',
#   'Maegashira12',
#   'Maegashira9',
#   'Maegashira2',
#   'Maegashira1',
#   'Sekiwake',
#   'Komusubi',
#   'Maegashira4',
#   'Maegashira10',
#   'Maegashira11',
#   'Maegashira8'],
#  12320: ['Makushita3', 'Makushita4', 'Juryo14', 'Juryo3', 'Juryo2'],
#  12406: ['Makushita4',
#   'Juryo13',
#   'Juryo10',
#   'Juryo9',
#   'Juryo11',
#   'Juryo12',
#   'Juryo6',
#   'Juryo4',
#   'Juryo1',
#   'Juryo3',
#   'Maegashira16',
#   'Maegashira15',
#   'Maegashira17',
#   'Juryo2'],
#  12285: ['Makushita10', 'Makushita3', 'Juryo14'],
#  12412: ['Juryo14',
#   'Makushita2',
#   'Juryo13',
#   'Juryo10',
#   'Juryo8',
#   'Juryo2',
#   'Maegashira14',
#   'Maegashira11',
#   'Maegashira6',
#   'Maegashira5',
#   'Maegashira4',
#   'Maegashira9',
#   'Juryo1',
#   'Juryo4',
#   'Juryo3'],
#  12076: ['Juryo14', 'Makushita3', 'Juryo13', 'Makushita2', 'Juryo12'],
#  12370: ['Makushita1',
#   'Juryo14',
#   'Juryo12',
#   'Juryo7',
#   'Juryo6',
#   'Juryo5',
#   'Juryo2',
#   'Juryo4',
#   'Juryo3',
#   'Maegashira16',
#   'Maegashira14',
#   'Maegashira8',
#   'Maegashira1',
#   'Maegashira2',
#   'Komusubi',
#   'Maegashira3',
#   'Sekiwake'],
#  12255: ['Makushita5',
#   'Makushita1',
#   'Juryo12',
#   'Juryo11',
#   'Juryo14',
#   'Juryo8',
#   'Juryo9',
#   'Juryo10'],
#  12369: ['Makushita1'],
#  12015: ['Makushita2', 'Juryo13'],
#  12362: ['Makushita3',
#   'Juryo13',
#   'Juryo9',
#   'Maegashira17',
#   'Maegashira15',
#   'Maegashira14',
#   'Maegashira13',
#   'Maegashira8',
#   'Juryo3'],
#  12231: ['Makushita3',
#   'Makushita1',
#   'Juryo14',
#   'Juryo11',
#   'Juryo9',
#   'Juryo4',
#   'Maegashira17',
#   'Maegashira8',
#   'Maegashira3',
#   'Maegashira5',
#   'Maegashira1',
#   'Maegashira4',
#   'Maegashira6',
#   'Maegashira2',
#   'Komusubi',
#   'Sekiwake',
#   'Ozeki'],
#  12427: ['Makushita4',
#   'Juryo14',
#   'Juryo4',
#   'Maegashira13',
#   'Maegashira9',
#   'Maegashira7',
#   'Maegashira3'],
#  7111: ['Makushita2', 'Makushita1', 'Juryo13'],
#  11949: ['Makushita2'],
#  12367: ['Makushita2', 'Makushita1', 'Makushita4', 'Juryo12'],
#  11980: ['Makushita3',
#   'Juryo10',
#   'Makushita1',
#   'Makushita5',
#   'Juryo3',
#   'Juryo1',
#   'Maegashira15',
#   'Maegashira9',
#   'Maegashira6',
#   'Maegashira4',
#   'Komusubi',
#   'Sekiwake'],
#  11809: ['Makushita2', 'Juryo4', 'Maegashira16', 'Maegashira17'],
#  12270: ['Makushita2',
#   'Juryo14',
#   'Juryo11',
#   'Juryo2',
#   'Maegashira18',
#   'Maegashira13',
#   'Maegashira14',
#   'Maegashira15',
#   'Maegashira8',
#   'Maegashira11',
#   'Maegashira3',
#   'Maegashira6',
#   'Maegashira2',
#   'Maegashira1',
#   'Komusubi'],
#  12470: ['Makushita3', 'Juryo13', 'Juryo3'],
#  12451: ['Makushita2',
#   'Makushita5',
#   'Maegashira16',
#   'Maegashira13',
#   'Maegashira14',
#   'Maegashira9',
#   'Maegashira5',
#   'Maegashira1',
#   'Maegashira6',
#   'Komusubi',
#   'Sekiwake'],
#  12075: ['Makushita4', 'Juryo14'],
#  12351: ['Makushita3',
#   'Maegashira17',
#   'Maegashira10',
#   'Maegashira5',
#   'Maegashira4',
#   'Maegashira3',
#   'Maegashira8'],
#  12449: ['Makushita4',
#   'Maegashira15',
#   'Maegashira12',
#   'Maegashira5',
#   'Maegashira3',
#   'Maegashira11',
#   'Juryo2',
#   'Maegashira14',
#   'Maegashira9',
#   'Maegashira13'],
#  12352: ['Juryo2',
#   'Maegashira14',
#   'Maegashira10',
#   'Maegashira16',
#   'Maegashira11',
#   'Maegashira1',
#   'Maegashira3',
#   'Maegashira5'],
#  12453: ['Maegashira18',
#   'Juryo1',
#   'Maegashira14',
#   'Maegashira15',
#   'Maegashira13',
#   'Maegashira8',
#   'Maegashira16',
#   'Maegashira6'],
#  12117: ['Juryo1', 'Juryo2', 'Maegashira14', 'Juryo3', 'Maegashira16'],
#  12575: ['Juryo2', 'Juryo3', 'Juryo1', 'Juryo4'],
#  12484: ['Juryo4'],
#  12314: ['Maegashira16', 'Maegashira10', 'Maegashira9', 'Maegashira5'],
#  12664: ['Juryo3', 'Maegashira15', 'Juryo1'],
#  12646: ['Juryo2', 'Maegashira15', 'Maegashira11', 'Maegashira6'],
#  12717: ['Juryo3', 'Juryo4'],
#  12721: ['Juryo5', 'Maegashira14', 'Maegashira5', 'Maegashira10'],
#  12162: ['Juryo3', 'Juryo1', 'Maegashira14'],
#  12688: ['Juryo1', 'Maegashira13'],
#  12796: ['Maegashira17'],
#  12516: ['Juryo2'],
#  12013: ['Juryo3'],
#  11976: ['Juryo5']}

# %%
# This just lists anyone who has ever been a yokozuna.
for key, value in rank_dict.items():
    for rikishi_id in rank_dict.values():
        if "Yokozuna" in value:
            print(key, value)
# Out:
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# 1350 ['Juryo2', 'Maegashira9', 'Maegashira2', 'Maegashira5', 'Komusubi', 'Maegashira3', 'Sekiwake', 'Maegashira1', 'Ozeki', 'Yokozuna']
# ...
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']
# 11927 ['Makushita4', 'Juryo11', 'Juryo3', 'Juryo1', 'Maegashira10', 'Maegashira9', 'Maegashira6', 'Maegashira1', 'Maegashira3', 'Maegashira2', 'Sekiwake', 'Ozeki', 'Juryo5', 'Juryo8', 'Maegashira17', 'Komusubi', 'Yokozuna']

# %%
# This next section trims down each list of ranks that a wrestler has had, keeping only the highest rank. So the value of the dictionary key,
# which includes a list of multiple ranks, is now converted into a list with a single entry, that of the highest rank achieved.
# I originally wanted this loop to get rid of the list completely, but that caused problems with exact matching between an element in a list
# using "in value" and non-exact matching using the same "in value" when the item had been converted into a string. The only way I found to
# prevent this kind of erroneous overriding was to keep the adjusted value as a list. 

rank_dict_temp = {}

for key, value in rank_dict.items():
    for rikishi_id in rank_dict.values():
        if "Yokozuna" in value:
            value = ["Yokozuna"]
            best_rank = "Yokozuna"
        elif "Ozeki" in value:
            value = ["Ozeki"]
            best_rank = "Ozeki"
        elif "Sekiwake" in value:
            value = ["Sekiwake"]
            best_rank = "Sekiwake"
        elif "Komusubi" in value:
            value = ["Komusubi"]
            best_rank = "Komusubi"
        elif "Maegashira1" in value:
            value = ["Maegashira1"]
            best_rank = "Maegashira1"
        elif "Maegashira2" in value:
            value = ["Maegashira2"]
            best_rank = "Maegashira2"
        elif "Maegashira3" in value:
            value = ["Maegashira3"]
            best_rank = "Maegashira3"
        elif "Maegashira4" in value:
            value = ["Maegashira4"]
            best_rank = "Maegashira4"
        elif "Maegashira5" in value:
            value = ["Maegashira5"]
            best_rank = "Maegashira5"
        elif "Maegashira6" in value:
            value = ["Maegashira6"]
            best_rank = "Maegashira6"
        elif "Maegashira7" in value:
            value = ["Maegashira7"]
            best_rank = "Maegashira7"
        elif "Maegashira8" in value:
            value = ["Maegashira8"]
            best_rank = "Maegashira8"
        elif "Maegashira9" in value:
            value = ["Maegashira9"]
            best_rank = "Maegashira9"
        elif "Maegashira10" in value:
            value = ["Maegashira10"]
            best_rank = "Maegashira10"
        elif "Maegashira11" in value:
            value = ["Maegashira11"]
            best_rank = "Maegashira11"
        elif "Maegashira12" in value:
            value = ["Maegashira12"]
            best_rank = "Maegashira12"
        elif "Maegashira13" in value:
            value = ["Maegashira13"]
            best_rank = "Maegashira13"
        elif "Maegashira14" in value:
            value = ["Maegashira14"]
            best_rank = "Maegashira14"
        elif "Maegashira15" in value:
            value = ["Maegashira15"]
        elif "Maegashira16" in value:
            value = ["Maegashira16"]
        elif "Maegashira17" in value:
            value = ["Maegashira17"]
        elif "Maegashira18" in value:
            value = ["Maegashira18"]
        elif "Maegashira19" in value:
            value = ["Maegashira19"]
        elif "Maegashira20" in value:
            value = ["Maegashira20"]
        elif "Maegashira21" in value:
            value = ["Maegashira21"]
        elif "Maegashira22" in value:
            value = ["Maegashira22"]
        elif "Maegashira23" in value:
            value = ["Maegashira23"]
        elif "Maegashira24" in value:
            value = ["Maegashira24"]
        elif "Maegashira25" in value:
            value = ["Maegashira25"]
        elif "Maegashira26" in value:
            value = ["Maegashira26"]
        elif "Maegashira27" in value:
            value = ["Maegashira27"]
        elif "Maegashira28" in value:
            value = ["Maegashira28"]
        elif "Maegashira29" in value:
            value = ["Maegashira29"]
        elif "Maegashira30" in value:
            value = ["Maegashira30"]
        elif "Juryo1" in value:
            value = ["Juryo1"]
        elif "Juryo2" in value:
            value = ["Juryo2"]
        elif "Juryo3" in value:
            value = ["Juryo3"]
        elif "Juryo4" in value:
            value = ["Juryo4"]
        elif "Juryo5" in value:
            value = ["Juryo5"]
        elif "Juryo6" in value:
            value = ["Juryo6"]
        elif "Juryo7" in value:
            value = ["Juryo7"]
        elif "Juryo8" in value:
            value = ["Juryo8"]
        elif "Juryo9" in value:
            value = ["Juryo9"]
        elif "Juryo10" in value:
            value = ["Juryo10"]
        elif "Juryo11" in value:
            value = ["Juryo11"]
        elif "Juryo12" in value:
            value = ["Juryo12"]
        elif "Juryo13" in value:
            value = ["Juryo13"]
        elif "Juryo14" in value:
            value = ["Juryo14"]
        elif "Juryo15" in value:
            value = ["Juryo15"]
        elif "Juryo16" in value:
            value = ["Juryo16"]
        elif "Juryo17" in value:
            value = ["Juryo17"]
        elif "Juryo18" in value:
            value = ["Juryo18"]
        elif "Juryo19" in value:
            value = ["Juryo19"]
        elif "Juryo20" in value:
            value = ["Juryo20"]
        elif "Juryo21" in value:
            value = ["Juryo21"]
        elif "Juryo22" in value:
            value = ["Juryo22"]
        elif "Juryo23" in value:
            value = ["Juryo23"]
        elif "Juryo24" in value:
            value = ["Juryo24"]
        elif "Juryo25" in value:
            value = ["Juryo25"]
        elif "Juryo26" in value:
            value = ["Juryo26"]
        elif "Juryo27" in value:
            value = ["Juryo27"]
        elif "Juryo28" in value:
            value = ["Juryo28"]
        elif "Juryo29" in value:
            value = ["Juryo29"]
        elif "Juryo30" in value:
            value = ["Juryo30"]
        elif "Makushita1" in value:
            value = ["Makushita1"]
        elif "Makushita2" in value:
            value = ["Makushita2"]
        elif "Makushita3" in value:
            value = ["Makushita3"]
        elif "Makushita4" in value:
            value = ["Makushita4"]
        elif "Makushita5" in value:
            value = ["Makushita5"]
        elif "Makushita6" in value:
            value = ["Makushita6"]
        elif "Makushita7" in value:
            value = ["Makushita7"]
        elif "Makushita8" in value:
            value = ["Makushita8"]
        elif "Makushita9" in value:
            value = ["Makushita9"]
        elif "Makushita10" in value:
            value = ["Makushita10"]
        elif "Makushita11" in value:
            value = ["Makushita11"]
        elif "Makushita12" in value:
            value = ["Makushita12"]
        elif "Makushita13" in value:
            value = ["Makushita13"]
        elif "Makushita14" in value:
            value = ["Makushita14"]
        elif "Makushita15" in value:
            value = ["Makushita15"]
        elif "Makushita16" in value:
            value = ["Makushita16"]
        elif "Makushita17" in value:
            value = ["Makushita17"]
        elif "Makushita18" in value:
            value = ["Makushita18"]
        elif "Makushita19" in value:
            value = ["Makushita19"]
        elif "Makushita20" in value:
            value = ["Makushita20"]
        elif "Makushita21" in value:
            value = ["Makushita21"]
        elif "Makushita22" in value:
            value = ["Makushita22"]
        elif "Makushita23" in value:
            value = ["Makushita23"]
        elif "Makushita24" in value:
            value = ["Makushita24"]
        elif "Makushita25" in value:
            value = ["Makushita25"]
        elif "Makushita26" in value:
            value = ["Makushita26"]
        elif "Makushita27" in value:
            value = ["Makushita27"]
        elif "Makushita28" in value:
            value = ["Makushita28"]
        elif "Makushita29" in value:
            value = ["Makushita29"]
        elif "Makushita30" in value:
            value = ["Makushita30"]
    rank_dict_temp[key] = value
    
# In what follows, I create a dictionary that features a wrestler's ID as key and top rank as value, this value cleaned up to be a string instead of a list.
# However, in the next cell, I figured out a way to work with rank_dict_temp, so this new dictionary is not neccessary. Still, I'm leaving the code here
# in case I need to reference it in the future.

# top_rank_dict = {}
# for key, value in rank_dict_temp.items():
#     value_to_string = value[0]
#     top_rank_dict[key] = value_to_string

print(top_rank_dict)
# Out:
# {4140: 'Maegashira13', 4306: 'Juryo7', 1337: 'Sekiwake', 4323: 'Juryo7', 4097: 'Juryo11', 4319: 'Juryo2', 4109: 'Juryo10', 4129: 'Juryo11', 4111: 'Juryo10', 4130: 'Maegashira6', 1302: 'Komusubi', 4318: 'Juryo7', 1361: 'Komusubi', 4316: 'Juryo2', 1385: 'Maegashira12', 4125: 'Juryo6', 1347: 'Komusubi', 4311: 'Juryo2', 1332: 'Sekiwake', 4322: 'Juryo5', 1380: 'Maegashira2', 4128: 'Maegashira14', 1350: 'Yokozuna', 1359: 'Sekiwake', 4087: 'Juryo2', 4091: 'Maegashira11', 1342: 'Yokozuna', 4103: 'Maegashira14', 4122: 'Maegashira14', 4131: 'Maegashira2', 1348: 'Komusubi', 4124: 'Maegashira2', 1334: 'Maegashira1', 4118: 'Maegashira8', 1345: 'Komusubi', 4100: 'Maegashira1', 1352: 'Sekiwake', 4132: 'Maegashira3', 4050: 'Maegashira2', 4117: 'Maegashira4', 1378: 'Sekiwake', 4133: 'Maegashira2', 1338: 'Sekiwake', 4077: 'Maegashira1', 1375: 'Sekiwake', 4102: 'Sekiwake', 1369: 'Sekiwake', 4107: 'Maegashira3', 4099: 'Komusubi', 4126: 'Komusubi', 1374: 'Komusubi', 1379: 'Ozeki', 4078: 'Maegashira1', 4127: 'Ozeki', 1363: 'Ozeki', 4112: 'Ozeki', 4094: 'Maegashira1', 4104: 'Yokozuna', 4095: 'Yokozuna', 4116: 'Sekiwake', 1353: 'Sekiwake', 4080: 'Yokozuna', 1354: 'Yokozuna', 4134: 'Komusubi', 1381: 'Juryo8', 1364: 'Sekiwake', 1417: 'Juryo5', 4303: 'Juryo13', 4119: 'Juryo13', 1451: 'Juryo3', 1317: 'Maegashira1', 1339: 'Yokozuna', 1356: 'Maegashira8', 4324: 'Juryo11', 5070: 'Makushita3', 1301: 'Ozeki', 1496: 'Juryo9', 6773: 'Makushita4', 1373: 'Juryo13', 4135: 'Juryo12', 6780: 'Makushita8', 4329: 'Juryo13', 4136: 'Yokozuna', 4325: 'Juryo13', 1362: 'Maegashira13', 4138: 'Maegashira11', 4328: 'Juryo9', 4137: 'Maegashira3', 1423: 'Juryo4', 4139: 'Maegashira4', 1376: 'Komusubi', 1358: 'Maegashira14', 1383: 'Juryo11', 1377: 'Juryo6', 28: 'Sekiwake', 4327: 'Juryo12', 1287: 'Ozeki', 4312: 'Makushita5', 1372: 'Komusubi', 1292: 'Sekiwake', 4326: 'Juryo12', 1430: 'Makushita4', 1653: 'Makushita1', 1311: 'Maegashira3', 4330: 'Juryo8', 5064: 'Makushita2', 33: 'Sekiwake', 4334: 'Juryo5', 4315: 'Makushita4', 5063: 'Makushita6', 49: 'Komusubi', 6775: 'Makushita9', 4321: 'Juryo7', 1333: 'Maegashira1', 1470: 'Juryo13', 4331: 'Juryo11', 1367: 'Maegashira1', 4333: 'Juryo11', 4991: 'Makushita1', 1335: 'Komusubi', 4332: 'Juryo4', 1476: 'Juryo4', 1390: 'Makushita5', 1310: 'Maegashira2', 1397: 'Juryo1', 37: 'Komusubi', 1303: 'Sekiwake', 4335: 'Juryo11', 1366: 'Maegashira12', 1365: 'Juryo1', 1315: 'Maegashira1', 23: 'Sekiwake', 1330: 'Komusubi', 4336: 'Juryo6', 30: 'Maegashira3', 1331: 'Maegashira14', 1370: 'Juryo9', 4988: 'Makushita2', 1313: 'Maegashira13', 1295: 'Komusubi', 1442: 'Makushita4', 60: 'Maegashira1', 1489: 'Makushita4', 1357: 'Juryo10', 1360: 'Juryo13', 4141: 'Maegashira2', 1329: 'Juryo2', 1425: 'Makushita2', 1349: 'Juryo4', 5123: 'Makushita4', 9: 'Sekiwake', 12: 'Sekiwake', 1433: 'Juryo9', 1355: 'Juryo5', 1512: 'Juryo12', 1296: 'Maegashira1', 1299: 'Maegashira4', 51: 'Komusubi', 1297: 'Juryo4', 1463: 'Makushita5', 1326: 'Maegashira12', 1368: 'Maegashira10', 4337: 'Juryo13', 1520: 'Juryo5', 1321: 'Juryo3', 1288: 'Maegashira1', 1418: 'Makushita1', 1319: 'Maegashira15', 1314: 'Maegashira13', 55: 'Juryo2', 48: 'Maegashira2', 1305: 'Maegashira9', 44: 'Maegashira1', 5051: 'Makushita5', 1290: 'Sekiwake', 1285: 'Maegashira14', 1327: 'Juryo4', 1382: 'Makushita2', 18: 'Sekiwake', 1371: 'Juryo8', 1309: 'Maegashira8', 1384: 'Makushita2', 1386: 'Makushita3', 3: 'Yokozuna', 2: 'Yokozuna', 1387: 'Makushita1', 82: 'Juryo4', 16: 'Maegashira2', 1: 'Yokozuna', 1323: 'Juryo5', 77: 'Juryo5', 1307: 'Maegashira2', 157: 'Komusubi', 14: 'Sekiwake', 1351: 'Juryo7', 53: 'Maegashira4', 1294: 'Komusubi', 45: 'Komusubi', 1324: 'Maegashira15', 160: 'Maegashira6', 42: 'Komusubi', 5: 'Ozeki', 1286: 'Komusubi', 1341: 'Juryo12', 62: 'Maegashira3', 1306: 'Maegashira14', 4: 'Yokozuna', 1336: 'Makushita2', 1388: 'Makushita1', 87: 'Komusubi', 15: 'Komusubi', 1344: 'Juryo11', 1346: 'Juryo11', 159: 'Makushita2', 1340: 'Juryo9', 140: 'Juryo7', 7: 'Ozeki', 11: 'Maegashira1', 24: 'Maegashira1', 73: 'Juryo ...

# %%
# This creates a dataframe with each wrestler's ID as well as the top rank achieved by that wrestler.
top_rank_df = pd.DataFrame.from_dict(rank_dict_temp, orient="index")
top_rank_df = top_rank_df.reset_index()
top_rank_df.columns = ["id", "top_rank"]
top_rank_df
# Out:
#         id      top_rank
# 0     4140  Maegashira13
# 1     4306        Juryo7
# 2     1337      Sekiwake
# 3     4323        Juryo7
# 4     4097       Juryo11
# ..     ...           ...
# 592  12688  Maegashira13
# 593  12796  Maegashira17
# 594  12516        Juryo2
# 595  12013        Juryo3
# 596  11976        Juryo5
#
# [597 rows x 2 columns]

# %%
# Now to merge the dataframe with the top rank to the main won-loss dataframe.
new_won_loss_df = pd.merge(new_won_loss_df, top_rank_df)
new_won_loss_df = new_won_loss_df.iloc[:, [0, 1, 2, 3, 4, 7, 5, 6]]
new_won_loss_df
# Out:
#         id     shikona  wins  losses   pct    top_rank alt_shikona2  \
# 0     1123      Hakuho  1121     212  0.84    Yokozuna         None
# 1        7        Kaio   956     642  0.60       Ozeki         Koga
# 2       89  Aminishiki   831     869  0.49    Sekiwake         None
# 3       41  Kyokutenho   827     888  0.48    Sekiwake         None
# 4       39  Wakanosato   781     692  0.53    Sekiwake       Kogawa
# ..     ...         ...   ...     ...   ...         ...          ...
# 592  11965   Tochimaru     0       1  0.00  Makushita3         None
# 593  12141       Shiba     0       1  0.00  Makushita5         None
# 594  12369      Murata     0       1  0.00  Makushita1         None
# 595  11949   Kotodaigo     0       2  0.00  Makushita2         None
# 596  12013  Shimazuumi     0       1  0.00      Juryo3         None
#
#     alt_shikona3
# 0           None
# 1           None
# 2           None
# 3           None
# 4           None
# ..           ...
# 592         None
# 593         None
# 594         None
# 595         None
# 596         None
#
# [597 rows x 8 columns]

# %%
# Every wrestler with 500+ wins in the top division.

with_500_wins = new_won_loss_df.loc[new_won_loss_df.wins >=500].sort_values(by='wins', ascending=False)
with_500_wins = with_500_wins.iloc[:, [0,1,2,3,4,5]]
with_500_wins = with_500_wins.sort_values(by='pct', ascending=False)
with_500_wins
# Out:
#        id        shikona  wins  losses   pct     top_rank
# 45   1354    Chiyonofuji   541      91  0.86     Yokozuna
# 0    1123         Hakuho  1121     212  0.84     Yokozuna
# 24    878      Asashoryu   622     164  0.79     Yokozuna
# 7       2     Takanohana   751     253  0.75     Yokozuna
# 29      1        Akebono   604     217  0.74     Yokozuna
# 10      4    Musashimaru   733     284  0.72     Yokozuna
# 55      3     Wakanohana   521     268  0.66     Yokozuna
# 6    1111     Harumafuji   752     402  0.65     Yokozuna
# 56     19     Tochiazuma   518     310  0.63        Ozeki
# 15   1219        Kakuryu   689     430  0.62     Yokozuna
# 8    1235     Kisenosato   742     472  0.61     Yokozuna
# 1       7           Kaio   956     642  0.60        Ozeki
# 42    876    Kotomitsuki   549     363  0.60        Ozeki
# 12      8    Chiyotaikai   703     494  0.59        Ozeki
# 46      6       Musoyama   540     377  0.59        Ozeki
# 16      5     Takanonami   688     500  0.58        Ozeki
# 14   1287      Konishiki   690     495  0.58        Ozeki
# 20   6468         Goeido   645     478  0.57        Ozeki
# 38   6480       Takayasu   561     437  0.56        Ozeki
# 32     31         Dejima   582     492  0.54        Ozeki
# 5    1226    Kotoshogiku   760     639  0.54        Ozeki
# 39     12    Kotonishiki   559     494  0.53     Sekiwake
# 4      39     Wakanosato   781     692  0.53     Sekiwake
# 22    842     Miyabiyama   641     583  0.52        Ozeki
# 13      9     Akinoshima   694     668  0.51     Sekiwake
# 40   1301      Kirishima   558     533  0.51        Ozeki
# 26   6599    Tochinoshin   610     585  0.51        Ozeki
# 30   6473      Tochiozan   604     582  0.51     Sekiwake
# 33   1227    Toyonoshima   582     559  0.51     Sekiwake
# 50  11784       Myogiryu   527     532  0.50     Sekiwake
# 51  11786        Aoiyama   527     531  0.50     Sekiwake
# 35   1292      Kotogaume   573     575  0.50     Sekiwake
# 28     18     Takatoriki   604     600  0.50     Sekiwake
# 17   5944      Tamawashi   685     695  0.50     Sekiwake
# 19     28      Mitoizumi   675     692  0.49     Sekiwake
# 57     60      Toyonoumi   515     544  0.49  Maegashira1
# 2      89     Aminishiki   831     869  0.49     Sekiwake
# 52    875   Takamisakari   526     549  0.49     Komusubi
# 11     13      Tosanoumi   713     731  0.49     Sekiwake
# 44     51         Daizen   542     574  0.49     Komusubi
# 59   2818      Tokitenku   504     530  0.49     Komusubi
# 25   1009     Asasekiryu   616     642  0.49     Sekiwake
# 23     14     Kotonowaka   638     673  0.49     Sekiwake
# 27   5967      Yoshikaze   605     631  0.49     Sekiwake
# 21     10    Tochinonada   644     691  0.48     Sekiwake
# 58    152    Tamanoshima   514     558  0.48     Sekiwake
# 36     17     Tamakasuga   571     620  0.48     Sekiwake
# 3      41     Kyokutenho   827     888  0.48     Sekiwake
# 37   6463       Okinoumi   566     611  0.48     Sekiwake
# 41  11728     Takarafuji   550     592  0.48     Sekiwake
# 18   1284       Takekaze   678     744  0.48     Sekiwake
# 43     23    Tochinowaka   548     602  0.48     Sekiwake
# 49     49     Misugisato   530     586  0.47     Komusubi
# 48     63       Otsukasa   531     601  0.47  Maegashira4
# 53   1302     Takamisugi   523     593  0.47     Komusubi
# 54     34      Asanowaka   522     590  0.47  Maegashira1
# 47     40          Kaiho   540     618  0.47     Komusubi
# 34     30  Kitakachidoki   575     641  0.47  Maegashira3
# 31     37    Kotoinazuma   596     666  0.47     Komusubi
# 9      33          Terao   740     855  0.46     Sekiwake

# %%
# dff = new_won_loss_df.loc[(new_won_loss_df.wins + new_won_loss_df.losses)>=500].sort_values(by='pct', ascending=False)
# dff = dff.iloc[:, [0,1,2,3,4,5]]
# dff

# dff.to_csv("data/won_loss_df.csv", index=False)
# dff
# Out:
#        id      shikona  wins  losses   pct  top_rank
# 45   1354  Chiyonofuji   541      91  0.86  Yokozuna
# 0    1123       Hakuho  1121     212  0.84  Yokozuna
# 24    878    Asashoryu   622     164  0.79  Yokozuna
# 7       2   Takanohana   751     253  0.75  Yokozuna
# 29      1      Akebono   604     217  0.74  Yokozuna
# ..    ...          ...   ...     ...   ...       ...
# 157  1369        Toryu   286     359  0.44  Sekiwake
# 134  1352      Tagaryu   334     417  0.44  Sekiwake
# 133  1347         Itai   339     426  0.44  Komusubi
# 173  1335   Takanofuji   266     350  0.43  Komusubi
# 222  4126    Sadanoumi   217     284  0.43  Komusubi
#
# [197 rows x 6 columns]

# %% [markdown]
# <!-- TO DO: re-do all those win/loss things, but with ID instead of Shikona -->
