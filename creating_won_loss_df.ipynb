# %%
import pandas as pd

results = pd.read_csv("data/results.csv", dtype={'basho': 'string', 'day': 'string', 'rikishi1_id': 'int64', 'rikishi1_rank': 'string', 'rikishi1_shikona': 'string', 'rikishi1_result': 'string', 'rikishi1_win': 'int64', 'kimarite': 'string', 'rikishi2_id': 'int64', 'rikishi2_rank': 'string', 'rikishi2_shikona': 'string', 'rikishi2_result': 'string', 'rikishi2_win': 'string'})

# %%
results
# Out:
#           basho day  rikishi1_id rikishi1_rank rikishi1_shikona  \
# 0       1983.01   1         4140          J13w      Chikubayama
# 1       1983.01   1         4306          Ms1e            Ofuji
# 2       1983.01   1         1337          J12w     Tochitsukasa
# 3       1983.01   1         4323          J13e         Shiraiwa
# 4       1983.01   1         4097          J12e       Tamakiyama
# ...         ...  ..          ...           ...              ...
# 227767  2023.07  15        11985           S1w         Daieisho
# 227768  2023.07  15        12451           S1e         Hoshoryu
# 227769  2023.07  15        12796          M17w          Hakuoho
# 227770  2023.07  15        12094           K1w              Abi
# 227771  2023.07  15        12231           O1w        Kirishima
#
#        rikishi1_result  rikishi1_win    kimarite  rikishi2_id rikishi2_rank  \
# 0            0-1 (7-8)             0    yorikiri         4306          Ms1e
# 1            1-0 (6-1)             1    yorikiri         4140          J13w
# 2            1-0 (9-6)             1   oshidashi         4323          J13e
# 3           0-1 (3-12)             0   oshidashi         1337          J12w
# 4            0-1 (8-7)             0    yorikiri         4319          J11w
# ...                ...           ...         ...          ...           ...
# 227767             9-6             0  hikiotoshi        11855           M9e
# 227768            12-3             1   uwatenage        12796          M17w
# 227769            11-4             0   uwatenage        12451           S1e
# 227770             6-9             1    yorikiri        12231           O1w
# 227771           6-7-2             0    yorikiri        12094           K1w
#
#        rikishi2_shikona rikishi2_result rikishi2_win
# 0                 Ofuji       1-0 (6-1)            1
# 1           Chikubayama       0-1 (7-8)            0
# 2              Shiraiwa      0-1 (3-12)            0
# 3          Tochitsukasa       1-0 (9-6)            1
# 4            Harunafuji      1-0 (5-10)            1
# ...                 ...             ...          ...
# 227767        Takanosho             8-7            1
# 227768          Hakuoho            11-4            0
# 227769         Hoshoryu            12-3            1
# 227770        Kirishima           6-7-2            0
# 227771              Abi             6-9            1
#
# [227772 rows x 13 columns]

# %%
# Sumo wrestlers in these datasets can best be identified by their unique ID numbers. Although each wrestler has his own name (shikona), some wrestlers
# may reuse the same name, and other wrestlers may change names during their career. Since the ID number is the one identifier that remains stable,
# this is the best identifier to which I will anchor my analysis. Here I make a quick list of unique ID numbers for later use.

rikishi_id_list = []

for i in results["rikishi1_id"].unique():

    rikishi_id_list.append(i)

# Next to make a dictionary that holds each wrestler's unique ID number as a key, with values being each name associated with that wrestler.
# The vast majority of ID numbers will only feature one name, but this will make sure to include any additional names as well.

rikishi_id_dict = {}

# Initializes a key for every number sumo["rikishi1_id"] but still only adds one shikona (wrestler name) as a value per key, overwriting old shikona.
# So while this fills out the dictionary, it remains incomplete.
for i in range(len(results)):
    rikishi_id_dict.update({results["rikishi1_id"][i]: [results["rikishi1_shikona"][i]]})


# This fills out the dictionary with all associated names.
# Easy to test on rikishi_id_dict[1111], which shows both names for this wrestler, "Ama" and "Harumafuji."
# The first entry in every names list is the *most recent* name the wrestler used. So rikishi_id_dict[1111][0] shows "Harumafuji."
# This is useful to know, because when referring to a wrestler in the present day, one generally refers to them by their most current name.
# So when we reference this dictionary to indicate a wrestler's name, we will go by their most recent name, even if they have used others in the past.
for index, row in results.iterrows():
    if row["rikishi1_shikona"] not in rikishi_id_dict[row["rikishi1_id"]]:
        rikishi_id_dict[row["rikishi1_id"]].append(row["rikishi1_shikona"])

rikishi_id_dict
# Out:
# {4140: ['Chikubayama'],
#  4306: ['Ofuji'],
#  1337: ['Tochitsukasa'],
#  4323: ['Shiraiwa'],
#  4097: ['Tamakiyama'],
#  4319: ['Harunafuji'],
#  4109: ['Kotogatake'],
#  4129: ['Hakuryuyama'],
#  4111: ['Zaonishiki'],
#  4130: ['Hachiya'],
#  1302: ['Takamisugi'],
#  4318: ['Tengoyama'],
#  1361: ['Daitetsu'],
#  4316: ['Kakureizan'],
#  1385: ['Tochiakagi'],
#  4125: ['Shinko'],
#  1347: ['Itai'],
#  4311: ['Hakuryu'],
#  1332: ['Sakahoko'],
#  4322: ['Sanofuji'],
#  1380: ['Hidanohana'],
#  4128: ['Kotochitose'],
#  1350: ['Onokuni'],
#  1359: ['Koboyama'],
#  4087: ['Wakajishi'],
#  4091: ['Washuyama'],
#  1342: ['Asahifuji'],
#  4103: ['Banryuyama'],
#  4122: ['Kurosegawa'],
#  4131: ['Tochitsurugi'],
#  1348: ['Jingaku'],
#  4124: ['Shishiho'],
#  1334: ['Wakasegawa'],
#  4118: ['Amanoyama'],
#  1345: ['Tamaryu'],
#  4100: ['Kaneshiro', 'Tochihikari'],
#  1352: ['Tagaryu'],
#  4132: ['Wakanofuji'],
#  4050: ['Takamiyama'],
#  4117: ['Misugiiso', 'Azumanada'],
#  1378: ['Hoo'],
#  4133: ['Takarakuni', 'Saisu'],
#  1338: ['Ozutsu'],
#  4077: ['Fujizakura'],
#  1375: ['Masudayama'],
#  4102: ['Aobajo'],
#  1369: ['Toryu'],
#  4107: ['Kaiki'],
#  4099: ['Kirinji'],
#  4126: ['Sadanoumi'],
#  1374: ['Kurama'],
#  1379: ['Asashio'],
#  4078: ['Oshio'],
#  4127: ['Wakashimazu'],
#  1363: ['Hokutenyu'],
#  4112: ['Kotokaze'],
#  4094: ['Onishiki'],
#  4104: ['Takanosato'],
#  4095: ['Wakanohana'],
#  4116: ['Dewanohana'],
#  1353: ['Daijuyama'],
#  4080: ['Kitanoumi'],
#  1354: ['Chiyonofuji'],
#  4134: ['Oyutaka'],
#  1381: ['Dewanoshima'],
#  1364: ['Masurao', 'Tejima'],
#  1417: ['Ichinowatari'],
#  4303: ['Suiryu'],
#  4119: ['Kotowaka'],
#  1451: ['Tochiizumi'],
#  1317: ['Hananokuni'],
#  1339: ['Hokutoumi', 'Hoshi'],
#  1356: ['Kinoarashi'],
#  4324: ['Genkaiho', 'Rinho'],
#  5070: ['Arai'],
#  1301: ['Kirishima'],
#  1496: ['Seionada'],
#  6773: ['Taigiyama'],
#  1373: ['Fukunosato'],
#  4135: ['Oko'],
#  6780: ['Tochiomi'],
#  4329: ['Fujinosato'],
#  4136: ['Futahaguro', 'Kitao'],
#  4325: ['Kiyomidake'],
#  1362: ['Onohana'],
#  4138: ['Tochimatoi'],
#  4328: ['Hanaarashi'],
#  4137: ['Fujinokawa', 'Hattori'],
#  1423: ['Wakanoumi', 'Hanaguruma', 'Hanaogi'],
#  4139: ['Koryu'],
#  1376: ['Hananoumi'],
#  1358: ['Hoshiiwato', 'Hoshikabuto'],
#  1383: ['Sekinohana'],
#  1377: ['Iwatefuji', 'Futasekaze'],
#  28: ['Mitoizumi'],
#  4327: ['Hiyama'],
#  1287: ['Konishiki'],
#  4312: ['Kotonoryu'],
#  1372: ['Maenoshin'],
#  1292: ['Kotogaume'],
#  4326: ['Hanaryu', 'Shushi'],
#  1430: ['Minenofuji'],
#  1653: ['Asahizakura'],
#  1311: ['Kototsubaki'],
#  4330: ['Wakatsukuba'],
#  5064: ['Byakuhoyama'],
#  33: ['Terao', 'Genjiyama'],
#  4334: ['Takuetsuyama'],
#  4315: ['Arashifuji', 'Fujinoiwa'],
#  5063: ['Suiseizan'],
#  49: ['Misugisato'],
#  6775: ['Hakusan'],
#  4321: ['Kaio'],
#  1333: ['Sasshunada'],
#  1470: ['Tenkoyama'],
#  4331: ['Iyozakura', 'Ichiki'],
#  1367: ['Fujinoshin', 'Fujihikari'],
#  4333: ['Tachinofuji', 'Tatsufuji'],
#  4991: ['Shishuyama'],
#  1335: ['Takanofuji'],
#  4332: ['Tochinohana'],
#  1476: ['Otaka'],
#  1390: ['Kondo', 'Toshoho'],
#  1310: ['Kirinishiki'],
#  1397: ['Ishinriki'],
#  37: ['Kotoinazuma'],
#  1303: ['Kotofuji', 'Kotoosugi'],
#  4335: ['Ojishi'],
#  1366: ['Takanomine'],
#  1365: ['Hananofuji'],
#  1315: ['Enazakura'],
#  23: ['Tochinowaka', 'Kaseda'],
#  1330: ['Ryogoku', 'Kobayashiyama'],
#  4336: ['Tamakirin', 'Taue'],
#  30: ['Kitakachidoki', 'Kuga'],
#  1331: ['Saganobori'],
#  1370: ['Morinosato', 'Takamichi'],
#  4988: ['Naruyama'],
#  1313: ['Komafudo', 'Hananowaka'],
#  1295: ['Kyokudozan'],
#  1442: ['Yuho'],
#  60: ['Toyonoumi', 'Takanohama'],
#  1489: ['Maenoarashi'],
#  1357: ['Yamanishiki', 'Yamazaki'],
#  1360: ['Oishida'],
#  4141: ['Nankairyu'],
#  1329: ['Daigaku'],
#  1425: ['Tobimaru'],
#  1349: ['Kotohakusan'],
#  5123: ['Amamifuji'],
#  9: ['Akinoshima'],
#  12: ['Kotonishiki', 'Kotomatsuzawa'],
#  1433: ['Kitafubuki'],
#  1355: ['Goken', 'Morita'],
#  1512: ['Fukuryudake'],
#  1296: ['Kasugafuji'],
#  1299: ['Kiraiho'],
#  51: ['Daizen'],
#  1297: ['Dairyu'],
#  1463: ['Maemiyama'],
#  1326: ['Tsunenoyama', 'Nishinoryu'],
#  1368: ['Ryukozan', 'Miyata'],
#  4337: ['Kiyononada'],
#  1520: ['Hidenohana'],
#  1321: ['Dewanokuni'],
#  1288: ['Kotobeppu'],
#  1418: ['Koganefuji'],
#  1319: ['Tachihikari'],
#  1314: ['Owakamatsu'],
#  55: ['Zenshinyama'],
#  48: ['Oginohana'],
#  1305: ['Kyokugozan'],
#  44: ['Kushimaumi', 'Kushima'],
#  5051: ['Kyokueiko'],
#  1290: ['Wakashoyo', 'Shidenryu', 'Babaguchi'],
#  1285: ['Asahisato'],
#  1327: ['Yoshinobori'],
#  1382: ['Takamishu'],
#  18: ['Takatoriki', 'Kamakari'],
#  1371: ['Ryujuyama'],
#  1309: ['Tamakairiki'],
#  1384: ['Takamio'],
#  1386: ['Fuchita'],
#  3: ['Wakanohana', 'Wakahanada'],
#  2: ['Takanohana', 'Takahanada'],
#  1387: ['Suginohana'],
#  82: ['Tochitenko'],
#  16: ['Minatofuji'],
#  1: ['Akebono'],
#  1323: ['Kumao'],
#  77: ['Yutakafuji', 'Osuzuki'],
#  1307: ['Daishoyama'],
#  157: ['Tomoefuji'],
#  14: ['Kotonowaka'],
#  1351: ['Ryugahama'],
#  53: ['Tokitsunada'],
#  1294: ['Naminohana'],
#  45: ['Daishoho', 'Murata'],
#  1324: ['Terunoumi', 'Hayashi', 'Daikiko'],
#  160: ['Tatsuhikari'],
#  42: ['Mainoumi', 'Nagao'],
#  5: ['Takanonami', 'Namioka'],
#  1286: ['Kenko'],
#  1341: ['Seifuriki', 'Seifu'],
#  62: ['Daishi'],
#  1306: ['Hitachiryu'],
#  4: ['Musashimaru'],
#  1336: ['Takanonada', 'Nakajima'],
#  1388: ['Tochisagami'],
#  87: ['Wakanoyama'],
#  15: ['Oginishiki'],
#  1344: ['Akinomine'],
#  1346: ['Kengaku'],
#  159: ['Kiyota'],
#  1340: ['Taishin', 'Murai'],
#  140: ['Ohidake'],
#  7: ['Kaio', 'Koga'],
#  11: ['Aogiyama', 'Teraki'],
#  24: ['Ganyu'],
#  73: ['Kanechika', 'Gassan'],
#  21: ['Asahiyutaka'],
#  133: ['Genkai'],
#  67: ['Tochinofuji'],
#  1325: ['Wakatosho'],
#  1322: ['Hidenoumi'],
#  1391: ['Mitsueyama'],
#  26: ['Higonoumi'],
#  76: ['Hoshitango'],
#  1392: ['Akinokuni'],
#  91: ['Hoshiandesu'],
#  1289: ['Rikio'],
#  209: ['Asanonami', 'Ota'],
#  34: ['Asanowaka', 'Wakaadachi'],
#  52: ['Tomonohana'],
#  1328: ['Yamanakayama'],
#  25: ['Hamanoshima', 'Hamasu'],
#  1393: ['Daishoryu'],
#  1394: ['Wakadozan'],
#  59: ['Susanoumi', 'Kanesaku', 'Masakabuto'],
#  36: ['Asanosho', 'Ozawa', 'Asasoyo'],
#  20: ['Shikishima', 'Yoshitane'],
#  1318: ['Shigenoumi'],
#  6: ['Musoyama'],
#  1395: ['Daitengo'],
#  372: ['Chokairyu'],
#  178: ['Shoeito', 'Kirinowaka'],
#  238: ['Umenosato'],
#  191: ['Kiyonofuji'],
#  144: ['Ryudo', 'Ikemori'],
#  145: ['Kobo', 'Mineyama'],
#  174: ['Mutsuhokkai'],
#  1316: ['Oyamato', 'Shirasaki'],
#  143: ['Daiden'],
#  108: ['Ominato'],
#  54: ['Ohinode'],
#  188: ['Genkainami'],
#  134: ['Fukuzono', 'Tsurunofuji'],
#  29: ['Kotoryu'],
#  177: ['Mutetsuyama', 'Kurimoto'],
#  66: ['Wakahayato'],
#  138: ['Sentoryu', 'Kaishinzan'],
#  13: ['Tosanoumi'],
#  74: ['Kotokanyu'],
#  1291: ['Sunahama'],
#  68: ['Gokenzan', 'Goto'],
#  75: ['Daihisho'],
#  17: ['Tamakasuga'],
#  57: ['Yamato'],
#  35: ['Kyokushuzan'],
#  8: ['Chiyotaikai'],
#  22: ['Gojoro'],
#  63: ['Otsukasa', 'Ouchi'],
#  27: ['Wakanojo', 'Aka'],
#  1300: ['Daiki'],
#  124: ['Sumiya', 'Saigo'],
#  1298: ['Kotoarashi'],
#  78: ['Toyozakura'],
#  79: ['Kotoiwakuni', 'Kotofujimoto'],
#  19: ['Tochiazuma', 'Shiga'],
#  1398: ['Nanfu'],
#  41: ['Kyokutenho'],
#  119: ['Takamihana'],
#  46: ['Dewaarashi'],
#  1293: ['Chiyonowaka'],
#  40: ['Kaiho', 'Kumagaya'],
#  58: ['Oikari'],
#  31: ['Dejima'],
#  10: ['Tochinonada', 'Goto'],
#  32: ['Akinoshu'],
#  121: ['Masunobori'],
#  47: ['Chiyotenzan'],
#  50: ['Tokitsuumi'],
#  38: ['Toki'],
#  39: ['Wakanosato', 'Kogawa'],
#  83: ['Arashi'],
#  64: ['Yotsukasa', 'Suzuki'],
#  61: ['Hokutohikari'],
#  43: ['Kinkaiyama'],
#  71: ['Takanowaka', 'Takaozaki'],
#  96: ['Jumonji', 'Kaigatake'],
#  56: ['Masutsuyoshi'],
#  72: ['Tochisakae', 'Okamoto', 'Tochinoiwa'],
#  65: ['Dewataira'],
#  70: ['Kitazakura'],
#  69: ['Towanoyama', 'Otakayama'],
#  86: ['Futatsukuba'],
#  842: ['Miyabiyama', 'Takeuchi'],
#  105: ['Buyuzan', 'Tominagayama'],
#  97: ['Tochinohana', 'Yachi'],
#  129: ['Hayateumi', 'Saito'],
#  116: ['Nakao', 'Wakatsutomu'],
#  167: ['Tamamitsukuni', 'Tamanokuni'],
#  101: ['Dewanofuji'],
#  81: ['Wakakosho'],
#  107: ['Kasuganishiki'],
#  149: ['Juzan'],
#  88: ['Tamarikido'],
#  152: ['Tamanoshima', 'Tamanonada'],
#  875: ['Takamisakari', 'Kato'],
#  876: ['Kotomitsuki', 'Kototamiya'],
#  89: ['Aminishiki'],
#  84: ['Tomikaze'],
#  312: ['Hokutomine'],
#  118: ['Midorifuji'],
#  205: ['Fujinohana', 'Goto'],
#  147: ['Toyonokuni', 'Minami'],
#  163: ['Senshuyama'],
#  251: ['Wakatoryu', 'Nodera'],
#  130: ['Kaido', 'Tanaka', 'Kaito'],
#  874: ['Hamanishiki', 'Takahama'],
#  878: ['Asashoryu'],
#  199: ['Kuniazuma'],
#  92: ['Harunoyama', 'Haruyama'],
#  222: ['Sumanofuji'],
#  99: ['Shunketsu', 'Komahikari', 'Ishide'],
#  785: ['Furuichi', 'Komidori'],
#  225: ['Takanotsuru', 'Sekiyama'],
#  135: ['Hokutoriki'],
#  287: ['Wakatoba', 'Yamada'],
#  80: ['Otoryu'],
#  1018: ['Shimotori', 'Shimootori'],
#  104: ['Wakaazuma'],
#  106: ['Torafusuyama'],
#  128: ['Nishikikaze'],
#  300: ['Dairaido', 'Raido'],
#  175: ['Ushiomaru'],
#  226: ['Wakatenro'],
#  126: ['Tochinoyama'],
#  168: ['Hokutoiwa'],
#  122: ['Daimanazuru'],
#  1087: ['Iwakiyama'],
#  865: ['Kasugao'],
#  784: ['Daishodai'],
#  132: ['Kotonomine'],
#  1009: ['Asasekiryu'],
#  1284: ['Takekaze', 'Narita'],
#  1187: ['Kokkai'],
#  204: ['Ryuho'],
#  264: ['Shishio'],
#  95: ['Hidenokuni'],
#  1225: ['Asahimaru', 'Asamiyoshi'],
#  113: ['Asofuji'],
#  1204: ['Kakizoe'],
#  2834: ['Futeno', 'Uchida'],
#  102: ['Asahibenten'],
#  103: ['Tochifudo'],
#  864: ['Bushuyama'],
#  2818: ['Tokitenku'],
#  334: ['Hokutojo'],
#  1111: ['Harumafuji', 'Ama'],
#  180: ['Wakainami'],
#  216: ['Raiko'],
#  1123: ['Hakuho'],
#  1421: ['Roho'],
#  315: ['Nadatsukasa'],
#  240: ['Ichinotani'],
#  1235: ['Kisenosato', 'Hagiwara'],
#  2830: ['Kotooshu'],
#  1227: ['Toyonoshima'],
#  206: ['Kotokasuga'],
#  239: ['Maikaze'],
#  1226: ['Kotoshogiku'],
#  1243: ['Katayama'],
#  296: ['Yoshiazuma'],
#  924: ['Wakakirin', 'Suzukawa'],
#  5977: ['Takamifuji'],
#  1402: ['Hakurozan'],
#  1032: ['Hochiyama'],
#  795: ['Tamaasuka'],
#  898: ['Chiyohakuho'],
#  244: ['Kaishozan'],
#  371: ['Kyokunankai'],
#  365: ['Kotokuni'],
#  90: ['Fukkoyama'],
#  136: ['Dewanosato'],
#  5988: ['Oiwato', 'Kanbayashi'],
#  2847: ['Masatsukasa'],
#  5967: ['Yoshikaze', 'Onishi'],
#  5984: ['Shirononami', 'Shiraishi'],
#  6432: ['Baruto'],
#  1109: ['Daishoma'],
#  1219: ['Kakuryu'],
#  1136: ['Mokonami'],
#  6018: ['Homasho'],
#  5985: ['Satoyama'],
#  6468: ['Goeido', 'Sawai'],
#  1031: ['Ryuo'],
#  247: ['Oga'],
#  1106: ['Koryu'],
#  6012: ['Dewaotori'],
#  1011: ['Hakuba'],
#  929: ['Kirinowaka'],
#  6010: ['Kimurayama'],
#  6643: ['Shimoda'],
#  6473: ['Tochiozan', 'Kageyama'],
#  900: ['Wakakoyu', 'Yakigaya'],
#  6467: ['Toyohibiki', 'Kadomoto'],
#  6527: ['Wakanoho'],
#  6620: ['Sakaizawa'],
#  1141: ['Shotenro', 'Musashiryu'],
#  6766: ['Kiyoseumi', 'Ichihara'],
#  1104: ['Hoshihikari'],
#  813: ['Kitataiki'],
#  6034: ['Sagatsukasa', 'Isobe'],
#  4980: ['Sokokurai'],
#  1127: ['Hokutokuni'],
#  6599: ['Tochinoshin'],
#  5944: ['Tamawashi'],
#  7115: ['Tosayutaka'],
#  1152: ['Daiyubu'],
#  6769: ['Yamamotoyama'],
#  7138: ['Daishoumi', 'Mori'],
#  6771: ['Aran'],
#  2831: ['Hoshikaze'],
#  2930: ['Tokusegawa'],
#  511: ['Yotsuguruma'],
#  662: ['Kotoyutaka'],
#  6463: ['Okinoumi', 'Fukuoka'],
#  1137: ['Sensho'],
#  1053: ['Kasugakuni'],
#  6572: ['Gagamaru'],
#  335: ['Shoketsu'],
#  6552: ['Sotairyu'],
#  7121: ['Tokushinho'],
#  2842: ['Sadanofuji'],
#  2820: ['Nakanokuni'],
#  11784: ['Myogiryu', 'Miyamoto'],
#  866: ['Surugatsukasa'],
#  6042: ['Masuraumi', 'Kurosawa'],
#  6497: ['Daido', 'Nakanishi'],
#  6614: ['Shohozan', 'Matsutani'],
#  2879: ['Sadanoumi'],
#  6753: ['Kaisei'],
#  11728: ['Takarafuji'],
#  1134: ['Tsurugidake'],
#  1215: ['Takanoyama'],
#  8900: ['Akiseyama', 'Fukao'],
#  6483: ['Maeta'],
#  6767: ['Tochinowaka'],
#  2835: ['Shironoryu'],
#  2851: ['Fujiazuma'],
#  6654: ['Masunoyama'],
#  6480: ['Takayasu'],
#  11726: ['Tokushoryu', 'Aoki'],
#  6491: ['Ikioi'],
#  1266: ['Nionoumi'],
#  11786: ['Aoiyama'],
#  6770: ['Tenkaiho', 'Minami'],
#  1241: ['Kitaharima'],
#  1054: ['Hitenryu', 'Mochimaru'],
#  1190: ['Kaonishiki'],
#  2832: ['Arawashi'],
#  2858: ['Tochitsubasa'],
#  6642: ['Chiyonokuni'],
#  1097: ['Oniarashi'],
#  7239: ['Kyokushuho'],
#  11850: ['Chiyozakura'],
#  7109: ['Chiyoarashi'],
#  9079: ['Kotoyuki'],
#  11729: ['Kimikaze', 'Naoe'],
#  6512: ['Hishofuji'],
#  6600: ['Tochihiryu'],
#  6622: ['Masakaze', 'Kitazono'],
#  11723: ['Azumaryu'],
#  6531: ['Asahisho'],
#  11934: ['Chiyotairyu', 'Meigetsuin'],
#  8904: ['Homarefuji'],
#  1405: ['Amuru'],
#  489: ['Chokozan'],
#  6928: ['Chiyootori'],
#  1058: ['Wakanoshima'],
#  6476: ['Hakiai'],
#  11971: ['Jokoryu', 'Sakumayama'],
#  8154: ['Higonojo'],
#  11724: ['Takanoiwa'],
#  8903: ['Keitenkai', 'Kei'],
#  7125: ['Tanzo', 'Terashita'],
#  6506: ['Kairyu'],
#  11989: ['Yamaguchi', 'Daikiho'],
#  9064: ['Tochiyashiki'],
#  6594: ['Ryuden'],
#  6559: ['Seiro'],
#  11840: ['Chiyonoo', 'Chiyoo'],
#  2929: ['Kagamio'],
#  6596: ['Nishikigi'],
#  7143: ['Amakaze', 'Kawanari'],
#  7240: ['Chiyomaru'],
#  9077: ['Kizenryu'],
#  940: ['Kotomisen'],
#  12055: ['Endo'],
#  11987: ['Osunaarashi'],
#  2909: ['Sakigake'],
#  11927: ['Terunofuji', 'Wakamisho'],
#  6445: ['Shoho'],
#  1052: ['Kihonoumi'],
#  9097: ['Kansei'],
#  6458: ['Yamatofuji'],
#  6646: ['Higoarashi'],
#  12107: ['Ichinojo'],
#  11985: ['Daieisho'],
#  8899: ['Kyokutaisei'],
#  12051: ['Ishiura'],
#  11764: ['Horyuyama'],
#  6013: ['Dewahayate'],
#  12026: ['Hidenoumi', 'Iwasaki'],
#  7153: ['Kotoeko'],
#  11845: ['Kagayaki', 'Tatsu'],
#  12113: ['Tsurugisho', 'Abiko'],
#  12043: ['Onosho'],
#  12094: ['Abi', 'Horikiri'],
#  12144: ['Daishomaru', 'Kawabata'],
#  12130: ['Shodai'],
#  12210: ['Mitakeumi'],
#  7156: ['Hokaho'],
#  12140: ['Takaryu'],
#  7127: ['Asabenkei'],
#  8901: ['Kisenoyama'],
#  12040: ['Daishoho'],
#  11785: ['Chiyoshoma'],
#  12226: ['Ura'],
#  11918: ['Akua'],
#  11868: ['Terutsuyoshi'],
#  11943: ['Hakuyozan'],
#  12191: ['Takakeisho', 'Sato'],
#  12239: ['Hokutofuji', 'Daiki'],
#  12024: ['Shimanoumi'],
#  12292: ['Yutakayama', 'Oyanagi'],
#  11946: ['Meisei'],
#  12273: ['Daiamami', 'Sakamoto'],
#  11947: ['Rikishin'],
#  11965: ['Tochimaru'],
#  12141: ['Shiba'],
#  12077: ['Takagenji'],
#  12291: ['Asanoyama'],
#  12203: ['Tobizaru', 'Iwasaki'],
#  11972: ['Daiseido'],
#  12425: ['Yago'],
#  11855: ['Takanosho', 'Masunosho'],
#  12320: ['Churanoumi', 'Kizaki'],
#  12406: ['Mitoryu'],
#  12285: ['Asagyokusei', 'Tamaki'],
#  12412: ['Enho'],
#  12076: ['Takanofuji', 'Takayoshitoshi'],
#  12370: ['Wakatakakage'],
#  12255: ['Chiyonoumi'],
#  12369: ['Murata'],
#  12015: ['Gokushindo'],
#  12362: ['Ichiyamamoto'],
#  12231: ['Kirishima', 'Kiribayama'],
#  12427: ['Tomokaze'],
#  7111: ['Irodori'],
#  11949: ['Kotodaigo'],
#  12367: ['Ryuko'],
#  11980: ['Wakamotoharu'],
#  11809: ['Kotokuzan'],
#  12270: ['Kotonowaka', 'Kotokamatani'],
#  12470: ['Kizakiumi'],
#  12451: ['Hoshoryu'],
#  12075: ['Kaisho'],
#  12351: ['Nishikifuji'],
#  12449: ['Kotoshoho', 'Kototebakari'],
#  12352: ['Midorifuji'],
#  12453: ['Oho'],
#  12117: ['Bushozan'],
#  12575: ['Tohakuryu'],
#  12484: ['Asanowaka'],
#  12314: ['Hiradoumi'],
#  12664: ['Atamifuji'],
#  12646: ['Hokuseiho'],
#  12717: ['Oshoma'],
#  12721: ['Kinbozan'],
#  12162: ['Shonannoumi'],
#  12688: ['Gonoyama'],
#  12796: ['Hakuoho'],
#  12516: ['Roga'],
#  12013: ['Shimazuumi'],
#  11976: ['Tamashoho']}

# %%
# Now to creates a dataframe using this dictionary, listing each wrestler's ID with any shikona (name) associated with him.
shikona_df = pd.DataFrame.from_dict([([key] + value) for key, value in rikishi_id_dict.items()])
shikona_df.rename(columns={0: "id", 1: "current_shikona", 2: "alt_shikona2", 3: "alt_shikona3"}, inplace=True)
shikona_df.head()
# Out:
#      id current_shikona alt_shikona2 alt_shikona3
# 0  4140     Chikubayama         None         None
# 1  4306           Ofuji         None         None
# 2  1337    Tochitsukasa         None         None
# 3  4323        Shiraiwa         None         None
# 4  4097      Tamakiyama         None         None

# %%
# There are two lines for each match in the original csv file, one for the winner and one for the loser.
# So as not to show duplicates of every match, we'll just show the winners with the "sumo_only_wins" list.

sumo_only_wins = results[results.rikishi1_win == int("1")] #could also use sumo.loc[sumo.rikishi1_win == 1]

sumo_only_wins
# Out:
#           basho day  rikishi1_id rikishi1_rank rikishi1_shikona  \
# 1       1983.01   1         4306          Ms1e            Ofuji
# 2       1983.01   1         1337          J12w     Tochitsukasa
# 5       1983.01   1         4319          J11w       Harunafuji
# 7       1983.01   1         4129          J11e      Hakuryuyama
# 9       1983.01   1         4130           J9w          Hachiya
# ...         ...  ..          ...           ...              ...
# 227763  2023.07  15        12270           K1e       Kotonowaka
# 227765  2023.07  15        12291           M4e        Asanoyama
# 227766  2023.07  15        11855           M9e        Takanosho
# 227768  2023.07  15        12451           S1e         Hoshoryu
# 227770  2023.07  15        12094           K1w              Abi
#
#        rikishi1_result  rikishi1_win    kimarite  rikishi2_id rikishi2_rank  \
# 1            1-0 (6-1)             1    yorikiri         4140          J13w
# 2            1-0 (9-6)             1   oshidashi         4323          J13e
# 5           1-0 (5-10)             1    yorikiri         4097          J12e
# 7           1-0 (3-12)             1  tsukidashi         4109          J10w
# 9            1-0 (8-7)             1  hatakikomi         4111          J10e
# ...                ...           ...         ...          ...           ...
# 227763            11-4             1    yorikiri         6594          M15e
# 227765           8-4-3             1    yorikiri        11980           S2w
# 227766             8-7             1  hikiotoshi        11985           S1w
# 227768            12-3             1   uwatenage        12796          M17w
# 227770             6-9             1    yorikiri        12231           O1w
#
#        rikishi2_shikona rikishi2_result rikishi2_win
# 1           Chikubayama       0-1 (7-8)            0
# 2              Shiraiwa      0-1 (3-12)            0
# 5            Tamakiyama       0-1 (8-7)            0
# 7            Kotogatake       0-1 (7-8)            0
# 9            Zaonishiki      0-1 (4-11)            0
# ...                 ...             ...          ...
# 227763           Ryuden            10-5            0
# 227765     Wakamotoharu             9-6            0
# 227766         Daieisho             9-6            0
# 227768          Hakuoho            11-4            0
# 227770        Kirishima           6-7-2            0
#
# [113886 rows x 13 columns]

# %%
#Same as above, but now we'll just show the losers with the "sumo_only_losses" list.
sumo_only_losses = results[results.rikishi1_win == int("0")]

sumo_only_losses
# Out:
#           basho day  rikishi1_id rikishi1_rank rikishi1_shikona  \
# 0       1983.01   1         4140          J13w      Chikubayama
# 3       1983.01   1         4323          J13e         Shiraiwa
# 4       1983.01   1         4097          J12e       Tamakiyama
# 6       1983.01   1         4109          J10w       Kotogatake
# 8       1983.01   1         4111          J10e       Zaonishiki
# ...         ...  ..          ...           ...              ...
# 227762  2023.07  15         6594          M15e           Ryuden
# 227764  2023.07  15        11980           S2w     Wakamotoharu
# 227767  2023.07  15        11985           S1w         Daieisho
# 227769  2023.07  15        12796          M17w          Hakuoho
# 227771  2023.07  15        12231           O1w        Kirishima
#
#        rikishi1_result  rikishi1_win    kimarite  rikishi2_id rikishi2_rank  \
# 0            0-1 (7-8)             0    yorikiri         4306          Ms1e
# 3           0-1 (3-12)             0   oshidashi         1337          J12w
# 4            0-1 (8-7)             0    yorikiri         4319          J11w
# 6            0-1 (7-8)             0  tsukidashi         4129          J11e
# 8           0-1 (4-11)             0  hatakikomi         4130           J9w
# ...                ...           ...         ...          ...           ...
# 227762            10-5             0    yorikiri        12270           K1e
# 227764             9-6             0    yorikiri        12291           M4e
# 227767             9-6             0  hikiotoshi        11855           M9e
# 227769            11-4             0   uwatenage        12451           S1e
# 227771           6-7-2             0    yorikiri        12094           K1w
#
#        rikishi2_shikona rikishi2_result rikishi2_win
# 0                 Ofuji       1-0 (6-1)            1
# 3          Tochitsukasa       1-0 (9-6)            1
# 4            Harunafuji      1-0 (5-10)            1
# 6           Hakuryuyama      1-0 (3-12)            1
# 8               Hachiya       1-0 (8-7)            1
# ...                 ...             ...          ...
# 227762       Kotonowaka            11-4            1
# 227764        Asanoyama           8-4-3            1
# 227767        Takanosho             8-7            1
# 227769         Hoshoryu            12-3            1
# 227771              Abi             6-9            1
#
# [113886 rows x 13 columns]

# %%
# For each wrestler's ID, this tallies up their total number of wins.
win_count = {}

for r in rikishi_id_list:
    win_count[r] = len(sumo_only_wins.loc[results.rikishi1_id == r])
    
# I now create a dataframe that sorts the win tallies from highest to lowest.
sorted_win_count = sorted(win_count.items(), key=lambda x:x[1], reverse=True)

sorted_win_count_df = pd.DataFrame.from_dict(sorted_win_count)
sorted_win_count_df.columns = ['id', 'wins']
sorted_win_count_df.head()
# Out:
#      id  wins
# 0  1123  1121
# 1     7   956
# 2    89   831
# 3    41   827
# 4    39   781

# %%
# I now do the same thing but for each wrestler's total number of losses.
loss_count = {}

for r in rikishi_id_list:
    loss_count[r] = len(sumo_only_losses.loc[results.rikishi1_id == r])
    
sorted_loss_count = sorted(loss_count.items(), key=lambda x:x[1], reverse=True)

sorted_loss_count_df = pd.DataFrame.from_dict(sorted_loss_count)
sorted_loss_count_df.columns = ['id', 'losses']
sorted_loss_count_df.head()
# Out:
#      id  losses
# 0    41     888
# 1    89     869
# 2    33     855
# 3  1284     744
# 4    13     731

# %%
# I now combine the dataframe for wins the with dataframe for losses.
won_loss_df = pd.merge(sorted_win_count_df, sorted_loss_count_df)
won_loss_df
# Out:
#         id  wins  losses
# 0     1123  1121     212
# 1        7   956     642
# 2       89   831     869
# 3       41   827     888
# 4       39   781     692
# ..     ...   ...     ...
# 592  11965     0       1
# 593  12141     0       1
# 594  12369     0       1
# 595  11949     0       2
# 596  12013     0       1
#
# [597 rows x 3 columns]

# %%
# With the won-loss totals in a single dataframe, now I calculate each wrestler's winning percentage.
pct_list = []

for i in range(len(won_loss_df)):
    pct = round(int(won_loss_df[won_loss_df.id == won_loss_df['id'][i]].wins.iloc[0]) / int(
    (won_loss_df[won_loss_df.id == won_loss_df['id'][i]].wins.iloc[0])
    + int(won_loss_df[won_loss_df.id == won_loss_df['id'][i]].losses.iloc[0])
), 2)
    pct_list.append(pct)
pct_list

won_loss_df["pct"] = pct_list
won_loss_df
# Out:
#         id  wins  losses   pct
# 0     1123  1121     212  0.84
# 1        7   956     642  0.60
# 2       89   831     869  0.49
# 3       41   827     888  0.48
# 4       39   781     692  0.53
# ..     ...   ...     ...   ...
# 592  11965     0       1  0.00
# 593  12141     0       1  0.00
# 594  12369     0       1  0.00
# 595  11949     0       2  0.00
# 596  12013     0       1  0.00
#
# [597 rows x 4 columns]

# %%
# This takes the won_loss_df and merges it with the shikona_df

new_won_loss_df = pd.merge(won_loss_df, shikona_df)
new_won_loss_df = new_won_loss_df.iloc[:, [0, 4, 1, 2, 3, 5, 6]]
new_won_loss_df.head()
# Out:
#      id current_shikona  wins  losses   pct alt_shikona2 alt_shikona3
# 0  1123          Hakuho  1121     212  0.84         None         None
# 1     7            Kaio   956     642  0.60         Koga         None
# 2    89      Aminishiki   831     869  0.49         None         None
# 3    41      Kyokutenho   827     888  0.48         None         None
# 4    39      Wakanosato   781     692  0.53       Kogawa         None

# %%
# Every wrestler with 500+ wins in the top division.

with_500_wins = new_won_loss_df.loc[won_loss_df.wins >=500].sort_values(by='wins', ascending=False)
with_500_wins = with_500_wins.iloc[:, [0,1,2,3,4]]
with_500_wins
# Out:
#        id current_shikona  wins  losses   pct
# 0    1123          Hakuho  1121     212  0.84
# 1       7            Kaio   956     642  0.60
# 2      89      Aminishiki   831     869  0.49
# 3      41      Kyokutenho   827     888  0.48
# 4      39      Wakanosato   781     692  0.53
# 5    1226     Kotoshogiku   760     639  0.54
# 6    1111      Harumafuji   752     402  0.65
# 7       2      Takanohana   751     253  0.75
# 8    1235      Kisenosato   742     472  0.61
# 9      33           Terao   740     855  0.46
# 10      4     Musashimaru   733     284  0.72
# 11     13       Tosanoumi   713     731  0.49
# 12      8     Chiyotaikai   703     494  0.59
# 13      9      Akinoshima   694     668  0.51
# 14   1287       Konishiki   690     495  0.58
# 15   1219         Kakuryu   689     430  0.62
# 16      5      Takanonami   688     500  0.58
# 17   5944       Tamawashi   685     695  0.50
# 18   1284        Takekaze   678     744  0.48
# 19     28       Mitoizumi   675     692  0.49
# 20   6468          Goeido   645     478  0.57
# 21     10     Tochinonada   644     691  0.48
# 22    842      Miyabiyama   641     583  0.52
# 23     14      Kotonowaka   638     673  0.49
# 24    878       Asashoryu   622     164  0.79
# 25   1009      Asasekiryu   616     642  0.49
# 26   6599     Tochinoshin   610     585  0.51
# 27   5967       Yoshikaze   605     631  0.49
# 29      1         Akebono   604     217  0.74
# 30   6473       Tochiozan   604     582  0.51
# 28     18      Takatoriki   604     600  0.50
# 31     37     Kotoinazuma   596     666  0.47
# 32     31          Dejima   582     492  0.54
# 33   1227     Toyonoshima   582     559  0.51
# 34     30   Kitakachidoki   575     641  0.47
# 35   1292       Kotogaume   573     575  0.50
# 36     17      Tamakasuga   571     620  0.48
# 37   6463        Okinoumi   566     611  0.48
# 38   6480        Takayasu   561     437  0.56
# 39     12     Kotonishiki   559     494  0.53
# 40   1301       Kirishima   558     533  0.51
# 41  11728      Takarafuji   550     592  0.48
# 42    876     Kotomitsuki   549     363  0.60
# 43     23     Tochinowaka   548     602  0.48
# 44     51          Daizen   542     574  0.49
# 45   1354     Chiyonofuji   541      91  0.86
# 46      6        Musoyama   540     377  0.59
# 47     40           Kaiho   540     618  0.47
# 48     63        Otsukasa   531     601  0.47
# 49     49      Misugisato   530     586  0.47
# 50  11784        Myogiryu   527     532  0.50
# 51  11786         Aoiyama   527     531  0.50
# 52    875    Takamisakari   526     549  0.49
# 53   1302      Takamisugi   523     593  0.47
# 54     34       Asanowaka   522     590  0.47
# 55      3      Wakanohana   521     268  0.66
# 56     19      Tochiazuma   518     310  0.63
# 57     60       Toyonoumi   515     544  0.49
# 58    152     Tamanoshima   514     558  0.48
# 59   2818       Tokitenku   504     530  0.49

# %% [markdown]
# <!-- TO DO: re-do all those win/loss things, but with ID instead of Shikona -->
